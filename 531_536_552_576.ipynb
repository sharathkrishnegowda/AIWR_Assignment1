# %%
import nltk
import numpy as np
import pandas as pd

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download('omw-1.4')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
stopwords = nltk.corpus.stopwords.words('english')
stemmer = nltk.stem.SnowballStemmer('english')
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
import pandas as pd

# %%
df1=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AIWR/IMDB Top 250 Movies.csv')

# %%
df1.isnull().sum()
# Out:
# rank           0
# name           0
# year           0
# rating         0
# genre          0
# certificate    0
# run_time       0
# tagline        0
# budget         0
# box_office     0
# casts          0
# directors      0
# writers        0
# dtype: int64

# %%
df = df1.dropna()

# %%
df.isnull().sum()
# Out:
# rank           0
# name           0
# year           0
# rating         0
# genre          0
# certificate    0
# run_time       0
# tagline        0
# budget         0
# box_office     0
# casts          0
# directors      0
# writers        0
# dtype: int64

# %%
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# 0   25000000    28884504  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1    6000000   250341816  Marlon Brando,Al Pacino,James Caan,Diane Keato...
# 2  185000000  1006234167  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 3   13000000    47961919  Al Pacino,Robert De Niro,Robert Duvall,Diane K...
# 4     350000         955  Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...
#
#               directors                                          writers
# 0        Frank Darabont                      Stephen King,Frank Darabont
# 1  Francis Ford Coppola                  Mario Puzo,Francis Ford Coppola
# 2     Christopher Nolan  Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3  Francis Ford Coppola                  Francis Ford Coppola,Mario Puzo
# 4          Sidney Lumet                                    Reginald Rose

# %% [markdown]
# TOKENIZING THE **CORPUS**

# %%
corpus = df["tagline"].values

# %%
def tokenizing_corpus(type):
    return list(map(word_tokenize, type))

# %%
corpus_tokenized = tokenizing_corpus(corpus)

# %%
for i in range(250):
    print(f"Doc {i}: {corpus_tokenized[i]}")
# Out:
# Doc 0: ['Fear', 'can', 'hold', 'you', 'prisoner', '.', 'Hope', 'can', 'set', 'you', 'free', '.']
# Doc 1: ['An', 'offer', 'you', 'ca', "n't", 'refuse', '.']
# Doc 2: ['Why', 'So', 'Serious', '?']
# Doc 3: ['All', 'the', 'power', 'on', 'earth', 'ca', "n't", 'change', 'destiny', '.']
# Doc 4: ['Life', 'Is', 'In', 'Their', 'Hands', '--', 'Death', 'Is', 'On', 'Their', 'Minds', '!']
# Doc 47: ['There', 'were', 'three', 'men', 'in', 'her', 'life', '.', 'One', 'knew', 'her', 'past', '.', 'One', 'wanted', 'her', 'land', '.', 'One', 'wanted', 'revenge', '.']
# Doc 48: ['The', 'Essential', 'Hitchcock']
# Doc 49: ['A', 'celebration', 'of', 'youth', ',', 'friendship', ',', 'and', 'the', 'everlasting', 'magic', 'of', 'the', 'movies', '.']
# Doc 50: ['In', 'space', 'no', 'one', 'can', 'hear', 'you', 'scream', '.']
# Doc 51: ['HE', 'RETURNS', '-And', 'the', 'world', 'rocks', 'again', 'with', 'laughter', '.', '(', 'Print', 'Ad-Daily', 'Examiner', ',', '(', '(', 'Grafton', ',', 'NSW', ')', ')', '6', 'July', '1931', ')']
# Doc 52: ['The', 'Horror', '.', '.', '.', 'The', 'Horror', '.', '.', '.']
# Doc 53: ['Some', 'memories', 'are', 'best', 'forgotten']
# Doc 54: ['Life', ',', 'liberty', 'and', 'the', 'pursuit', 'of', 'vengeance', '.']
# Doc 55: ['Indiana', 'Jones', '-', 'the', 'new', 'hero', 'from', 'the', 'creators', 'of', 'JAWS', 'and', 'STAR', 'WARS', '.']
# Doc 56: ['After', '700', 'years', 'of', 'doing', 'what', 'he', 'was', 'built', 'for', '-', 'he', "'ll", 'discover', 'what', 'he', "'s", 'meant', 'for', '.']
# Doc 57: ['Before', 'the', 'Fall', 'of', 'the', 'Berlin', 'Wall', ',', 'East', 'Germany', "'s", 'Secret', 'Police', 'Listened', 'to', 'Your', 'Secrets']
# Doc 58: ['A', 'Hollywood', 'Story']
# Doc 59: ['Never', 'has', 'the', 'screen', 'thrust', 'so', 'deeply', 'into', 'the', 'guts', 'of', 'war', '!']
# Doc 60: ['Iconic', 'terror', 'from', 'the', 'No', '1', 'bestselling', 'writer', '.']
# Doc 61: ['The', 'Comedy', 'Masterpiece', '!']
# Doc 62: ['An', 'entire', 'universe', '.', 'Once', 'and', 'for', 'all', '.']
# Doc 63: ['The', 'most', 'electrifying', 'entertainment', 'of', 'our', 'time', '!']
# Doc 64: ['This', 'time', 'there', "'s", 'more', '.']
# Doc 65: ['Enter', 'a', 'universe', 'where', 'more', 'than', 'one', 'wears', 'the', 'mask', '.']
# Doc 66: ['...', 'look', 'closer']
# Doc 67: ['The', 'comedy', 'classic', 'from', 'celebrated', 'director', 'STANLEY', 'KUBRICK']
# Doc 68: ['The', 'Legend', 'Ends']
# Doc 69: ['15', 'years', 'of', 'imprisonment', ',', 'five', 'days', 'of', 'vengeance']
# Doc 70: ['Once', 'upon', 'a', 'time', 'in', 'Nazi', 'occupied', 'France', '...']
# Doc 71: ['The', 'man', '...', 'The', 'music', '...', 'The', 'madness', '...', 'The', 'murder', '...', 'The', 'motion', 'picture', '...']
# Doc 72: ['The', 'celebration', 'of', 'a', 'lifetime']
# Doc 73: ['``', 'Oooh', '...', '3-D', "''", '(', 'USA', '2009', 're-release', ')']
# Doc 74: ['Put', 'on', 'a', 'happy', 'face', '.']
# Doc 75: ['The', 'story', 'of', 'a', 'man', 'with', 'a', 'free', 'soul', '...', 'and', 'with', 'the', 'courage', 'to', 'follow', 'it', '.']
# Doc 119: ['He', "'s", 'back', 'in', 'an', 'all', 'new', 'adventure', '.', 'Memorial', 'Day', '1989', '.']
# Doc 120: ['The', 'Prize', 'Picture', 'They', 'Want', 'to', 'Censor', '!']
# Doc 121: ['Every', 'Child', 'is', 'Special']
# Doc 122: ['Time', 'is', 'the', 'enemy', '.']
# Doc 123: ['April', '1945', ',', 'a', 'nation', 'awaits', 'its', '...']
# Doc 124: ['You', 'think', 'our', 'girls', 'are', 'any', 'lesser', 'than', 'boys', '?']
# Doc 125: ['The', 'man', 'with', 'no', 'name', 'is', 'back', '.']
# Doc 126: ['The', 'Legend', 'Begins']
# Doc 127: ['This', 'is', 'the', 'great', 'film', 'he', 'has', 'been', 'working', 'on', 'for', 'a', 'whole', 'year']
# Doc 128: ['Not', 'since', 'SCARFACE', ',', 'so', 'much', 'action', '.', 'Not', 'since', 'the', 'Marx', 'Brothers', ',', 'so', 'much', 'comedy', '.', 'Not', 'since', 'THE', 'SEVEN', 'YEAR', 'ITCH', ',', 'so', 'much', 'Marilyn', '.']
# Doc 129: ['Nothing', 'is', 'as', 'it', 'seems']
# Doc 130: ['It', "'s", 'all', 'about', 'women', '--', '-and', 'their', 'men', '!']
# Doc 131: ['Earn', '.', 'Spend', '.', 'Party', '.']
# Doc 132: ['Inspired', 'by', 'a', 'True', 'Friendship']
# Doc 133: ['More', 'than', 'a', 'motion', 'picture', '...', 'It', 'is', 'an', 'overwhelming', 'experience', 'in', 'human', 'emotion', 'you', 'will', 'never', 'forget', '!']
# Doc 134: ['You', 'do', "n't", 'stay', 'at', 'the', 'top', 'forever']
# Doc 135: ['tionDramaWar']
# Doc 136: ['What', 'happens', 'when', 'make-believe', 'believes', 'it', "'s", 'real', '?']
# Doc 137: ['All', 'the', 'world', "'s", 'a', 'stage', '...']
# Doc 138: ['There', 'Will', 'Be', 'Greed', '.', 'There', 'Will', 'Be', 'Vengeance', '.']
# Doc 139: ['It', "'s", 'a', 'hell', 'of', 'a', 'thing', ',', 'killing', 'a', 'man']
# Doc 140: ['``', 'I', 'see', 'dead', 'people', "''"]
# Doc 141: ['Someone', 'is', 'missing', '.']
# Doc 142: ['The', 'Only', 'Thing', 'Greater', 'Than', 'the', 'Power', 'of', 'the', 'Mind', 'is', 'the', 'Courage', 'of', 'the', 'Heart']
# Doc 143: ['Life', 'finds', 'a', 'way', '.']
# Doc 144: ['Better', 'if', 'all', 'these', 'men', 'were', 'dead', '.', 'Think', 'about', 'it', '!']
# Doc 145: ['Storming', 'to', 'a', 'New', 'High', 'in', 'High', 'Adventure', '!']
# Doc 146: ['You', 'can', 'do', 'worse', 'than', 'see', 'it', '.']
# Doc 147: ['put', 'a', 'fence', 'in', 'front', 'of', 'these', 'men', '...', 'and', 'they', "'ll", 'climb', 'it', '...']
# Doc 148: ['There', 'Are', 'No', 'Clean', 'Getaways']
# Doc 149: ['The', 'Multiverse', 'Unleashed', '.']
# Doc 150: ['In', 'the', 'year', '2003', ',', 'Uma', 'Thurman', 'will', 'kill', 'Bill']
# Doc 196: ['OUR', 'OPERATOR', 'SAYS', '..', "''", 'IT', "'S", 'GOING', 'TO', 'BE', 'A', 'PLEASURE', 'TO', 'RUN', '``', 'MR.', 'SMITH', 'GOES', 'TO', 'WASHINGTON', "''", '5', 'DAYS', 'STARTING', 'SUNDAY', ',', 'NOV.7', ')', '(', 'print', 'ad', '-', 'Lubbock', 'Morning', 'Avalanche', '-', 'Cactus', 'Theatre', '-', 'Lubbock', 'Texas', '-', 'November', '2', ',', '1938', '-', 'all', 'caps', ')']
# Doc 197: ['WHAT', 'A', 'LOVELY', 'DAY', '(', 'all', 'caps', 'One', 'Sheet', ')']
# Doc 198: ['A', 'film', 'of', 'visual', 'scope', ',', 'of', 'imaginative', 'concept', ',', 'of', 'powerful', 'content', ',', 'written', 'and', 'directed', 'by', 'Ingmar', 'Bergman', ',', 'twice', 'honored', 'by', 'the', 'Interational', 'Jury', 'at', 'the', 'Cannes', 'Film', 'Festival', '1956,1957']
# Doc 199: ['Two', 'unlikely', 'people', '.', 'Two', 'different', 'worlds', 'come', 'together', 'in', 'a', 'story', 'about', 'a', 'most', 'unusual', 'friendship', '.']
# Doc 200: ['One', 'adventure', 'will', 'change', 'two', 'worlds']
# Doc 201: ['Love', 'knows', 'no', 'boundaries']
# Doc 202: ['Monsters', ',', 'Inc.', ':', 'We', 'Scare', 'Because', 'We', 'Care']
# Doc 203: ['Amity', 'Island', 'had', 'everything', '.', 'Clear', 'skies', '.', 'Gentle', 'surf', '.', 'Warm', 'water', '.', 'People', 'flocked', 'there', 'every', 'summer', '.', 'It', 'was', 'the', 'perfect', 'feeding', 'ground', '.']
# Doc 204: ['He', 'was', 'their', 'inspiration', '.', 'He', 'made', 'their', 'lives', 'extraordinary', '.']
# Doc 205: ['Hay', 'quienes', 'tratan', 'de', 'ganarse', 'la', 'vida', 'sin', 'mover', 'un', 'dedo', '...', 'otros', 'tienen', 'que', 'cortarlos', '.', '(', 'Mexico', ')']
# Doc 206: ['As', 'long', 'as', 'life', 'goes', 'on', ',', 'relationships', 'between', 'parents', 'and', 'children', 'will', 'bring', 'boundless', 'joy', 'and', 'endless', 'grief', '.']
# Doc 207: ['JOAN', 'of', 'ARC', 'PICTURES', 'Inc.', 'presents']
# Doc 208: ['When', 'a', 'country', 'descended', 'into', 'madness', 'and', 'the', 'world', 'turned', 'its', 'back', ',', 'one', 'man', 'had', 'to', 'make', 'a', 'choice']
# Doc 209: ['They', 'took', 'the', 'American', 'dream', 'for', 'a', 'ride', '.']
# Doc 210: ['You', 'have', 'a', 'ringside', 'seat', 'for', 'the', 'bloodiest', 'bicentennial', 'in', 'history', '!']
# Doc 211: ['The', 'first', 'casualty', 'of', 'war', 'is', 'innocence', '.']
# Doc 212: ['Dinner', 'is', 'served', '...', 'Summer', '2007']
# Doc 213: ['Break', 'the', 'story', '.', 'Break', 'the', 'silence', '.']
# Doc 214: ['La', 'sua', 'missione', 'e', 'una', 'sola', ':', 'distruggere', ',', 'uccidere', '...', '(', 'His', 'one', 'and', 'only', 'mission', ':', 'to', 'destroy', ',', 'to', 'kill', '...', ')', '(', 'Italian', 'DVD', ')']
# Doc 237: ['``', 'What', 'we', "'ve", 'got', 'here', 'is', 'failure', 'to', 'communicate', '.', "''"]
# Doc 238: ['Never', 'did', 'they', 'expect', 'to', 'get', 'into', 'a', 'controversial', 'relationship', '...']
# Doc 239: ['From', 'the', 'Vanguard', 'of', 'New', 'Film-Makers', 'Comes', 'an', 'Extraordinary', 'Motion', 'Picture']
# Doc 240: ['RADIANCE', 'THAT', 'FLOODS', 'THE', 'SCREEN', '...', 'AND', 'WARMS', 'THE', 'HEART', '!']
# Doc 241: ['Two', 'great', 'lovers', 'of', 'the', 'screen', 'in', 'the', 'grandest', 'of', 'romantic', 'comedies', '!']
# Doc 242: ['A', 'new', 'film', 'by', 'Ingmar', 'Bergman']
# Doc 243: ['A', 'motion', 'picture', 'destined', 'to', 'offend', 'nearly', 'two', 'thirds', 'of', 'the', 'civilized', 'world', '.', 'And', 'severely', 'annoy', 'the', 'other', 'third', '.']
# Doc 244: ['Some', 'secrets', 'are', 'too', 'huge', 'to', 'hide']
# Doc 245: ['Change', 'begins', 'with', 'a', 'whisper', '.']
# Doc 246: ['There', 'is', 'man', 'and', 'beast', 'at', 'nature', "'s", 'mercy', '.', 'There', 'is', 'awe', 'and', 'love', 'and', 'reverence', '.', 'And', 'there', 'is', 'the', 'man', 'called', '...']
# Doc 247: ['Wish', 'granted', '!', '(', 'DVD', 're-release', ')']
# Doc 248: ['His', 'Triumph', 'Changed', 'The', 'World', 'Forever', '.']
# Doc 249: ['Inside', 'everyone', 'is', 'a', 'frontier', 'waiting', 'to', 'be', 'discovered', '.']

# %% [markdown]
# REMOVING THE STOPWORDS

# %%
verify=[',',':',';','.','#','(',')','{','[',']',"}",'/','?']

# %%
def removing_stopwords(tokenized_review):
    _function = lambda review: [word for word in review if word not in stopwords and word not in verify]
    return list(map(_function, tokenized_review))

# %%
nostopword_corpus = removing_stopwords(corpus_tokenized)

# %%
for i in range(250):
    print(f"review {i}: {nostopword_corpus[i]}")
# Out:
# review 0: ['Fear', 'hold', 'prisoner', 'Hope', 'set', 'free']
# review 1: ['An', 'offer', 'ca', "n't", 'refuse']
# review 2: ['Why', 'So', 'Serious']
# review 3: ['All', 'power', 'earth', 'ca', "n't", 'change', 'destiny']
# review 4: ['Life', 'Is', 'In', 'Their', 'Hands', '--', 'Death', 'Is', 'On', 'Their', 'Minds', '!']
# review 5: ['Whoever', 'saves', 'one', 'life', 'saves', 'world', 'entire']
# review 6: ['The', 'eye', 'enemy', 'moving']
# review 7: ['Girls', 'like', "n't", 'make', 'invitations', 'like', 'anyone', '!']
# review 8: ['The', 'Legend', 'Comes', 'Life']
# review 9: ['They', 'formed', 'alliance', 'hate', 'steal', 'fortune', 'dead', 'man', "'s", 'gold']
# review 10: ['The', 'story', 'lifetime']
# review 11: ['How', 'much', 'know', "'ve", 'never', 'fight']
# review 12: ['A', 'New', 'Power', 'Is', 'Rising']
# review 13: ['Your', 'mind', 'scene', 'crime']
# review 14: ['The', 'Adventure', 'Continues', '...']
# review 15: ['Free', 'mind']
# review 16: ['``', 'As', 'far', 'back', 'I', 'remember', 'I', "'ve", 'always', 'wanted', 'gangster', "''", '--', 'Henry', 'Hill', 'Brooklyn', 'N.Y.', '1955']
# review 17: ['If', "'s", 'crazy', 'make']
# review 18: ['Long', 'way', 'hard', 'hell', 'leads', 'light']
# review 19: ['Will', 'Take', 'Its', 'Place', 'With', 'Seven', 'Greatest', 'Films', 'All', 'Time', '!']
# review 20: ['Frank', 'Capra', "'s", '...', "''", 'It', "'s", 'Wonderful', 'Life', "''"]
# review 21: ['Dr.', 'Hannibal', 'Lecter', 'Brilliant', 'Cunning', 'Psychotic', 'In', 'mind', 'lies', 'clue', 'ruthless', 'killer', '-', 'Clarice', 'Starling', 'FBI', 'Brilliant', 'Vulnerable', 'Alone', 'She', 'must', 'trust', 'stop', 'killer']
# review 22: ['If', 'run', 'beast', 'get', 'If', 'stay', 'beast', 'eat']
# review 23: ['In', 'Last', 'Great', 'Invasion', 'Last', 'Great', 'War', 'The', 'Greatest', 'Danger', 'Eight', 'Men', 'Saving', '...', 'One']
# review 24: ['Mankind', 'born', 'Earth', 'It', 'never', 'meant', 'die']
# review 25: ['An', 'unforgettable', 'fable', 'proves', 'love', 'family', 'imagination', 'conquer', 'Canadian', 'one', 'sheet']
# review 26: ['Miracles', 'happen']
# review 27: ['It', "'s", 'Back', '!', 'The', 'Force', 'three', 'weeks', '1979', 'Reissue', 'Poster']
# review 28: ['It', "'s", 'nothing', 'personal']
# review 29: ['He', "'s", 'kid', 'ever', 'get', 'trouble', 'born', 'UK']
# review 30: ['The', 'tunnel', 'led', 'Chihiro', 'mysterious', 'town']
# review 31: ['Music', 'passion', 'Survival', 'masterpiece']
# review 32: ['The', 'picture', 'MUST', 'see', 'beginning', '...', 'Or', '!', '...', 'For', 'one', 'seated', 'start', '...', 'Alfred', 'Hitchcock', "'s", 'greatest', 'shocker', 'Psycho']
# review 33: ['Misplaced', 'familyhood', 'Australia/New', 'Zealand/Singapore']
# review 34: ['If', 'want', 'job', 'done', 'right', 'hire', 'professional']
# review 35: ['See', 'first', 'time', 'ever', '3D', '2011', '3D', 're-release']
# review 36: ['Father', 'murdered', 'son', 'husband', 'murdered', 'wife', 'I', 'shall', 'vengeance', 'life', 'next']
# review 37: ['His', 'father', 'taught', 'hate', 'His', 'friends', 'taught', 'rage', 'His', 'enemies', 'gave', 'hope']
# review 38: ['Lies', 'Betrayal', 'Sacrifice', 'How', 'far', 'take']
# review 39: ['The', 'greatest', 'trick', 'devil', 'ever', 'pulled', 'convince', 'world', "n't", 'exist']
# review 40: ['A', 'Friendship', 'That', 'Became', 'Rivalry']
# review 41: ['The', 'road', 'greatness', 'take', 'edge']
# review 42: ['Where', 'Love', 'Cuts', 'Deep', 'Dagger', '!']
# review 43: ['imationDramaWar']
# review 44: ['The', 'World', 'Has', 'Never', 'Understood', 'Why', 'Japanese', 'Prefer', 'Death', 'Dishonor', '!', 'This', 'Samurai', 'Picture', 'Provides', 'The', 'Answer', '!', '!']
# review 45: ['Sometimes', 'reach', 'someone', 'else', "'s", 'world', 'find', "'s", 'missing']
# review 46: ['He', 'stands', 'alone', 'greatest', 'entertainer', 'modern', 'times', '!', 'No', 'one', 'earth', 'make', 'laugh', 'heartily', 'touch', 'heart', 'deeply', '...', 'whole', 'world', 'laughs', 'cries', 'thrills', 'priceless', 'genius', '!']
# review 47: ['There', 'three', 'men', 'life', 'One', 'knew', 'past', 'One', 'wanted', 'land', 'One', 'wanted', 'revenge']
# review 48: ['The', 'Essential', 'Hitchcock']
# review 49: ['A', 'celebration', 'youth', 'friendship', 'everlasting', 'magic', 'movies']
# review 50: ['In', 'space', 'one', 'hear', 'scream']
# review 51: ['HE', 'RETURNS', '-And', 'world', 'rocks', 'laughter', 'Print', 'Ad-Daily', 'Examiner', 'Grafton', 'NSW', '6', 'July', '1931']
# review 52: ['The', 'Horror', 'The', 'Horror']
# review 53: ['Some', 'memories', 'best', 'forgotten']
# review 54: ['Life', 'liberty', 'pursuit', 'vengeance']
# review 55: ['Indiana', 'Jones', '-', 'new', 'hero', 'creators', 'JAWS', 'STAR', 'WARS']
# review 56: ['After', '700', 'years', 'built', '-', "'ll", 'discover', "'s", 'meant']
# review 57: ['Before', 'Fall', 'Berlin', 'Wall', 'East', 'Germany', "'s", 'Secret', 'Police', 'Listened', 'Your', 'Secrets']
# review 58: ['A', 'Hollywood', 'Story']
# review 59: ['Never', 'screen', 'thrust', 'deeply', 'guts', 'war', '!']
# review 60: ['Iconic', 'terror', 'No', '1', 'bestselling', 'writer']
# review 61: ['The', 'Comedy', 'Masterpiece', '!']
# review 62: ['An', 'entire', 'universe', 'Once']
# review 63: ['The', 'electrifying', 'entertainment', 'time', '!']
# review 64: ['This', 'time', "'s"]
# review 65: ['Enter', 'universe', 'one', 'wears', 'mask']
# review 66: ['...', 'look', 'closer']
# review 67: ['The', 'comedy', 'classic', 'celebrated', 'director', 'STANLEY', 'KUBRICK']
# review 68: ['The', 'Legend', 'Ends']
# review 69: ['15', 'years', 'imprisonment', 'five', 'days', 'vengeance']
# review 70: ['Once', 'upon', 'time', 'Nazi', 'occupied', 'France', '...']
# review 71: ['The', 'man', '...', 'The', 'music', '...', 'The', 'madness', '...', 'The', 'murder', '...', 'The', 'motion', 'picture', '...']
# review 72: ['The', 'celebration', 'lifetime']
# review 73: ['``', 'Oooh', '...', '3-D', "''", 'USA', '2009', 're-release']
# review 74: ['Put', 'happy', 'face']
# review 75: ['The', 'story', 'man', 'free', 'soul', '...', 'courage', 'follow']
# review 76: ['This', 'story', '42', 'raw', 'recruits', 'caught', 'war', "n't", 'understand', 'Captain', 'must', 'lead', 'struggle', 'survive']
# review 77: ['Avenge', 'fallen']
# review 78: ['Live']
# review 79: ['Crime', 'passion', 'lust', 'power', '-', 'Sergio', 'Leone', "'s", 'explosive', 'saga', 'gangland', 'America']
# review 80: ['Some', 'people', 'never', 'believe', 'someone', 'believes']
# review 81: ['Experience', 'Japan', "'s", '1', 'film', '2016', 'visionary', 'director', 'Makoto', 'Shinkai']
# review 82: ['Do', "n't", 'Stupid', 'Be', 'I.D.I.O.T']
# review 83: ['Singin', "'", 'Swingin', "'", 'Glorious', 'Feelin', "'", 'Technicolor', 'Musical']
# review 84: ['From', 'director', 'Pi']
# review 85: ['The', 'Breakout', 'Comedy', 'Of', 'The', 'Summer']
# review 86: ['142', 'Screenful', 'Minutes', 'Thrills', 'Suspense', '!']
# review 87: ['``', 'Why', 'suing', 'parents', "''", '``', 'For', 'giving', 'life', "''"]
# review 88: ['Coming', 'May', '25', '1983', 'galaxy', 'Second', 'Advance', 'poster']
# review 89: ['I', 'already', 'forget', 'I', 'used', 'feel']
# review 90: ['Let', 'Awe', 'Mystery', 'Journey', 'Unlike', 'Any', 'Other', 'Begin']
# review 91: ['Seven', 'Total', 'Strangers', 'Team', 'Up', 'For', 'The', 'Perfect', 'Crime', 'They', 'Do', "n't", 'Know', 'Each', 'Other', "'s", 'Name', 'But', 'They', "'ve", 'Got', 'Each', 'Other', "'s", 'Color']
# review 92: ['The', 'cruelest', 'side', 'war']
# review 93: ['The', 'lie', 'spreading']
# review 94: ['Radio', "'s", 'Most', 'Dynamic', 'Artist', 'The', 'Man', 'At', 'Whose', 'Voice', 'A', 'Nation', 'Trembled', 'Now', 'screen', "'s", 'exciting', 'NEW', 'star', '!', 'ORSON', 'WELLES', 'picture', 'Hollywood', 'said', "'d", 'never', 'make']
# review 95: ['IT', 'STAGGERS', 'THE', 'SENSES', '!', '...', 'SHOCKS', 'Imagination', '-', 'It', 'leave', 'Gasping', '-', 'It', 'Sensation', '3', 'Continents', '!']
# review 96: ['A', 'Mighty', 'Motion', 'Picture', 'Of', 'Action', 'And', 'Adventure', '!']
# review 97: ['Alfred', 'Hitchcock', 'takes', '....', 'North', 'Northwest', '!']
# review 98: ['A', 'Hitchcock', 'thriller', 'You', 'see', 'beginning', '!']
# review 99: ['One', 'Great', 'Films', 'Our', 'Time', '!']
# review 100: ['One', 'person', 'change', 'life', 'forever']
# review 101: ['Movie-wise', 'never', 'anything', 'like', '``', 'THE', 'APARTMENT', "''", 'love-wise', 'laugh-wise', 'otherwise-wise', '!']
# review 102: ['Being', 'adventures', 'young', 'man', '...', 'could', "n't", 'resist', 'pretty', 'girls', '...', 'bit', 'old', 'ultra-violence', '...', 'went', 'jail', 're-conditioned', '...', 'came', 'different', 'young', 'man', '...']
# review 103: ['IT', "'S", 'LOVE', 'AND', 'MURDER', 'AT', 'FIRST', 'SIGHT', '!', 'print', 'ad', '-', 'Lubbock', 'Morning', 'Avalanche', '-', 'Lindsey', 'Theatre', '-', 'Lubbock', 'Texas', '-', 'September', '1', '1944', '-', 'caps']
# review 104: ['An', 'Epic', 'Story', 'Vietnam', 'War', 'Australia', 'Theatrical']
# review 105: ['Feel', 'need', '...', 'The', 'need', 'speed']
# review 106: ['He', 'Tony', 'Montana', 'The', 'world', 'remember', 'another', 'name', '...', 'SCARFACE']
# review 107: ['An', 'American', 'Musical']
# review 108: ['The', 'search', 'began', 'opening', 'mother', "'s"]
# review 109: ['The', 'beloved', 'widely', 'read', 'Pulitzer', 'Prize', 'Winner', 'comes', 'vividly', 'alive', 'screen', '!']
# review 110: ['An', 'L.A.', 'Redemption']
# review 111: ['Recapture', '``', 'STING', 'Experience', "''", 'REMEMBER', 'HOW', 'GOOD', 'THE', 'FEEL', 'WAS', 'THE', 'FIRST', 'TIME', 're-release']
# review 112: ['Fly', 'Up', 'Venezuela']
# review 113: ['Ugly', 'truth', 'sweet', 'lies']
# review 114: ['Fritz', 'Lang', "'s", '1927', 'Masterpiece', 'Now', 'With', '25', 'Minutes', 'Lost', 'Footage', '2010', 're-release']
# review 115: ['On', 'every', 'street', 'every', 'city', 'country', "'s", 'nobody', 'dreams', 'somebody']
# review 116: ['Off', 'record', 'QT', 'hush-hush', '...']
# review 117: ['It', 'blow', 'back', 'wall', 'theater', '!']
# review 118: ['Stealin', "'", 'Stones', 'Breakin', "'", 'Bones']
# review 119: ['He', "'s", 'back', 'new', 'adventure', 'Memorial', 'Day', '1989']
# review 120: ['The', 'Prize', 'Picture', 'They', 'Want', 'Censor', '!']
# review 121: ['Every', 'Child', 'Special']
# review 122: ['Time', 'enemy']
# review 123: ['April', '1945', 'nation', 'awaits', '...']
# review 124: ['You', 'think', 'girls', 'lesser', 'boys']
# review 125: ['The', 'man', 'name', 'back']
# review 126: ['The', 'Legend', 'Begins']
# review 127: ['This', 'great', 'film', 'working', 'whole', 'year']
# review 128: ['Not', 'since', 'SCARFACE', 'much', 'action', 'Not', 'since', 'Marx', 'Brothers', 'much', 'comedy', 'Not', 'since', 'THE', 'SEVEN', 'YEAR', 'ITCH', 'much', 'Marilyn']
# review 129: ['Nothing', 'seems']
# review 130: ['It', "'s", 'women', '--', '-and', 'men', '!']
# review 131: ['Earn', 'Spend', 'Party']
# review 132: ['Inspired', 'True', 'Friendship']
# review 133: ['More', 'motion', 'picture', '...', 'It', 'overwhelming', 'experience', 'human', 'emotion', 'never', 'forget', '!']
# review 134: ['You', "n't", 'stay', 'top', 'forever']
# review 135: ['tionDramaWar']
# review 136: ['What', 'happens', 'make-believe', 'believes', "'s", 'real']
# review 137: ['All', 'world', "'s", 'stage', '...']
# review 138: ['There', 'Will', 'Be', 'Greed', 'There', 'Will', 'Be', 'Vengeance']
# review 139: ['It', "'s", 'hell', 'thing', 'killing', 'man']
# review 140: ['``', 'I', 'see', 'dead', 'people', "''"]
# review 141: ['Someone', 'missing']
# review 142: ['The', 'Only', 'Thing', 'Greater', 'Than', 'Power', 'Mind', 'Courage', 'Heart']
# review 143: ['Life', 'finds', 'way']
# review 144: ['Better', 'men', 'dead', 'Think', '!']
# review 145: ['Storming', 'New', 'High', 'High', 'Adventure', '!']
# review 146: ['You', 'worse', 'see']
# review 147: ['put', 'fence', 'front', 'men', '...', "'ll", 'climb', '...']
# review 148: ['There', 'Are', 'No', 'Clean', 'Getaways']
# review 149: ['The', 'Multiverse', 'Unleashed']
# review 150: ['In', 'year', '2003', 'Uma', 'Thurman', 'kill', 'Bill']
# review 151: ['The', 'husband', 'wife', '...', 'bandit']
# review 152: ['Anytime', 'Anywhere', 'Anyone']
# review 153: ['71', '%', 'Earth', "'s", 'surface', 'covered', 'water', 'That', "'s", 'lot', 'space', 'find', 'one', 'fish']
# review 154: ['An', 'incredible', 'true', 'story', '...', 'probably', 'year', "'s", 'best', 'film']
# review 155: ['You', 'get', 'tough', 'You', 'get', 'tender', 'You', 'get', 'close', 'Maybe', 'even', 'get', 'close', 'truth']
# review 156: ['ographyDramaSport']
# review 157: ['Remember', 'remember', '5th', 'November', 'gun', 'powder', 'treason', 'plot', 'I', 'know', 'reason', 'gun', 'powder', 'treason', 'ever', 'forgot']
# review 158: ['For', 'thousands', 'remember', 'unparalleled', 'drama', 'action', 'romance', '!', 'For', 'new', 'thousands', 'wonders', 'revealed', 'first', 'time', '!', 'Breathtaking', 'spectacle', 'inspired', 'acting', 'greatest', 'cast', 'ever', 'assembled', '!', 'The', 'screen', "'s", 'exciting', 'love', 'story', '!', 'The', 'most-talked', 'picture', 'ever', 'made', '!', 'reissue']
# review 159: ['A', 'Disgrace', 'Criminals', 'Everywhere']
# review 160: ['Meet', 'little', 'voices', 'inside', 'head']
# review 161: ['Kiss', 'By', 'Kiss', '...', 'Supreme', 'Suspense', 'Unfurls', '!']
# review 162: ['Un', 'crimen', 'sin', 'castigo', 'Un', 'amor', 'puro', 'Una', 'historia', 'que', 'debe', 'morir', 'A', 'crime', 'without', 'punishment', 'A', 'pure', 'love', 'A', 'story', 'must', 'die']
# review 163: ['imationAdventureFamilyFantasy']
# review 164: ['medyCrimeDrama']
# review 165: ['The', 'towering', 'triumph', 'adventure', 'makers', '``', 'Lawrence', 'Arabia', "''"]
# review 166: ['Choose', 'life', 'Choose', 'job', 'Choose', 'starter', 'home', 'Choose', 'dental', 'insurance', 'leisure', 'wear', 'matching', 'luggage', 'Choose', 'future', 'But', 'would', 'anyone', 'want', 'thing', 'like']
# review 167: ['Every', 'moment', 'matters']
# review 168: ['Fight', 'Country']
# review 169: ['A', 'homespun', 'murder', 'story']
# review 170: []
# review 171: ['imationComedyFamilyFantasy']
# review 172: ['The', 'true', 'story', 'real', 'fake']
# review 173: ['Beyond', 'silence', 'past', 'Beyond', 'dreams', 'feeling', 'Beyond', 'hope', 'memory', 'Beyond', 'journey', 'love']
# review 174: ['A', 'Little', 'Secret', '...', 'Their', 'Biggest', 'Adventure', '!']
# review 175: ['A', 'Futuristic', 'Vision', 'Perfected', '2007', 'Final', 'Cut']
# review 176: ['``', 'The', 'Picture', 'I', 'Want', 'Be', 'Remembered', "''", '-Charlie', 'Chaplin', 'Print', 'Ad-', 'Calgary', 'Daily', 'Herald', 'Calgary', 'Alta', '30', 'December', '1925']
# review 177: ['Jump', 'live', 'Eurorail', 'journey', 'never', 'forget', '!']
# review 178: ['The', 'extraordinary', 'true', 'story', 'Solomon', 'Northup']
# review 179: ['Discover', 'friendship', 'launched', 'legend']
# review 180: ['It', 'All', 'Ends', 'Here']
# review 181: ['The', 'Man', 'Lived', 'Jungle', 'Law', 'Docks', '!']
# review 182: ['A', 'Tale', 'Christ']
# review 183: ['You', "n't", 'know', "'ve", 'got', "'til", "'s", '...']
# review 184: ['ventureComedyCrime']
# review 185: ['``', 'We', 'stuff', 'dreams', 'made', 'little', 'life', 'rounded', 'sleep', "''", 'Shakespeare', '-', 'The', 'Tempest']
# review 186: ['Buster', 'drives', '``', 'The', 'General', "''", 'trainload', 'laughter', 'Trade', 'paper', 'ad']
# review 187: ['Carol', 'Reed', "'s", 'Classic', 'Thriller']
# review 188: ['Falsely', 'accused', 'Wrongly', 'imprisoned', 'He', 'fought', 'justice', 'clear', 'father', "'s", 'name']
# review 189: ['One', 'important', 'powerful', 'films', 'time', '!']
# review 190: ['At', 'long', 'last', 'Redmond', 'Barry', 'became', 'gentleman', '--', 'tragedy']
# review 191: ['Based', 'incredible', 'true', 'story']
# review 192: ['The', 'complete', 'restored', 'version', '1953', 'French', 'classic', 'reissue']
# review 193: ['1986', 'small', 'town', '...', 'two', 'detectives', 'everything', 'new']
# review 194: ['every', 'inch', 'footage', 'holds', 'laugh', '!']
# review 195: ['We', 'lose', 'control']
# review 196: ['OUR', 'OPERATOR', 'SAYS', '..', "''", 'IT', "'S", 'GOING', 'TO', 'BE', 'A', 'PLEASURE', 'TO', 'RUN', '``', 'MR.', 'SMITH', 'GOES', 'TO', 'WASHINGTON', "''", '5', 'DAYS', 'STARTING', 'SUNDAY', 'NOV.7', 'print', 'ad', '-', 'Lubbock', 'Morning', 'Avalanche', '-', 'Cactus', 'Theatre', '-', 'Lubbock', 'Texas', '-', 'November', '2', '1938', '-', 'caps']
# review 197: ['WHAT', 'A', 'LOVELY', 'DAY', 'caps', 'One', 'Sheet']
# review 198: ['A', 'film', 'visual', 'scope', 'imaginative', 'concept', 'powerful', 'content', 'written', 'directed', 'Ingmar', 'Bergman', 'twice', 'honored', 'Interational', 'Jury', 'Cannes', 'Film', 'Festival', '1956,1957']
# review 199: ['Two', 'unlikely', 'people', 'Two', 'different', 'worlds', 'come', 'together', 'story', 'unusual', 'friendship']
# review 200: ['One', 'adventure', 'change', 'two', 'worlds']
# review 201: ['Love', 'knows', 'boundaries']
# review 202: ['Monsters', 'Inc.', 'We', 'Scare', 'Because', 'We', 'Care']
# review 203: ['Amity', 'Island', 'everything', 'Clear', 'skies', 'Gentle', 'surf', 'Warm', 'water', 'People', 'flocked', 'every', 'summer', 'It', 'perfect', 'feeding', 'ground']
# review 204: ['He', 'inspiration', 'He', 'made', 'lives', 'extraordinary']
# review 205: ['Hay', 'quienes', 'tratan', 'de', 'ganarse', 'la', 'vida', 'sin', 'mover', 'un', 'dedo', '...', 'otros', 'tienen', 'que', 'cortarlos', 'Mexico']
# review 206: ['As', 'long', 'life', 'goes', 'relationships', 'parents', 'children', 'bring', 'boundless', 'joy', 'endless', 'grief']
# review 207: ['JOAN', 'ARC', 'PICTURES', 'Inc.', 'presents']
# review 208: ['When', 'country', 'descended', 'madness', 'world', 'turned', 'back', 'one', 'man', 'make', 'choice']
# review 209: ['They', 'took', 'American', 'dream', 'ride']
# review 210: ['You', 'ringside', 'seat', 'bloodiest', 'bicentennial', 'history', '!']
# review 211: ['The', 'first', 'casualty', 'war', 'innocence']
# review 212: ['Dinner', 'served', '...', 'Summer', '2007']
# review 213: ['Break', 'story', 'Break', 'silence']
# review 214: ['La', 'sua', 'missione', 'e', 'una', 'sola', 'distruggere', 'uccidere', '...', 'His', 'one', 'mission', 'destroy', 'kill', '...', 'Italian', 'DVD']
# review 215: ['His', 'time', 'come']
# review 216: ['For', "'s", 'last', 'real', 'taste', 'innocence', 'first', 'real', 'taste', 'life', 'But', 'everyone', "'s", 'time', 'memories', 'made']
# review 217: ['Everyone', "'s", 'driven', 'something']
# review 218: ['``', 'NETWORK', "''", '...', 'humanoids', 'love', 'story', 'trials', 'tribulations', 'savior', 'television', 'attempted', 'suicides', 'assassination', '--', "'s", 'ALL', 'coming', 'along', 'galaxy', 'stars', 'know', 'love', '!']
# review 219: ['Into', 'heart', 'Into', 'soul']
# review 220: ['What', 'second', 'chance', 'one', 'got', 'away']
# review 221: ['Mighty', 'Miracle', 'Show', 'Of', '1000', 'Delights', '!']
# review 222: ['The', 'Saga', 'Indian', 'Family']
# review 223: ['What', 'would', 'stuck', 'day', '...', 'Anything', 'want', 'everything', 'heart', 'desires']
# review 224: ['THE', 'SCREEN', "'S", 'GREATEST', 'LOVE', 'STORY', 'IS', 'THE', 'BEST', 'FILM', 'THIS', 'YEAR', 'FROM', 'HOLLYWOOD', '!']
# review 225: ['The', 'movie', "'ve", 'waiting', '...', 'without', 'wait']
# review 226: ['Save', 'The', 'Day']
# review 227: ['The', 'Picture', 'Everyone', 'Wants', 'To', 'See']
# review 228: ['So', 'far', 'good']
# review 229: ['The', 'French', 'Colonel', '...', 'forced', 'even', 'torture', '!', 'One', 'many', 'women', '...', 'stopped', 'nothing', 'win', '!', 'The', 'Algerian', 'Street', 'Boy', '...', 'became', 'rebel', 'hero', '!']
# review 230: ['Prepare', 'blown', 'water']
# review 231: ['A', 'true', 'story', 'faith', 'devotion', 'undying', 'love']
# review 232: ['The', 'thousands', 'read', 'book', 'know', 'WE', 'WILL', 'NOT', 'SELL', 'ANY', 'CHILDREN', 'TICKETS', 'see', 'picture', '!']
# review 233: ['imeDramaMystery']
# review 234: ['Give', 'room', 'dad', 'place', 'go', '...']
# review 235: ['Love', 'Betrayal', 'Death']
# review 236: ['THE', 'MIGHTY', 'NOVEL', 'LEAPS', 'TO', 'TURBULENT', 'LIFE', 'ON', 'THE', 'SCREEN', '!', 'Print', 'Ad-', 'Syracuse', 'Herald-American', 'Syracuse', 'NY', '24', 'March', '1940']
# review 237: ['``', 'What', "'ve", 'got', 'failure', 'communicate', "''"]
# review 238: ['Never', 'expect', 'get', 'controversial', 'relationship', '...']
# review 239: ['From', 'Vanguard', 'New', 'Film-Makers', 'Comes', 'Extraordinary', 'Motion', 'Picture']
# review 240: ['RADIANCE', 'THAT', 'FLOODS', 'THE', 'SCREEN', '...', 'AND', 'WARMS', 'THE', 'HEART', '!']
# review 241: ['Two', 'great', 'lovers', 'screen', 'grandest', 'romantic', 'comedies', '!']
# review 242: ['A', 'new', 'film', 'Ingmar', 'Bergman']
# review 243: ['A', 'motion', 'picture', 'destined', 'offend', 'nearly', 'two', 'thirds', 'civilized', 'world', 'And', 'severely', 'annoy', 'third']
# review 244: ['Some', 'secrets', 'huge', 'hide']
# review 245: ['Change', 'begins', 'whisper']
# review 246: ['There', 'man', 'beast', 'nature', "'s", 'mercy', 'There', 'awe', 'love', 'reverence', 'And', 'man', 'called', '...']
# review 247: ['Wish', 'granted', '!', 'DVD', 're-release']
# review 248: ['His', 'Triumph', 'Changed', 'The', 'World', 'Forever']
# review 249: ['Inside', 'everyone', 'frontier', 'waiting', 'discovered']

# %% [markdown]
# CASE FOLDING

# %%
def case_folding(tokenized_reviews):
    _function = lambda review: [word.lower() for word in review]
    return list(map(_function, tokenized_reviews))

# %%
nostopw_casefolded_corpus = case_folding(nostopword_corpus)

# %%
for i in range(250):
    print(f"Text {i}: {nostopw_casefolded_corpus[i]}")
# Out:
# Text 0: ['fear', 'hold', 'prisoner', 'hope', 'set', 'free']
# Text 1: ['an', 'offer', 'ca', "n't", 'refuse']
# Text 2: ['why', 'so', 'serious']
# Text 3: ['all', 'power', 'earth', 'ca', "n't", 'change', 'destiny']
# Text 4: ['life', 'is', 'in', 'their', 'hands', '--', 'death', 'is', 'on', 'their', 'minds', '!']
# Text 5: ['whoever', 'saves', 'one', 'life', 'saves', 'world', 'entire']
# Text 6: ['the', 'eye', 'enemy', 'moving']
# Text 7: ['girls', 'like', "n't", 'make', 'invitations', 'like', 'anyone', '!']
# Text 8: ['the', 'legend', 'comes', 'life']
# Text 9: ['they', 'formed', 'alliance', 'hate', 'steal', 'fortune', 'dead', 'man', "'s", 'gold']
# Text 10: ['the', 'story', 'lifetime']
# Text 11: ['how', 'much', 'know', "'ve", 'never', 'fight']
# Text 12: ['a', 'new', 'power', 'is', 'rising']
# Text 13: ['your', 'mind', 'scene', 'crime']
# Text 14: ['the', 'adventure', 'continues', '...']
# Text 15: ['free', 'mind']
# Text 16: ['``', 'as', 'far', 'back', 'i', 'remember', 'i', "'ve", 'always', 'wanted', 'gangster', "''", '--', 'henry', 'hill', 'brooklyn', 'n.y.', '1955']
# Text 17: ['if', "'s", 'crazy', 'make']
# Text 18: ['long', 'way', 'hard', 'hell', 'leads', 'light']
# Text 19: ['will', 'take', 'its', 'place', 'with', 'seven', 'greatest', 'films', 'all', 'time', '!']
# Text 20: ['frank', 'capra', "'s", '...', "''", 'it', "'s", 'wonderful', 'life', "''"]
# Text 21: ['dr.', 'hannibal', 'lecter', 'brilliant', 'cunning', 'psychotic', 'in', 'mind', 'lies', 'clue', 'ruthless', 'killer', '-', 'clarice', 'starling', 'fbi', 'brilliant', 'vulnerable', 'alone', 'she', 'must', 'trust', 'stop', 'killer']
# Text 22: ['if', 'run', 'beast', 'get', 'if', 'stay', 'beast', 'eat']
# Text 125: ['the', 'man', 'name', 'back']
# Text 126: ['the', 'legend', 'begins']
# Text 127: ['this', 'great', 'film', 'working', 'whole', 'year']
# Text 128: ['not', 'since', 'scarface', 'much', 'action', 'not', 'since', 'marx', 'brothers', 'much', 'comedy', 'not', 'since', 'the', 'seven', 'year', 'itch', 'much', 'marilyn']
# Text 129: ['nothing', 'seems']
# Text 130: ['it', "'s", 'women', '--', '-and', 'men', '!']
# Text 131: ['earn', 'spend', 'party']
# Text 132: ['inspired', 'true', 'friendship']
# Text 133: ['more', 'motion', 'picture', '...', 'it', 'overwhelming', 'experience', 'human', 'emotion', 'never', 'forget', '!']
# Text 134: ['you', "n't", 'stay', 'top', 'forever']
# Text 135: ['tiondramawar']
# Text 136: ['what', 'happens', 'make-believe', 'believes', "'s", 'real']
# Text 137: ['all', 'world', "'s", 'stage', '...']
# Text 138: ['there', 'will', 'be', 'greed', 'there', 'will', 'be', 'vengeance']
# Text 139: ['it', "'s", 'hell', 'thing', 'killing', 'man']
# Text 140: ['``', 'i', 'see', 'dead', 'people', "''"]
# Text 141: ['someone', 'missing']
# Text 142: ['the', 'only', 'thing', 'greater', 'than', 'power', 'mind', 'courage', 'heart']
# Text 143: ['life', 'finds', 'way']
# Text 144: ['better', 'men', 'dead', 'think', '!']
# Text 145: ['storming', 'new', 'high', 'high', 'adventure', '!']
# Text 146: ['you', 'worse', 'see']
# Text 147: ['put', 'fence', 'front', 'men', '...', "'ll", 'climb', '...']
# Text 148: ['there', 'are', 'no', 'clean', 'getaways']
# Text 149: ['the', 'multiverse', 'unleashed']
# Text 150: ['in', 'year', '2003', 'uma', 'thurman', 'kill', 'bill']
# Text 151: ['the', 'husband', 'wife', '...', 'bandit']
# Text 152: ['anytime', 'anywhere', 'anyone']
# Text 153: ['71', '%', 'earth', "'s", 'surface', 'covered', 'water', 'that', "'s", 'lot', 'space', 'find', 'one', 'fish']
# Text 154: ['an', 'incredible', 'true', 'story', '...', 'probably', 'year', "'s", 'best', 'film']
# Text 155: ['you', 'get', 'tough', 'you', 'get', 'tender', 'you', 'get', 'close', 'maybe', 'even', 'get', 'close', 'truth']
# Text 156: ['ographydramasport']
# Text 157: ['remember', 'remember', '5th', 'november', 'gun', 'powder', 'treason', 'plot', 'i', 'know', 'reason', 'gun', 'powder', 'treason', 'ever', 'forgot']
# Text 158: ['for', 'thousands', 'remember', 'unparalleled', 'drama', 'action', 'romance', '!', 'for', 'new', 'thousands', 'wonders', 'revealed', 'first', 'time', '!', 'breathtaking', 'spectacle', 'inspired', 'acting', 'greatest', 'cast', 'ever', 'assembled', '!', 'the', 'screen', "'s", 'exciting', 'love', 'story', '!', 'the', 'most-talked', 'picture', 'ever', 'made', '!', 'reissue']
# Text 159: ['a', 'disgrace', 'criminals', 'everywhere']
# Text 160: ['meet', 'little', 'voices', 'inside', 'head']
# Text 161: ['kiss', 'by', 'kiss', '...', 'supreme', 'suspense', 'unfurls', '!']
# Text 162: ['un', 'crimen', 'sin', 'castigo', 'un', 'amor', 'puro', 'una', 'historia', 'que', 'debe', 'morir', 'a', 'crime', 'without', 'punishment', 'a', 'pure', 'love', 'a', 'story', 'must', 'die']
# Text 163: ['imationadventurefamilyfantasy']
# Text 164: ['medycrimedrama']
# Text 165: ['the', 'towering', 'triumph', 'adventure', 'makers', '``', 'lawrence', 'arabia', "''"]
# Text 166: ['choose', 'life', 'choose', 'job', 'choose', 'starter', 'home', 'choose', 'dental', 'insurance', 'leisure', 'wear', 'matching', 'luggage', 'choose', 'future', 'but', 'would', 'anyone', 'want', 'thing', 'like']
# Text 167: ['every', 'moment', 'matters']
# Text 168: ['fight', 'country']
# Text 169: ['a', 'homespun', 'murder', 'story']
# Text 170: []
# Text 171: ['imationcomedyfamilyfantasy']
# Text 172: ['the', 'true', 'story', 'real', 'fake']
# Text 173: ['beyond', 'silence', 'past', 'beyond', 'dreams', 'feeling', 'beyond', 'hope', 'memory', 'beyond', 'journey', 'love']
# Text 174: ['a', 'little', 'secret', '...', 'their', 'biggest', 'adventure', '!']
# Text 175: ['a', 'futuristic', 'vision', 'perfected', '2007', 'final', 'cut']
# Text 176: ['``', 'the', 'picture', 'i', 'want', 'be', 'remembered', "''", '-charlie', 'chaplin', 'print', 'ad-', 'calgary', 'daily', 'herald', 'calgary', 'alta', '30', 'december', '1925']
# Text 177: ['jump', 'live', 'eurorail', 'journey', 'never', 'forget', '!']
# Text 178: ['the', 'extraordinary', 'true', 'story', 'solomon', 'northup']
# Text 179: ['discover', 'friendship', 'launched', 'legend']
# Text 180: ['it', 'all', 'ends', 'here']
# Text 181: ['the', 'man', 'lived', 'jungle', 'law', 'docks', '!']
# Text 182: ['a', 'tale', 'christ']
# Text 183: ['you', "n't", 'know', "'ve", 'got', "'til", "'s", '...']
# Text 184: ['venturecomedycrime']
# Text 185: ['``', 'we', 'stuff', 'dreams', 'made', 'little', 'life', 'rounded', 'sleep', "''", 'shakespeare', '-', 'the', 'tempest']
# Text 186: ['buster', 'drives', '``', 'the', 'general', "''", 'trainload', 'laughter', 'trade', 'paper', 'ad']
# Text 187: ['carol', 'reed', "'s", 'classic', 'thriller']
# Text 188: ['falsely', 'accused', 'wrongly', 'imprisoned', 'he', 'fought', 'justice', 'clear', 'father', "'s", 'name']
# Text 189: ['one', 'important', 'powerful', 'films', 'time', '!']
# Text 190: ['at', 'long', 'last', 'redmond', 'barry', 'became', 'gentleman', '--', 'tragedy']
# Text 191: ['based', 'incredible', 'true', 'story']
# Text 192: ['the', 'complete', 'restored', 'version', '1953', 'french', 'classic', 'reissue']
# Text 193: ['1986', 'small', 'town', '...', 'two', 'detectives', 'everything', 'new']
# Text 194: ['every', 'inch', 'footage', 'holds', 'laugh', '!']
# Text 195: ['we', 'lose', 'control']
# Text 196: ['our', 'operator', 'says', '..', "''", 'it', "'s", 'going', 'to', 'be', 'a', 'pleasure', 'to', 'run', '``', 'mr.', 'smith', 'goes', 'to', 'washington', "''", '5', 'days', 'starting', 'sunday', 'nov.7', 'print', 'ad', '-', 'lubbock', 'morning', 'avalanche', '-', 'cactus', 'theatre', '-', 'lubbock', 'texas', '-', 'november', '2', '1938', '-', 'caps']
# Text 197: ['what', 'a', 'lovely', 'day', 'caps', 'one', 'sheet']
# Text 198: ['a', 'film', 'visual', 'scope', 'imaginative', 'concept', 'powerful', 'content', 'written', 'directed', 'ingmar', 'bergman', 'twice', 'honored', 'interational', 'jury', 'cannes', 'film', 'festival', '1956,1957']
# Text 199: ['two', 'unlikely', 'people', 'two', 'different', 'worlds', 'come', 'together', 'story', 'unusual', 'friendship']
# Text 200: ['one', 'adventure', 'change', 'two', 'worlds']
# Text 201: ['love', 'knows', 'boundaries']
# Text 202: ['monsters', 'inc.', 'we', 'scare', 'because', 'we', 'care']
# Text 203: ['amity', 'island', 'everything', 'clear', 'skies', 'gentle', 'surf', 'warm', 'water', 'people', 'flocked', 'every', 'summer', 'it', 'perfect', 'feeding', 'ground']
# Text 204: ['he', 'inspiration', 'he', 'made', 'lives', 'extraordinary']
# Text 205: ['hay', 'quienes', 'tratan', 'de', 'ganarse', 'la', 'vida', 'sin', 'mover', 'un', 'dedo', '...', 'otros', 'tienen', 'que', 'cortarlos', 'mexico']
# Text 206: ['as', 'long', 'life', 'goes', 'relationships', 'parents', 'children', 'bring', 'boundless', 'joy', 'endless', 'grief']
# Text 207: ['joan', 'arc', 'pictures', 'inc.', 'presents']
# Text 208: ['when', 'country', 'descended', 'madness', 'world', 'turned', 'back', 'one', 'man', 'make', 'choice']
# Text 209: ['they', 'took', 'american', 'dream', 'ride']
# Text 210: ['you', 'ringside', 'seat', 'bloodiest', 'bicentennial', 'history', '!']
# Text 211: ['the', 'first', 'casualty', 'war', 'innocence']
# Text 212: ['dinner', 'served', '...', 'summer', '2007']
# Text 213: ['break', 'story', 'break', 'silence']
# Text 214: ['la', 'sua', 'missione', 'e', 'una', 'sola', 'distruggere', 'uccidere', '...', 'his', 'one', 'mission', 'destroy', 'kill', '...', 'italian', 'dvd']
# Text 215: ['his', 'time', 'come']
# Text 216: ['for', "'s", 'last', 'real', 'taste', 'innocence', 'first', 'real', 'taste', 'life', 'but', 'everyone', "'s", 'time', 'memories', 'made']
# Text 217: ['everyone', "'s", 'driven', 'something']
# Text 218: ['``', 'network', "''", '...', 'humanoids', 'love', 'story', 'trials', 'tribulations', 'savior', 'television', 'attempted', 'suicides', 'assassination', '--', "'s", 'all', 'coming', 'along', 'galaxy', 'stars', 'know', 'love', '!']
# Text 219: ['into', 'heart', 'into', 'soul']
# Text 220: ['what', 'second', 'chance', 'one', 'got', 'away']
# Text 221: ['mighty', 'miracle', 'show', 'of', '1000', 'delights', '!']
# Text 222: ['the', 'saga', 'indian', 'family']
# Text 223: ['what', 'would', 'stuck', 'day', '...', 'anything', 'want', 'everything', 'heart', 'desires']
# Text 224: ['the', 'screen', "'s", 'greatest', 'love', 'story', 'is', 'the', 'best', 'film', 'this', 'year', 'from', 'hollywood', '!']
# Text 225: ['the', 'movie', "'ve", 'waiting', '...', 'without', 'wait']
# Text 226: ['save', 'the', 'day']
# Text 227: ['the', 'picture', 'everyone', 'wants', 'to', 'see']
# Text 228: ['so', 'far', 'good']
# Text 229: ['the', 'french', 'colonel', '...', 'forced', 'even', 'torture', '!', 'one', 'many', 'women', '...', 'stopped', 'nothing', 'win', '!', 'the', 'algerian', 'street', 'boy', '...', 'became', 'rebel', 'hero', '!']
# Text 230: ['prepare', 'blown', 'water']
# Text 231: ['a', 'true', 'story', 'faith', 'devotion', 'undying', 'love']
# Text 232: ['the', 'thousands', 'read', 'book', 'know', 'we', 'will', 'not', 'sell', 'any', 'children', 'tickets', 'see', 'picture', '!']
# Text 233: ['imedramamystery']
# Text 234: ['give', 'room', 'dad', 'place', 'go', '...']
# Text 235: ['love', 'betrayal', 'death']
# Text 236: ['the', 'mighty', 'novel', 'leaps', 'to', 'turbulent', 'life', 'on', 'the', 'screen', '!', 'print', 'ad-', 'syracuse', 'herald-american', 'syracuse', 'ny', '24', 'march', '1940']
# Text 237: ['``', 'what', "'ve", 'got', 'failure', 'communicate', "''"]
# Text 238: ['never', 'expect', 'get', 'controversial', 'relationship', '...']
# Text 239: ['from', 'vanguard', 'new', 'film-makers', 'comes', 'extraordinary', 'motion', 'picture']
# Text 240: ['radiance', 'that', 'floods', 'the', 'screen', '...', 'and', 'warms', 'the', 'heart', '!']
# Text 241: ['two', 'great', 'lovers', 'screen', 'grandest', 'romantic', 'comedies', '!']
# Text 242: ['a', 'new', 'film', 'ingmar', 'bergman']
# Text 243: ['a', 'motion', 'picture', 'destined', 'offend', 'nearly', 'two', 'thirds', 'civilized', 'world', 'and', 'severely', 'annoy', 'third']
# Text 244: ['some', 'secrets', 'huge', 'hide']
# Text 245: ['change', 'begins', 'whisper']
# Text 246: ['there', 'man', 'beast', 'nature', "'s", 'mercy', 'there', 'awe', 'love', 'reverence', 'and', 'man', 'called', '...']
# Text 247: ['wish', 'granted', '!', 'dvd', 're-release']
# Text 248: ['his', 'triumph', 'changed', 'the', 'world', 'forever']
# Text 249: ['inside', 'everyone', 'frontier', 'waiting', 'discovered']

# %% [markdown]
# LEMMATIZING WORDS

# %%
def lemmatize_words(tokenized_reviews):
    function = lambda review: [lemmatizer.lemmatize(word) for word in review]
    return list(map(function, tokenized_reviews))

# %%
nostopw_casefolded_lemmatized_corpus = lemmatize_words(nostopw_casefolded_corpus)

# %%
for i in range(250):
    print(f"Text {i}: {nostopw_casefolded_lemmatized_corpus[i]}")
# Out:
# Text 0: ['fear', 'hold', 'prisoner', 'hope', 'set', 'free']
# Text 1: ['an', 'offer', 'ca', "n't", 'refuse']
# Text 2: ['why', 'so', 'serious']
# Text 3: ['all', 'power', 'earth', 'ca', "n't", 'change', 'destiny']
# Text 4: ['life', 'is', 'in', 'their', 'hand', '--', 'death', 'is', 'on', 'their', 'mind', '!']
# Text 5: ['whoever', 'save', 'one', 'life', 'save', 'world', 'entire']
# Text 6: ['the', 'eye', 'enemy', 'moving']
# Text 7: ['girl', 'like', "n't", 'make', 'invitation', 'like', 'anyone', '!']
# Text 8: ['the', 'legend', 'come', 'life']
# Text 109: ['the', 'beloved', 'widely', 'read', 'pulitzer', 'prize', 'winner', 'come', 'vividly', 'alive', 'screen', '!']
# Text 110: ['an', 'l.a.', 'redemption']
# Text 111: ['recapture', '``', 'sting', 'experience', "''", 'remember', 'how', 'good', 'the', 'feel', 'wa', 'the', 'first', 'time', 're-release']
# Text 112: ['fly', 'up', 'venezuela']
# Text 113: ['ugly', 'truth', 'sweet', 'lie']
# Text 114: ['fritz', 'lang', "'s", '1927', 'masterpiece', 'now', 'with', '25', 'minute', 'lost', 'footage', '2010', 're-release']
# Text 115: ['on', 'every', 'street', 'every', 'city', 'country', "'s", 'nobody', 'dream', 'somebody']
# Text 116: ['off', 'record', 'qt', 'hush-hush', '...']
# Text 117: ['it', 'blow', 'back', 'wall', 'theater', '!']
# Text 118: ['stealin', "'", 'stone', 'breakin', "'", 'bone']
# Text 119: ['he', "'s", 'back', 'new', 'adventure', 'memorial', 'day', '1989']
# Text 120: ['the', 'prize', 'picture', 'they', 'want', 'censor', '!']
# Text 121: ['every', 'child', 'special']
# Text 122: ['time', 'enemy']
# Text 123: ['april', '1945', 'nation', 'awaits', '...']
# Text 124: ['you', 'think', 'girl', 'lesser', 'boy']
# Text 125: ['the', 'man', 'name', 'back']
# Text 126: ['the', 'legend', 'begin']
# Text 127: ['this', 'great', 'film', 'working', 'whole', 'year']
# Text 128: ['not', 'since', 'scarface', 'much', 'action', 'not', 'since', 'marx', 'brother', 'much', 'comedy', 'not', 'since', 'the', 'seven', 'year', 'itch', 'much', 'marilyn']
# Text 129: ['nothing', 'seems']
# Text 130: ['it', "'s", 'woman', '--', '-and', 'men', '!']
# Text 131: ['earn', 'spend', 'party']
# Text 132: ['inspired', 'true', 'friendship']
# Text 133: ['more', 'motion', 'picture', '...', 'it', 'overwhelming', 'experience', 'human', 'emotion', 'never', 'forget', '!']
# Text 134: ['you', "n't", 'stay', 'top', 'forever']
# Text 135: ['tiondramawar']
# Text 136: ['what', 'happens', 'make-believe', 'belief', "'s", 'real']
# Text 137: ['all', 'world', "'s", 'stage', '...']
# Text 138: ['there', 'will', 'be', 'greed', 'there', 'will', 'be', 'vengeance']
# Text 139: ['it', "'s", 'hell', 'thing', 'killing', 'man']
# Text 140: ['``', 'i', 'see', 'dead', 'people', "''"]
# Text 141: ['someone', 'missing']
# Text 142: ['the', 'only', 'thing', 'greater', 'than', 'power', 'mind', 'courage', 'heart']
# Text 143: ['life', 'find', 'way']
# Text 144: ['better', 'men', 'dead', 'think', '!']
# Text 145: ['storming', 'new', 'high', 'high', 'adventure', '!']
# Text 146: ['you', 'worse', 'see']
# Text 147: ['put', 'fence', 'front', 'men', '...', "'ll", 'climb', '...']
# Text 148: ['there', 'are', 'no', 'clean', 'getaway']
# Text 149: ['the', 'multiverse', 'unleashed']
# Text 150: ['in', 'year', '2003', 'uma', 'thurman', 'kill', 'bill']
# Text 151: ['the', 'husband', 'wife', '...', 'bandit']
# Text 152: ['anytime', 'anywhere', 'anyone']
# Text 153: ['71', '%', 'earth', "'s", 'surface', 'covered', 'water', 'that', "'s", 'lot', 'space', 'find', 'one', 'fish']
# Text 154: ['an', 'incredible', 'true', 'story', '...', 'probably', 'year', "'s", 'best', 'film']
# Text 155: ['you', 'get', 'tough', 'you', 'get', 'tender', 'you', 'get', 'close', 'maybe', 'even', 'get', 'close', 'truth']
# Text 156: ['ographydramasport']
# Text 157: ['remember', 'remember', '5th', 'november', 'gun', 'powder', 'treason', 'plot', 'i', 'know', 'reason', 'gun', 'powder', 'treason', 'ever', 'forgot']
# Text 158: ['for', 'thousand', 'remember', 'unparalleled', 'drama', 'action', 'romance', '!', 'for', 'new', 'thousand', 'wonder', 'revealed', 'first', 'time', '!', 'breathtaking', 'spectacle', 'inspired', 'acting', 'greatest', 'cast', 'ever', 'assembled', '!', 'the', 'screen', "'s", 'exciting', 'love', 'story', '!', 'the', 'most-talked', 'picture', 'ever', 'made', '!', 'reissue']
# Text 159: ['a', 'disgrace', 'criminal', 'everywhere']
# Text 160: ['meet', 'little', 'voice', 'inside', 'head']
# Text 161: ['kiss', 'by', 'kiss', '...', 'supreme', 'suspense', 'unfurls', '!']
# Text 162: ['un', 'crimen', 'sin', 'castigo', 'un', 'amor', 'puro', 'una', 'historia', 'que', 'debe', 'morir', 'a', 'crime', 'without', 'punishment', 'a', 'pure', 'love', 'a', 'story', 'must', 'die']
# Text 163: ['imationadventurefamilyfantasy']
# Text 164: ['medycrimedrama']
# Text 165: ['the', 'towering', 'triumph', 'adventure', 'maker', '``', 'lawrence', 'arabia', "''"]
# Text 166: ['choose', 'life', 'choose', 'job', 'choose', 'starter', 'home', 'choose', 'dental', 'insurance', 'leisure', 'wear', 'matching', 'luggage', 'choose', 'future', 'but', 'would', 'anyone', 'want', 'thing', 'like']
# Text 167: ['every', 'moment', 'matter']
# Text 168: ['fight', 'country']
# Text 169: ['a', 'homespun', 'murder', 'story']
# Text 170: []
# Text 171: ['imationcomedyfamilyfantasy']
# Text 172: ['the', 'true', 'story', 'real', 'fake']
# Text 173: ['beyond', 'silence', 'past', 'beyond', 'dream', 'feeling', 'beyond', 'hope', 'memory', 'beyond', 'journey', 'love']
# Text 174: ['a', 'little', 'secret', '...', 'their', 'biggest', 'adventure', '!']
# Text 175: ['a', 'futuristic', 'vision', 'perfected', '2007', 'final', 'cut']
# Text 176: ['``', 'the', 'picture', 'i', 'want', 'be', 'remembered', "''", '-charlie', 'chaplin', 'print', 'ad-', 'calgary', 'daily', 'herald', 'calgary', 'alta', '30', 'december', '1925']
# Text 177: ['jump', 'live', 'eurorail', 'journey', 'never', 'forget', '!']
# Text 178: ['the', 'extraordinary', 'true', 'story', 'solomon', 'northup']
# Text 179: ['discover', 'friendship', 'launched', 'legend']
# Text 180: ['it', 'all', 'end', 'here']
# Text 181: ['the', 'man', 'lived', 'jungle', 'law', 'dock', '!']
# Text 182: ['a', 'tale', 'christ']
# Text 183: ['you', "n't", 'know', "'ve", 'got', "'til", "'s", '...']
# Text 184: ['venturecomedycrime']
# Text 185: ['``', 'we', 'stuff', 'dream', 'made', 'little', 'life', 'rounded', 'sleep', "''", 'shakespeare', '-', 'the', 'tempest']
# Text 186: ['buster', 'drive', '``', 'the', 'general', "''", 'trainload', 'laughter', 'trade', 'paper', 'ad']
# Text 187: ['carol', 'reed', "'s", 'classic', 'thriller']
# Text 188: ['falsely', 'accused', 'wrongly', 'imprisoned', 'he', 'fought', 'justice', 'clear', 'father', "'s", 'name']
# Text 189: ['one', 'important', 'powerful', 'film', 'time', '!']
# Text 190: ['at', 'long', 'last', 'redmond', 'barry', 'became', 'gentleman', '--', 'tragedy']
# Text 191: ['based', 'incredible', 'true', 'story']
# Text 192: ['the', 'complete', 'restored', 'version', '1953', 'french', 'classic', 'reissue']
# Text 193: ['1986', 'small', 'town', '...', 'two', 'detective', 'everything', 'new']
# Text 194: ['every', 'inch', 'footage', 'hold', 'laugh', '!']
# Text 195: ['we', 'lose', 'control']
# Text 196: ['our', 'operator', 'say', '..', "''", 'it', "'s", 'going', 'to', 'be', 'a', 'pleasure', 'to', 'run', '``', 'mr.', 'smith', 'go', 'to', 'washington', "''", '5', 'day', 'starting', 'sunday', 'nov.7', 'print', 'ad', '-', 'lubbock', 'morning', 'avalanche', '-', 'cactus', 'theatre', '-', 'lubbock', 'texas', '-', 'november', '2', '1938', '-', 'cap']
# Text 197: ['what', 'a', 'lovely', 'day', 'cap', 'one', 'sheet']
# Text 198: ['a', 'film', 'visual', 'scope', 'imaginative', 'concept', 'powerful', 'content', 'written', 'directed', 'ingmar', 'bergman', 'twice', 'honored', 'interational', 'jury', 'cannes', 'film', 'festival', '1956,1957']
# Text 199: ['two', 'unlikely', 'people', 'two', 'different', 'world', 'come', 'together', 'story', 'unusual', 'friendship']
# Text 200: ['one', 'adventure', 'change', 'two', 'world']
# Text 201: ['love', 'know', 'boundary']
# Text 202: ['monster', 'inc.', 'we', 'scare', 'because', 'we', 'care']
# Text 203: ['amity', 'island', 'everything', 'clear', 'sky', 'gentle', 'surf', 'warm', 'water', 'people', 'flocked', 'every', 'summer', 'it', 'perfect', 'feeding', 'ground']
# Text 204: ['he', 'inspiration', 'he', 'made', 'life', 'extraordinary']
# Text 205: ['hay', 'quienes', 'tratan', 'de', 'ganarse', 'la', 'vida', 'sin', 'mover', 'un', 'dedo', '...', 'otros', 'tienen', 'que', 'cortarlos', 'mexico']
# Text 206: ['a', 'long', 'life', 'go', 'relationship', 'parent', 'child', 'bring', 'boundless', 'joy', 'endless', 'grief']
# Text 207: ['joan', 'arc', 'picture', 'inc.', 'present']
# Text 208: ['when', 'country', 'descended', 'madness', 'world', 'turned', 'back', 'one', 'man', 'make', 'choice']
# Text 209: ['they', 'took', 'american', 'dream', 'ride']
# Text 210: ['you', 'ringside', 'seat', 'bloodiest', 'bicentennial', 'history', '!']
# Text 211: ['the', 'first', 'casualty', 'war', 'innocence']
# Text 212: ['dinner', 'served', '...', 'summer', '2007']
# Text 213: ['break', 'story', 'break', 'silence']
# Text 214: ['la', 'sua', 'missione', 'e', 'una', 'sola', 'distruggere', 'uccidere', '...', 'his', 'one', 'mission', 'destroy', 'kill', '...', 'italian', 'dvd']
# Text 215: ['his', 'time', 'come']
# Text 216: ['for', "'s", 'last', 'real', 'taste', 'innocence', 'first', 'real', 'taste', 'life', 'but', 'everyone', "'s", 'time', 'memory', 'made']
# Text 217: ['everyone', "'s", 'driven', 'something']
# Text 218: ['``', 'network', "''", '...', 'humanoid', 'love', 'story', 'trial', 'tribulation', 'savior', 'television', 'attempted', 'suicide', 'assassination', '--', "'s", 'all', 'coming', 'along', 'galaxy', 'star', 'know', 'love', '!']
# Text 219: ['into', 'heart', 'into', 'soul']
# Text 220: ['what', 'second', 'chance', 'one', 'got', 'away']
# Text 221: ['mighty', 'miracle', 'show', 'of', '1000', 'delight', '!']
# Text 222: ['the', 'saga', 'indian', 'family']
# Text 223: ['what', 'would', 'stuck', 'day', '...', 'anything', 'want', 'everything', 'heart', 'desire']
# Text 224: ['the', 'screen', "'s", 'greatest', 'love', 'story', 'is', 'the', 'best', 'film', 'this', 'year', 'from', 'hollywood', '!']
# Text 225: ['the', 'movie', "'ve", 'waiting', '...', 'without', 'wait']
# Text 226: ['save', 'the', 'day']
# Text 227: ['the', 'picture', 'everyone', 'want', 'to', 'see']
# Text 228: ['so', 'far', 'good']
# Text 229: ['the', 'french', 'colonel', '...', 'forced', 'even', 'torture', '!', 'one', 'many', 'woman', '...', 'stopped', 'nothing', 'win', '!', 'the', 'algerian', 'street', 'boy', '...', 'became', 'rebel', 'hero', '!']
# Text 230: ['prepare', 'blown', 'water']
# Text 231: ['a', 'true', 'story', 'faith', 'devotion', 'undying', 'love']
# Text 232: ['the', 'thousand', 'read', 'book', 'know', 'we', 'will', 'not', 'sell', 'any', 'child', 'ticket', 'see', 'picture', '!']
# Text 233: ['imedramamystery']
# Text 234: ['give', 'room', 'dad', 'place', 'go', '...']
# Text 235: ['love', 'betrayal', 'death']
# Text 236: ['the', 'mighty', 'novel', 'leap', 'to', 'turbulent', 'life', 'on', 'the', 'screen', '!', 'print', 'ad-', 'syracuse', 'herald-american', 'syracuse', 'ny', '24', 'march', '1940']
# Text 237: ['``', 'what', "'ve", 'got', 'failure', 'communicate', "''"]
# Text 238: ['never', 'expect', 'get', 'controversial', 'relationship', '...']
# Text 239: ['from', 'vanguard', 'new', 'film-makers', 'come', 'extraordinary', 'motion', 'picture']
# Text 240: ['radiance', 'that', 'flood', 'the', 'screen', '...', 'and', 'warms', 'the', 'heart', '!']
# Text 241: ['two', 'great', 'lover', 'screen', 'grandest', 'romantic', 'comedy', '!']
# Text 242: ['a', 'new', 'film', 'ingmar', 'bergman']
# Text 243: ['a', 'motion', 'picture', 'destined', 'offend', 'nearly', 'two', 'third', 'civilized', 'world', 'and', 'severely', 'annoy', 'third']
# Text 244: ['some', 'secret', 'huge', 'hide']
# Text 245: ['change', 'begin', 'whisper']
# Text 246: ['there', 'man', 'beast', 'nature', "'s", 'mercy', 'there', 'awe', 'love', 'reverence', 'and', 'man', 'called', '...']
# Text 247: ['wish', 'granted', '!', 'dvd', 're-release']
# Text 248: ['his', 'triumph', 'changed', 'the', 'world', 'forever']
# Text 249: ['inside', 'everyone', 'frontier', 'waiting', 'discovered']

# %% [markdown]
# STEMMING

# %%
def stem_words(tokenized_reviews):
    function = lambda reviews: [stemmer.stem(word) for word in reviews]
    return list(map(function, tokenized_reviews))

# %%
nostopword_casefolded_stemming_corpus = lemmatize_words(nostopw_casefolded_lemmatized_corpus)

# %%
for i in range(250):
    print(f"review {i}: {nostopword_casefolded_stemming_corpus[i]}")
# Out:
# review 0: ['fear', 'hold', 'prisoner', 'hope', 'set', 'free']
# review 1: ['an', 'offer', 'ca', "n't", 'refuse']
# review 2: ['why', 'so', 'serious']
# review 3: ['all', 'power', 'earth', 'ca', "n't", 'change', 'destiny']
# review 4: ['life', 'is', 'in', 'their', 'hand', '--', 'death', 'is', 'on', 'their', 'mind', '!']
# review 5: ['whoever', 'save', 'one', 'life', 'save', 'world', 'entire']
# review 6: ['the', 'eye', 'enemy', 'moving']
# review 7: ['girl', 'like', "n't", 'make', 'invitation', 'like', 'anyone', '!']
# review 8: ['the', 'legend', 'come', 'life']
# review 9: ['they', 'formed', 'alliance', 'hate', 'steal', 'fortune', 'dead', 'man', "'s", 'gold']
# review 10: ['the', 'story', 'lifetime']
# review 11: ['how', 'much', 'know', "'ve", 'never', 'fight']
# review 12: ['a', 'new', 'power', 'is', 'rising']
# review 13: ['your', 'mind', 'scene', 'crime']
# review 14: ['the', 'adventure', 'continues', '...']
# review 15: ['free', 'mind']
# review 16: ['``', 'a', 'far', 'back', 'i', 'remember', 'i', "'ve", 'always', 'wanted', 'gangster', "''", '--', 'henry', 'hill', 'brooklyn', 'n.y.', '1955']
# review 17: ['if', "'s", 'crazy', 'make']
# review 18: ['long', 'way', 'hard', 'hell', 'lead', 'light']
# review 19: ['will', 'take', 'it', 'place', 'with', 'seven', 'greatest', 'film', 'all', 'time', '!']
# review 20: ['frank', 'capra', "'s", '...', "''", 'it', "'s", 'wonderful', 'life', "''"]
# review 21: ['dr.', 'hannibal', 'lecter', 'brilliant', 'cunning', 'psychotic', 'in', 'mind', 'lie', 'clue', 'ruthless', 'killer', '-', 'clarice', 'starling', 'fbi', 'brilliant', 'vulnerable', 'alone', 'she', 'must', 'trust', 'stop', 'killer']
# review 22: ['if', 'run', 'beast', 'get', 'if', 'stay', 'beast', 'eat']
# review 23: ['in', 'last', 'great', 'invasion', 'last', 'great', 'war', 'the', 'greatest', 'danger', 'eight', 'men', 'saving', '...', 'one']
# review 24: ['mankind', 'born', 'earth', 'it', 'never', 'meant', 'die']
# review 25: ['an', 'unforgettable', 'fable', 'prof', 'love', 'family', 'imagination', 'conquer', 'canadian', 'one', 'sheet']
# review 26: ['miracle', 'happen']
# review 27: ['it', "'s", 'back', '!', 'the', 'force', 'three', 'week', '1979', 'reissue', 'poster']
# review 28: ['it', "'s", 'nothing', 'personal']
# review 29: ['he', "'s", 'kid', 'ever', 'get', 'trouble', 'born', 'uk']
# review 30: ['the', 'tunnel', 'led', 'chihiro', 'mysterious', 'town']
# review 31: ['music', 'passion', 'survival', 'masterpiece']
# review 32: ['the', 'picture', 'must', 'see', 'beginning', '...', 'or', '!', '...', 'for', 'one', 'seated', 'start', '...', 'alfred', 'hitchcock', "'s", 'greatest', 'shocker', 'psycho']
# review 33: ['misplaced', 'familyhood', 'australia/new', 'zealand/singapore']
# review 34: ['if', 'want', 'job', 'done', 'right', 'hire', 'professional']
# review 35: ['see', 'first', 'time', 'ever', '3d', '2011', '3d', 're-release']
# review 36: ['father', 'murdered', 'son', 'husband', 'murdered', 'wife', 'i', 'shall', 'vengeance', 'life', 'next']
# review 37: ['his', 'father', 'taught', 'hate', 'his', 'friend', 'taught', 'rage', 'his', 'enemy', 'gave', 'hope']
# review 38: ['lie', 'betrayal', 'sacrifice', 'how', 'far', 'take']
# review 39: ['the', 'greatest', 'trick', 'devil', 'ever', 'pulled', 'convince', 'world', "n't", 'exist']
# review 40: ['a', 'friendship', 'that', 'became', 'rivalry']
# review 41: ['the', 'road', 'greatness', 'take', 'edge']
# review 42: ['where', 'love', 'cut', 'deep', 'dagger', '!']
# review 43: ['imationdramawar']
# review 44: ['the', 'world', 'ha', 'never', 'understood', 'why', 'japanese', 'prefer', 'death', 'dishonor', '!', 'this', 'samurai', 'picture', 'provides', 'the', 'answer', '!', '!']
# review 45: ['sometimes', 'reach', 'someone', 'else', "'s", 'world', 'find', "'s", 'missing']
# review 46: ['he', 'stand', 'alone', 'greatest', 'entertainer', 'modern', 'time', '!', 'no', 'one', 'earth', 'make', 'laugh', 'heartily', 'touch', 'heart', 'deeply', '...', 'whole', 'world', 'laugh', 'cry', 'thrill', 'priceless', 'genius', '!']
# review 47: ['there', 'three', 'men', 'life', 'one', 'knew', 'past', 'one', 'wanted', 'land', 'one', 'wanted', 'revenge']
# review 48: ['the', 'essential', 'hitchcock']
# review 49: ['a', 'celebration', 'youth', 'friendship', 'everlasting', 'magic', 'movie']
# review 50: ['in', 'space', 'one', 'hear', 'scream']
# review 51: ['he', 'return', '-and', 'world', 'rock', 'laughter', 'print', 'ad-daily', 'examiner', 'grafton', 'nsw', '6', 'july', '1931']
# review 52: ['the', 'horror', 'the', 'horror']
# review 53: ['some', 'memory', 'best', 'forgotten']
# review 54: ['life', 'liberty', 'pursuit', 'vengeance']
# review 55: ['indiana', 'jones', '-', 'new', 'hero', 'creator', 'jaw', 'star', 'war']
# review 56: ['after', '700', 'year', 'built', '-', "'ll", 'discover', "'s", 'meant']
# review 57: ['before', 'fall', 'berlin', 'wall', 'east', 'germany', "'s", 'secret', 'police', 'listened', 'your', 'secret']
# review 58: ['a', 'hollywood', 'story']
# review 59: ['never', 'screen', 'thrust', 'deeply', 'gut', 'war', '!']
# review 60: ['iconic', 'terror', 'no', '1', 'bestselling', 'writer']
# review 61: ['the', 'comedy', 'masterpiece', '!']
# review 62: ['an', 'entire', 'universe', 'once']
# review 63: ['the', 'electrifying', 'entertainment', 'time', '!']
# review 64: ['this', 'time', "'s"]
# review 65: ['enter', 'universe', 'one', 'wear', 'mask']
# review 66: ['...', 'look', 'closer']
# review 67: ['the', 'comedy', 'classic', 'celebrated', 'director', 'stanley', 'kubrick']
# review 68: ['the', 'legend', 'end']
# review 69: ['15', 'year', 'imprisonment', 'five', 'day', 'vengeance']
# review 70: ['once', 'upon', 'time', 'nazi', 'occupied', 'france', '...']
# review 71: ['the', 'man', '...', 'the', 'music', '...', 'the', 'madness', '...', 'the', 'murder', '...', 'the', 'motion', 'picture', '...']
# review 72: ['the', 'celebration', 'lifetime']
# review 73: ['``', 'oooh', '...', '3-d', "''", 'usa', '2009', 're-release']
# review 74: ['put', 'happy', 'face']
# review 75: ['the', 'story', 'man', 'free', 'soul', '...', 'courage', 'follow']
# review 76: ['this', 'story', '42', 'raw', 'recruit', 'caught', 'war', "n't", 'understand', 'captain', 'must', 'lead', 'struggle', 'survive']
# review 77: ['avenge', 'fallen']
# review 78: ['live']
# review 79: ['crime', 'passion', 'lust', 'power', '-', 'sergio', 'leone', "'s", 'explosive', 'saga', 'gangland', 'america']
# review 80: ['some', 'people', 'never', 'believe', 'someone', 'belief']
# review 81: ['experience', 'japan', "'s", '1', 'film', '2016', 'visionary', 'director', 'makoto', 'shinkai']
# review 82: ['do', "n't", 'stupid', 'be', 'i.d.i.o.t']
# review 83: ['singin', "'", 'swingin', "'", 'glorious', 'feelin', "'", 'technicolor', 'musical']
# review 84: ['from', 'director', 'pi']
# review 85: ['the', 'breakout', 'comedy', 'of', 'the', 'summer']
# review 86: ['142', 'screenful', 'minute', 'thrill', 'suspense', '!']
# review 87: ['``', 'why', 'suing', 'parent', "''", '``', 'for', 'giving', 'life', "''"]
# review 88: ['coming', 'may', '25', '1983', 'galaxy', 'second', 'advance', 'poster']
# review 89: ['i', 'already', 'forget', 'i', 'used', 'feel']
# review 90: ['let', 'awe', 'mystery', 'journey', 'unlike', 'any', 'other', 'begin']
# review 91: ['seven', 'total', 'stranger', 'team', 'up', 'for', 'the', 'perfect', 'crime', 'they', 'do', "n't", 'know', 'each', 'other', "'s", 'name', 'but', 'they', "'ve", 'got', 'each', 'other', "'s", 'color']
# review 92: ['the', 'cruelest', 'side', 'war']
# review 93: ['the', 'lie', 'spreading']
# review 94: ['radio', "'s", 'most', 'dynamic', 'artist', 'the', 'man', 'at', 'whose', 'voice', 'a', 'nation', 'trembled', 'now', 'screen', "'s", 'exciting', 'new', 'star', '!', 'orson', 'welles', 'picture', 'hollywood', 'said', "'d", 'never', 'make']
# review 95: ['it', 'stagger', 'the', 'sen', '!', '...', 'shock', 'imagination', '-', 'it', 'leave', 'gasping', '-', 'it', 'sensation', '3', 'continent', '!']
# review 96: ['a', 'mighty', 'motion', 'picture', 'of', 'action', 'and', 'adventure', '!']
# review 97: ['alfred', 'hitchcock', 'take', '....', 'north', 'northwest', '!']
# review 98: ['a', 'hitchcock', 'thriller', 'you', 'see', 'beginning', '!']
# review 99: ['one', 'great', 'film', 'our', 'time', '!']
# review 100: ['one', 'person', 'change', 'life', 'forever']
# review 101: ['movie-wise', 'never', 'anything', 'like', '``', 'the', 'apartment', "''", 'love-wise', 'laugh-wise', 'otherwise-wise', '!']
# review 102: ['being', 'adventure', 'young', 'man', '...', 'could', "n't", 'resist', 'pretty', 'girl', '...', 'bit', 'old', 'ultra-violence', '...', 'went', 'jail', 're-conditioned', '...', 'came', 'different', 'young', 'man', '...']
# review 103: ['it', "'s", 'love', 'and', 'murder', 'at', 'first', 'sight', '!', 'print', 'ad', '-', 'lubbock', 'morning', 'avalanche', '-', 'lindsey', 'theatre', '-', 'lubbock', 'texas', '-', 'september', '1', '1944', '-', 'cap']
# review 104: ['an', 'epic', 'story', 'vietnam', 'war', 'australia', 'theatrical']
# review 105: ['feel', 'need', '...', 'the', 'need', 'speed']
# review 106: ['he', 'tony', 'montana', 'the', 'world', 'remember', 'another', 'name', '...', 'scarface']
# review 107: ['an', 'american', 'musical']
# review 108: ['the', 'search', 'began', 'opening', 'mother', "'s"]
# review 109: ['the', 'beloved', 'widely', 'read', 'pulitzer', 'prize', 'winner', 'come', 'vividly', 'alive', 'screen', '!']
# review 110: ['an', 'l.a.', 'redemption']
# review 111: ['recapture', '``', 'sting', 'experience', "''", 'remember', 'how', 'good', 'the', 'feel', 'wa', 'the', 'first', 'time', 're-release']
# review 112: ['fly', 'up', 'venezuela']
# review 113: ['ugly', 'truth', 'sweet', 'lie']
# review 114: ['fritz', 'lang', "'s", '1927', 'masterpiece', 'now', 'with', '25', 'minute', 'lost', 'footage', '2010', 're-release']
# review 115: ['on', 'every', 'street', 'every', 'city', 'country', "'s", 'nobody', 'dream', 'somebody']
# review 116: ['off', 'record', 'qt', 'hush-hush', '...']
# review 117: ['it', 'blow', 'back', 'wall', 'theater', '!']
# review 118: ['stealin', "'", 'stone', 'breakin', "'", 'bone']
# review 119: ['he', "'s", 'back', 'new', 'adventure', 'memorial', 'day', '1989']
# review 120: ['the', 'prize', 'picture', 'they', 'want', 'censor', '!']
# review 121: ['every', 'child', 'special']
# review 122: ['time', 'enemy']
# review 123: ['april', '1945', 'nation', 'awaits', '...']
# review 124: ['you', 'think', 'girl', 'lesser', 'boy']
# review 125: ['the', 'man', 'name', 'back']
# review 126: ['the', 'legend', 'begin']
# review 127: ['this', 'great', 'film', 'working', 'whole', 'year']
# review 128: ['not', 'since', 'scarface', 'much', 'action', 'not', 'since', 'marx', 'brother', 'much', 'comedy', 'not', 'since', 'the', 'seven', 'year', 'itch', 'much', 'marilyn']
# review 129: ['nothing', 'seems']
# review 130: ['it', "'s", 'woman', '--', '-and', 'men', '!']
# review 131: ['earn', 'spend', 'party']
# review 132: ['inspired', 'true', 'friendship']
# review 133: ['more', 'motion', 'picture', '...', 'it', 'overwhelming', 'experience', 'human', 'emotion', 'never', 'forget', '!']
# review 134: ['you', "n't", 'stay', 'top', 'forever']
# review 135: ['tiondramawar']
# review 136: ['what', 'happens', 'make-believe', 'belief', "'s", 'real']
# review 137: ['all', 'world', "'s", 'stage', '...']
# review 138: ['there', 'will', 'be', 'greed', 'there', 'will', 'be', 'vengeance']
# review 139: ['it', "'s", 'hell', 'thing', 'killing', 'man']
# review 140: ['``', 'i', 'see', 'dead', 'people', "''"]
# review 141: ['someone', 'missing']
# review 142: ['the', 'only', 'thing', 'greater', 'than', 'power', 'mind', 'courage', 'heart']
# review 143: ['life', 'find', 'way']
# review 144: ['better', 'men', 'dead', 'think', '!']
# review 145: ['storming', 'new', 'high', 'high', 'adventure', '!']
# review 146: ['you', 'worse', 'see']
# review 147: ['put', 'fence', 'front', 'men', '...', "'ll", 'climb', '...']
# review 148: ['there', 'are', 'no', 'clean', 'getaway']
# review 149: ['the', 'multiverse', 'unleashed']
# review 150: ['in', 'year', '2003', 'uma', 'thurman', 'kill', 'bill']
# review 151: ['the', 'husband', 'wife', '...', 'bandit']
# review 152: ['anytime', 'anywhere', 'anyone']
# review 153: ['71', '%', 'earth', "'s", 'surface', 'covered', 'water', 'that', "'s", 'lot', 'space', 'find', 'one', 'fish']
# review 154: ['an', 'incredible', 'true', 'story', '...', 'probably', 'year', "'s", 'best', 'film']
# review 155: ['you', 'get', 'tough', 'you', 'get', 'tender', 'you', 'get', 'close', 'maybe', 'even', 'get', 'close', 'truth']
# review 156: ['ographydramasport']
# review 157: ['remember', 'remember', '5th', 'november', 'gun', 'powder', 'treason', 'plot', 'i', 'know', 'reason', 'gun', 'powder', 'treason', 'ever', 'forgot']
# review 158: ['for', 'thousand', 'remember', 'unparalleled', 'drama', 'action', 'romance', '!', 'for', 'new', 'thousand', 'wonder', 'revealed', 'first', 'time', '!', 'breathtaking', 'spectacle', 'inspired', 'acting', 'greatest', 'cast', 'ever', 'assembled', '!', 'the', 'screen', "'s", 'exciting', 'love', 'story', '!', 'the', 'most-talked', 'picture', 'ever', 'made', '!', 'reissue']
# review 159: ['a', 'disgrace', 'criminal', 'everywhere']
# review 160: ['meet', 'little', 'voice', 'inside', 'head']
# review 161: ['kiss', 'by', 'kiss', '...', 'supreme', 'suspense', 'unfurls', '!']
# review 162: ['un', 'crimen', 'sin', 'castigo', 'un', 'amor', 'puro', 'una', 'historia', 'que', 'debe', 'morir', 'a', 'crime', 'without', 'punishment', 'a', 'pure', 'love', 'a', 'story', 'must', 'die']
# review 163: ['imationadventurefamilyfantasy']
# review 164: ['medycrimedrama']
# review 165: ['the', 'towering', 'triumph', 'adventure', 'maker', '``', 'lawrence', 'arabia', "''"]
# review 166: ['choose', 'life', 'choose', 'job', 'choose', 'starter', 'home', 'choose', 'dental', 'insurance', 'leisure', 'wear', 'matching', 'luggage', 'choose', 'future', 'but', 'would', 'anyone', 'want', 'thing', 'like']
# review 167: ['every', 'moment', 'matter']
# review 168: ['fight', 'country']
# review 169: ['a', 'homespun', 'murder', 'story']
# review 170: []
# review 171: ['imationcomedyfamilyfantasy']
# review 172: ['the', 'true', 'story', 'real', 'fake']
# review 173: ['beyond', 'silence', 'past', 'beyond', 'dream', 'feeling', 'beyond', 'hope', 'memory', 'beyond', 'journey', 'love']
# review 174: ['a', 'little', 'secret', '...', 'their', 'biggest', 'adventure', '!']
# review 175: ['a', 'futuristic', 'vision', 'perfected', '2007', 'final', 'cut']
# review 176: ['``', 'the', 'picture', 'i', 'want', 'be', 'remembered', "''", '-charlie', 'chaplin', 'print', 'ad-', 'calgary', 'daily', 'herald', 'calgary', 'alta', '30', 'december', '1925']
# review 177: ['jump', 'live', 'eurorail', 'journey', 'never', 'forget', '!']
# review 178: ['the', 'extraordinary', 'true', 'story', 'solomon', 'northup']
# review 179: ['discover', 'friendship', 'launched', 'legend']
# review 180: ['it', 'all', 'end', 'here']
# review 181: ['the', 'man', 'lived', 'jungle', 'law', 'dock', '!']
# review 182: ['a', 'tale', 'christ']
# review 183: ['you', "n't", 'know', "'ve", 'got', "'til", "'s", '...']
# review 184: ['venturecomedycrime']
# review 185: ['``', 'we', 'stuff', 'dream', 'made', 'little', 'life', 'rounded', 'sleep', "''", 'shakespeare', '-', 'the', 'tempest']
# review 186: ['buster', 'drive', '``', 'the', 'general', "''", 'trainload', 'laughter', 'trade', 'paper', 'ad']
# review 187: ['carol', 'reed', "'s", 'classic', 'thriller']
# review 188: ['falsely', 'accused', 'wrongly', 'imprisoned', 'he', 'fought', 'justice', 'clear', 'father', "'s", 'name']
# review 189: ['one', 'important', 'powerful', 'film', 'time', '!']
# review 190: ['at', 'long', 'last', 'redmond', 'barry', 'became', 'gentleman', '--', 'tragedy']
# review 191: ['based', 'incredible', 'true', 'story']
# review 192: ['the', 'complete', 'restored', 'version', '1953', 'french', 'classic', 'reissue']
# review 193: ['1986', 'small', 'town', '...', 'two', 'detective', 'everything', 'new']
# review 194: ['every', 'inch', 'footage', 'hold', 'laugh', '!']
# review 195: ['we', 'lose', 'control']
# review 196: ['our', 'operator', 'say', '..', "''", 'it', "'s", 'going', 'to', 'be', 'a', 'pleasure', 'to', 'run', '``', 'mr.', 'smith', 'go', 'to', 'washington', "''", '5', 'day', 'starting', 'sunday', 'nov.7', 'print', 'ad', '-', 'lubbock', 'morning', 'avalanche', '-', 'cactus', 'theatre', '-', 'lubbock', 'texas', '-', 'november', '2', '1938', '-', 'cap']
# review 197: ['what', 'a', 'lovely', 'day', 'cap', 'one', 'sheet']
# review 198: ['a', 'film', 'visual', 'scope', 'imaginative', 'concept', 'powerful', 'content', 'written', 'directed', 'ingmar', 'bergman', 'twice', 'honored', 'interational', 'jury', 'cannes', 'film', 'festival', '1956,1957']
# review 199: ['two', 'unlikely', 'people', 'two', 'different', 'world', 'come', 'together', 'story', 'unusual', 'friendship']
# review 200: ['one', 'adventure', 'change', 'two', 'world']
# review 201: ['love', 'know', 'boundary']
# review 202: ['monster', 'inc.', 'we', 'scare', 'because', 'we', 'care']
# review 203: ['amity', 'island', 'everything', 'clear', 'sky', 'gentle', 'surf', 'warm', 'water', 'people', 'flocked', 'every', 'summer', 'it', 'perfect', 'feeding', 'ground']
# review 204: ['he', 'inspiration', 'he', 'made', 'life', 'extraordinary']
# review 205: ['hay', 'quienes', 'tratan', 'de', 'ganarse', 'la', 'vida', 'sin', 'mover', 'un', 'dedo', '...', 'otros', 'tienen', 'que', 'cortarlos', 'mexico']
# review 206: ['a', 'long', 'life', 'go', 'relationship', 'parent', 'child', 'bring', 'boundless', 'joy', 'endless', 'grief']
# review 207: ['joan', 'arc', 'picture', 'inc.', 'present']
# review 208: ['when', 'country', 'descended', 'madness', 'world', 'turned', 'back', 'one', 'man', 'make', 'choice']
# review 209: ['they', 'took', 'american', 'dream', 'ride']
# review 210: ['you', 'ringside', 'seat', 'bloodiest', 'bicentennial', 'history', '!']
# review 211: ['the', 'first', 'casualty', 'war', 'innocence']
# review 212: ['dinner', 'served', '...', 'summer', '2007']
# review 213: ['break', 'story', 'break', 'silence']
# review 214: ['la', 'sua', 'missione', 'e', 'una', 'sola', 'distruggere', 'uccidere', '...', 'his', 'one', 'mission', 'destroy', 'kill', '...', 'italian', 'dvd']
# review 215: ['his', 'time', 'come']
# review 216: ['for', "'s", 'last', 'real', 'taste', 'innocence', 'first', 'real', 'taste', 'life', 'but', 'everyone', "'s", 'time', 'memory', 'made']
# review 217: ['everyone', "'s", 'driven', 'something']
# review 218: ['``', 'network', "''", '...', 'humanoid', 'love', 'story', 'trial', 'tribulation', 'savior', 'television', 'attempted', 'suicide', 'assassination', '--', "'s", 'all', 'coming', 'along', 'galaxy', 'star', 'know', 'love', '!']
# review 219: ['into', 'heart', 'into', 'soul']
# review 220: ['what', 'second', 'chance', 'one', 'got', 'away']
# review 221: ['mighty', 'miracle', 'show', 'of', '1000', 'delight', '!']
# review 222: ['the', 'saga', 'indian', 'family']
# review 223: ['what', 'would', 'stuck', 'day', '...', 'anything', 'want', 'everything', 'heart', 'desire']
# review 224: ['the', 'screen', "'s", 'greatest', 'love', 'story', 'is', 'the', 'best', 'film', 'this', 'year', 'from', 'hollywood', '!']
# review 225: ['the', 'movie', "'ve", 'waiting', '...', 'without', 'wait']
# review 226: ['save', 'the', 'day']
# review 227: ['the', 'picture', 'everyone', 'want', 'to', 'see']
# review 228: ['so', 'far', 'good']
# review 229: ['the', 'french', 'colonel', '...', 'forced', 'even', 'torture', '!', 'one', 'many', 'woman', '...', 'stopped', 'nothing', 'win', '!', 'the', 'algerian', 'street', 'boy', '...', 'became', 'rebel', 'hero', '!']
# review 230: ['prepare', 'blown', 'water']
# review 231: ['a', 'true', 'story', 'faith', 'devotion', 'undying', 'love']
# review 232: ['the', 'thousand', 'read', 'book', 'know', 'we', 'will', 'not', 'sell', 'any', 'child', 'ticket', 'see', 'picture', '!']
# review 233: ['imedramamystery']
# review 234: ['give', 'room', 'dad', 'place', 'go', '...']
# review 235: ['love', 'betrayal', 'death']
# review 236: ['the', 'mighty', 'novel', 'leap', 'to', 'turbulent', 'life', 'on', 'the', 'screen', '!', 'print', 'ad-', 'syracuse', 'herald-american', 'syracuse', 'ny', '24', 'march', '1940']
# review 237: ['``', 'what', "'ve", 'got', 'failure', 'communicate', "''"]
# review 238: ['never', 'expect', 'get', 'controversial', 'relationship', '...']
# review 239: ['from', 'vanguard', 'new', 'film-makers', 'come', 'extraordinary', 'motion', 'picture']
# review 240: ['radiance', 'that', 'flood', 'the', 'screen', '...', 'and', 'warms', 'the', 'heart', '!']
# review 241: ['two', 'great', 'lover', 'screen', 'grandest', 'romantic', 'comedy', '!']
# review 242: ['a', 'new', 'film', 'ingmar', 'bergman']
# review 243: ['a', 'motion', 'picture', 'destined', 'offend', 'nearly', 'two', 'third', 'civilized', 'world', 'and', 'severely', 'annoy', 'third']
# review 244: ['some', 'secret', 'huge', 'hide']
# review 245: ['change', 'begin', 'whisper']
# review 246: ['there', 'man', 'beast', 'nature', "'s", 'mercy', 'there', 'awe', 'love', 'reverence', 'and', 'man', 'called', '...']
# review 247: ['wish', 'granted', '!', 'dvd', 're-release']
# review 248: ['his', 'triumph', 'changed', 'the', 'world', 'forever']
# review 249: ['inside', 'everyone', 'frontier', 'waiting', 'discovered']

# %% [markdown]
# CREATING AN INVERTED INDEX POST PROCESSING

# %%
def create_invert(tokenized_reviews):
    inverted_index = dict()
    for index in range(len(tokenized_reviews)):
        for word in tokenized_reviews[index]:
            if word not in inverted_index:
                inverted_index[word] = list()
            inverted_index[word].append(index)
    
    for key in inverted_index:
        inverted_index[key] = list(set(inverted_index[key]))
        
    return inverted_index

# %%
inverted_index = create_invert(nostopword_casefolded_stemming_corpus)

# %%
for key in list(inverted_index.keys())[:1000]:
    print(f"Word: {key}\nText Indices: {inverted_index[key]}\n")
# Out:
# Word: fear
# Text Indices: [0]
#
# Word: hold
# Text Indices: [0, 194]
#
# Word: prisoner
# Text Indices: [0]
#
# Word: hope
# Text Indices: [0, 37, 173]
#
# Word: set
# Text Indices: [0]
#
# Word: free
# Text Indices: [0, 75, 15]
#
# Word: an
# Text Indices: [1, 104, 107, 110, 25, 154, 62]
#
# Word: offer
# Text Indices: [1]
#
# Word: ca
# Text Indices: [1, 3]
#
# Word: n't
# Text Indices: [1, 3, 102, 39, 7, 134, 76, 82, 183, 91]
#
# Word: refuse
# Text Indices: [1]
#
# Word: why
# Text Indices: [2, 44, 87]
#
# Word: so
# Text Indices: [2, 228]
#
# Word: serious
# Text Indices: [2]
#
# Word: all
# Text Indices: [3, 137, 19, 180, 218]
#
# Word: power
# Text Indices: [3, 12, 142, 79]
#
# Word: earth
# Text Indices: [24, 153, 3, 46]
#
# Word: change
# Text Indices: [200, 3, 100, 245]
#
# Word: destiny
# Text Indices: [3]
#
# Word: life
# Text Indices: [4, 5, 36, 100, 8, 166, 204, 236, 206, 47, 143, 20, 54, 87, 216, 185]
#
# Word: is
# Text Indices: [224, 4, 12]
#
# Word: in
# Text Indices: [4, 50, 21, 150, 23]
#
# Word: their
# Text Indices: [4, 174]
#
# Word: hand
# Text Indices: [4]
#
# Word: --
# Text Indices: [130, 4, 16, 218, 190]
#
# Word: death
# Text Indices: [235, 4, 44]
#
# Word: on
# Text Indices: [115, 4, 236]
#
# Word: mind
# Text Indices: [4, 13, 142, 15, 21]
#
# Word: !
# Text Indices: [130, 4, 133, 7, 144, 145, 19, 27, 158, 32, 161, 42, 44, 46, 174, 177, 181, 59, 61, 189, 63, 194, 210, 86, 218, 221, 94, 95, 96, 97, 98, 99, 224, 101, 229, 103, 232, 236, 109, 240, 241, 117, 247, 120]
#
# Word: whoever
# Text Indices: [5]
#
# Word: save
# Text Indices: [226, 5]
#
# Word: one
# Text Indices: [32, 65, 153, 99, 100, 5, 197, 229, 200, 46, 47, 208, 50, 214, 23, 25, 220, 189]
#
# Word: world
# Text Indices: [5, 39, 199, 137, 106, 200, 44, 45, 46, 208, 51, 243, 248]
#
# Word: entire
# Text Indices: [5, 62]
#
# Word: the
# Text Indices: [128, 6, 8, 10, 14, 142, 149, 23, 151, 27, 30, 158, 32, 165, 39, 41, 44, 172, 48, 176, 178, 52, 181, 185, 186, 61, 63, 192, 67, 68, 71, 72, 75, 211, 85, 91, 92, 93, 94, 95, 222, 224, 225, 226, 227, 101, 229, 248, 232, 105, 106, 108, 109, 236, 111, 240, 120, 125, 126]
#
# Word: eye
# Text Indices: [6]
#
# Word: enemy
# Text Indices: [122, 37, 6]
#
# Word: moving
# Text Indices: [6]
#
# Word: girl
# Text Indices: [124, 102, 7]
#
# Word: like
# Text Indices: [101, 166, 7]
#
# Word: make
# Text Indices: [7, 46, 208, 17, 94]
#
# Word: invitation
# Text Indices: [7]
#
# Word: anyone
# Text Indices: [152, 166, 7]
#
# Word: legend
# Text Indices: [8, 179, 68, 126]
#
# Word: come
# Text Indices: [199, 8, 109, 239, 215]
#
# Word: they
# Text Indices: [120, 9, 91, 209]
#
# Word: formed
# Text Indices: [9]
#
# Word: alliance
# Text Indices: [9]
#
# Word: hate
# Text Indices: [9, 37]
#
# Word: steal
# Text Indices: [9]
#
# Word: fortune
# Text Indices: [9]
#
# Word: dead
# Text Indices: [144, 9, 140]
#
# Word: man
# Text Indices: [102, 71, 9, 75, 139, 208, 181, 246, 125, 94]
#
# Word: 's
# Text Indices: [130, 136, 9, 137, 139, 17, 20, 153, 154, 27, 28, 29, 158, 32, 45, 183, 56, 57, 187, 188, 64, 196, 79, 81, 216, 217, 218, 91, 94, 224, 103, 108, 114, 115, 246, 119]
#
# Word: gold
# Text Indices: [9]
#
# Word: story
# Text Indices: [224, 162, 154, 104, 169, 10, 75, 76, 172, 199, 218, 231, 178, 213, 58, 158, 191]
#
# Word: lifetime
# Text Indices: [72, 10]
#
# Word: how
# Text Indices: [11, 38, 111]
#
# Word: much
# Text Indices: [128, 11]
#
# Word: know
# Text Indices: [232, 201, 11, 183, 218, 91, 157]
#
# Word: 've
# Text Indices: [225, 11, 237, 16, 183, 91]
#
# Word: never
# Text Indices: [101, 133, 11, 44, 238, 80, 177, 24, 59, 94]
#
# Word: fight
# Text Indices: [168, 11]
#
# Word: a
# Text Indices: [12, 16, 159, 162, 40, 169, 174, 175, 49, 182, 58, 196, 197, 198, 206, 94, 96, 98, 231, 242, 243]
#
# Word: new
# Text Indices: [193, 12, 239, 145, 242, 55, 119, 158, 94]
#
# Word: rising
# Text Indices: [12]
#
# Word: your
# Text Indices: [57, 13]
#
# Word: scene
# Text Indices: [13]
#
# Word: crime
# Text Indices: [162, 91, 13, 79]
#
# Word: adventure
# Text Indices: [96, 165, 102, 200, 14, 174, 145, 119]
#
# Word: continues
# Text Indices: [14]
#
# Word: ...
# Text Indices: [133, 137, 14, 147, 20, 23, 151, 154, 32, 161, 46, 174, 183, 193, 66, 70, 71, 73, 75, 205, 212, 214, 218, 95, 223, 225, 229, 102, 105, 106, 234, 238, 240, 116, 246, 123]
#
# Word: ``
# Text Indices: [196, 101, 165, 73, 218, 140, 237, 111, 16, 176, 87, 185, 186]
#
# Word: far
# Text Indices: [16, 228, 38]
#
# Word: back
# Text Indices: [16, 208, 117, 119, 27, 125]
#
# Word: i
# Text Indices: [36, 140, 16, 176, 89, 157]
#
# Word: remember
# Text Indices: [106, 111, 16, 157, 158]
#
# Word: always
# Text Indices: [16]
#
# Word: wanted
# Text Indices: [16, 47]
#
# Word: gangster
# Text Indices: [16]
#
# Word: ''
# Text Indices: [196, 101, 165, 73, 218, 140, 237, 111, 16, 176, 20, 87, 185, 186]
#
# Word: henry
# Text Indices: [16]
#
# Word: hill
# Text Indices: [16]
#
# Word: brooklyn
# Text Indices: [16]
#
# Word: n.y.
# Text Indices: [16]
#
# Word: 1955
# Text Indices: [16]
#
# Word: if
# Text Indices: [17, 34, 22]
#
# Word: crazy
# Text Indices: [17]
#
# Word: long
# Text Indices: [18, 206, 190]
#
# Word: way
# Text Indices: [18, 143]
#
# Word: hard
# Text Indices: [18]
#
# Word: hell
# Text Indices: [18, 139]
#
# Word: lead
# Text Indices: [18, 76]
#
# Word: light
# Text Indices: [18]
#
# Word: will
# Text Indices: [232, 138, 19]
#
# Word: take
# Text Indices: [41, 19, 38, 97]
#
# Word: it
# Text Indices: [130, 196, 133, 103, 139, 203, 19, 20, 117, 180, 24, 27, 28, 95]
#
# Word: place
# Text Indices: [234, 19]
#
# Word: with
# Text Indices: [114, 19]
#
# Word: seven
# Text Indices: [128, 91, 19]
#
# Word: greatest
# Text Indices: [32, 224, 39, 46, 19, 23, 158]
#
# Word: film
# Text Indices: [224, 99, 198, 81, 242, 19, 154, 189, 127]
#
# Word: time
# Text Indices: [64, 35, 99, 70, 46, 111, 19, 215, 216, 122, 189, 158, 63]
#
# Word: frank
# Text Indices: [20]
#
# Word: capra
# Text Indices: [20]
#
# Word: wonderful
# Text Indices: [20]
#
# Word: dr.
# Text Indices: [21]
#
# Word: hannibal
# Text Indices: [21]
#
# Word: lecter
# Text Indices: [21]
#
# Word: brilliant
# Text Indices: [21]
#
# Word: cunning
# Text Indices: [21]
#
# Word: psychotic
# Text Indices: [21]
#
# Word: lie
# Text Indices: [113, 93, 21, 38]
#
# Word: clue
# Text Indices: [21]
#
# Word: ruthless
# Text Indices: [21]
#
# Word: killer
# Text Indices: [21]
#
# Word: -
# Text Indices: [196, 103, 79, 21, 55, 56, 185, 95]
#
# Word: clarice
# Text Indices: [21]
#
# Word: starling
# Text Indices: [21]
#
# Word: fbi
# Text Indices: [21]
#
# Word: vulnerable
# Text Indices: [21]
#
# Word: alone
# Text Indices: [21, 46]
#
# Word: she
# Text Indices: [21]
#
# Word: must
# Text Indices: [32, 162, 76, 21]
#
# Word: trust
# Text Indices: [21]
#
# Word: stop
# Text Indices: [21]
#
# Word: run
# Text Indices: [196, 22]
#
# Word: beast
# Text Indices: [22, 246]
#
# Word: get
# Text Indices: [155, 29, 22, 238]
#
# Word: stay
# Text Indices: [134, 22]
#
# Word: eat
# Text Indices: [22]
#
# Word: last
# Text Indices: [216, 190, 23]
#
# Word: great
# Text Indices: [241, 99, 127, 23]
#
# Word: invasion
# Text Indices: [23]
#
# Word: war
# Text Indices: [104, 76, 211, 23, 55, 59, 92]
#
# Word: danger
# Text Indices: [23]
#
# Word: eight
# Text Indices: [23]
#
# Word: men
# Text Indices: [130, 47, 144, 147, 23]
#
# Word: saving
# Text Indices: [23]
#
# Word: mankind
# Text Indices: [24]
#
# Word: born
# Text Indices: [24, 29]
#
# Word: meant
# Text Indices: [24, 56]
#
# Word: die
# Text Indices: [24, 162]
#
# Word: unforgettable
# Text Indices: [25]
#
# Word: fable
# Text Indices: [25]
#
# Word: prof
# Text Indices: [25]
#
# Word: love
# Text Indices: [224, 162, 103, 231, 201, 42, 235, 173, 246, 25, 218, 158]
#
# Word: family
# Text Indices: [25, 222]
#
# Word: imagination
# Text Indices: [25, 95]
#
# Word: conquer
# Text Indices: [25]
#
# Word: canadian
# Text Indices: [25]
#
# Word: sheet
# Text Indices: [25, 197]
#
# Word: miracle
# Text Indices: [26, 221]
#
# Word: happen
# Text Indices: [26]
#
# Word: force
# Text Indices: [27]
#
# Word: three
# Text Indices: [27, 47]
#
# Word: week
# Text Indices: [27]
#
# Word: 1979
# Text Indices: [27]
#
# Word: reissue
# Text Indices: [192, 27, 158]
#
# Word: poster
# Text Indices: [88, 27]
#
# Word: nothing
# Text Indices: [129, 28, 229]
#
# Word: personal
# Text Indices: [28]
#
# Word: he
# Text Indices: [106, 204, 46, 51, 119, 188, 29]
#
# Word: kid
# Text Indices: [29]
#
# Word: ever
# Text Indices: [35, 39, 157, 29, 158]
#
# Word: trouble
# Text Indices: [29]
#
# Word: uk
# Text Indices: [29]
#
# Word: tunnel
# Text Indices: [30]
#
# Word: led
# Text Indices: [30]
#
# Word: chihiro
# Text Indices: [30]
#
# Word: mysterious
# Text Indices: [30]
#
# Word: town
# Text Indices: [193, 30]
#
# Word: music
# Text Indices: [71, 31]
#
# Word: passion
# Text Indices: [79, 31]
#
# Word: survival
# Text Indices: [31]
#
# Word: masterpiece
# Text Indices: [114, 61, 31]
#
# Word: picture
# Text Indices: [32, 96, 227, 133, 71, 232, 44, 207, 176, 239, 243, 120, 158, 94]
#
# Word: see
# Text Indices: [32, 98, 35, 227, 232, 140, 146]
#
# Word: beginning
# Text Indices: [32, 98]
#
# Word: or
# Text Indices: [32]
#
# Word: for
# Text Indices: [32, 87, 216, 91, 158]
#
# Word: seated
# Text Indices: [32]
#
# Word: start
# Text Indices: [32]
#
# Word: alfred
# Text Indices: [32, 97]
#
# Word: hitchcock
# Text Indices: [32, 97, 48, 98]
#
# Word: shocker
# Text Indices: [32]
#
# Word: psycho
# Text Indices: [32]
#
# Word: misplaced
# Text Indices: [33]
#
# Word: familyhood
# Text Indices: [33]
#
# Word: australia/new
# Text Indices: [33]
#
# Word: zealand/singapore
# Text Indices: [33]
#
# Word: want
# Text Indices: [34, 227, 166, 176, 120, 223]
#
# Word: job
# Text Indices: [34, 166]
#
# Word: done
# Text Indices: [34]
#
# Word: right
# Text Indices: [34]
#
# Word: hire
# Text Indices: [34]
#
# Word: professional
# Text Indices: [34]
#
# Word: first
# Text Indices: [35, 103, 111, 211, 216, 158]
#
# Word: 3d
# Text Indices: [35]
#
# Word: 2011
# Text Indices: [35]
#
# Word: re-release
# Text Indices: [35, 73, 111, 114, 247]
#
# Word: father
# Text Indices: [188, 36, 37]
#
# Word: murdered
# Text Indices: [36]
#
# Word: son
# Text Indices: [36]
#
# Word: husband
# Text Indices: [36, 151]
#
# Word: wife
# Text Indices: [36, 151]
#
# Word: shall
# Text Indices: [36]
#
# Word: vengeance
# Text Indices: [138, 36, 69, 54]
#
# Word: next
# Text Indices: [36]
#
# Word: his
# Text Indices: [248, 37, 214, 215]
#
# Word: taught
# Text Indices: [37]
#
# Word: friend
# Text Indices: [37]
#
# Word: rage
# Text Indices: [37]
#
# Word: gave
# Text Indices: [37]
#
# Word: betrayal
# Text Indices: [235, 38]
#
# Word: sacrifice
# Text Indices: [38]
#
# Word: trick
# Text Indices: [39]
#
# Word: devil
# Text Indices: [39]
#
# Word: pulled
# Text Indices: [39]
#
# Word: convince
# Text Indices: [39]
#
# Word: exist
# Text Indices: [39]
#
# Word: friendship
# Text Indices: [132, 199, 40, 49, 179]
#
# Word: that
# Text Indices: [40, 153, 240]
#
# Word: became
# Text Indices: [40, 229, 190]
#
# Word: rivalry
# Text Indices: [40]
#
# Word: road
# Text Indices: [41]
#
# Word: greatness
# Text Indices: [41]
#
# Word: edge
# Text Indices: [41]
#
# Word: where
# Text Indices: [42]
#
# Word: cut
# Text Indices: [42, 175]
#
# Word: deep
# Text Indices: [42]
#
# Word: dagger
# Text Indices: [42]
#
# Word: imationdramawar
# Text Indices: [43]
#
# Word: ha
# Text Indices: [44]
#
# Word: understood
# Text Indices: [44]
#
# Word: japanese
# Text Indices: [44]
#
# Word: prefer
# Text Indices: [44]
#
# Word: dishonor
# Text Indices: [44]
#
# Word: this
# Text Indices: [64, 224, 44, 76, 127]
#
# Word: samurai
# Text Indices: [44]
#
# Word: provides
# Text Indices: [44]
#
# Word: answer
# Text Indices: [44]
#
# Word: sometimes
# Text Indices: [45]
#
# Word: reach
# Text Indices: [45]
#
# Word: someone
# Text Indices: [80, 45, 141]
#
# Word: else
# Text Indices: [45]
#
# Word: find
# Text Indices: [153, 45, 143]
#
# Word: missing
# Text Indices: [45, 141]
#
# Word: stand
# Text Indices: [46]
#
# Word: entertainer
# Text Indices: [46]
#
# Word: modern
# Text Indices: [46]
#
# Word: no
# Text Indices: [148, 60, 46]
#
# Word: laugh
# Text Indices: [194, 46]
#
# Word: heartily
# Text Indices: [46]
#
# Word: touch
# Text Indices: [46]
#
# Word: heart
# Text Indices: [142, 46, 240, 219, 223]
#
# Word: deeply
# Text Indices: [59, 46]
#
# Word: whole
# Text Indices: [46, 127]
#
# Word: cry
# Text Indices: [46]
#
# Word: thrill
# Text Indices: [86, 46]
#
# Word: priceless
# Text Indices: [46]
#
# Word: genius
# Text Indices: [46]
#
# Word: there
# Text Indices: [138, 148, 246, 47]
#
# Word: knew
# Text Indices: [47]
#
# Word: past
# Text Indices: [173, 47]
#
# Word: land
# Text Indices: [47]
#
# Word: revenge
# Text Indices: [47]
#
# Word: essential
# Text Indices: [48]
#
# Word: celebration
# Text Indices: [72, 49]
#
# Word: youth
# Text Indices: [49]
#
# Word: everlasting
# Text Indices: [49]
#
# Word: magic
# Text Indices: [49]
#
# Word: movie
# Text Indices: [49, 225]
#
# Word: space
# Text Indices: [153, 50]
#
# Word: hear
# Text Indices: [50]
#
# Word: scream
# Text Indices: [50]
#
# Word: return
# Text Indices: [51]
#
# Word: -and
# Text Indices: [130, 51]
#
# Word: rock
# Text Indices: [51]
#
# Word: laughter
# Text Indices: [186, 51]
#
# Word: print
# Text Indices: [196, 103, 236, 176, 51]
#
# Word: ad-daily
# Text Indices: [51]
#
# Word: examiner
# Text Indices: [51]
#
# Word: grafton
# Text Indices: [51]
#
# Word: nsw
# Text Indices: [51]
#
# Word: 6
# Text Indices: [51]
#
# Word: july
# Text Indices: [51]
#
# Word: 1931
# Text Indices: [51]
#
# Word: horror
# Text Indices: [52]
#
# Word: some
# Text Indices: [80, 244, 53]
#
# Word: memory
# Text Indices: [216, 53, 173]
#
# Word: best
# Text Indices: [224, 154, 53]
#
# Word: forgotten
# Text Indices: [53]
#
# Word: liberty
# Text Indices: [54]
#
# Word: pursuit
# Text Indices: [54]
#
# Word: indiana
# Text Indices: [55]
#
# Word: jones
# Text Indices: [55]
#
# Word: hero
# Text Indices: [229, 55]
#
# Word: creator
# Text Indices: [55]
#
# Word: jaw
# Text Indices: [55]
#
# Word: star
# Text Indices: [218, 94, 55]
#
# Word: after
# Text Indices: [56]
#
# Word: 700
# Text Indices: [56]
#
# Word: year
# Text Indices: [128, 224, 69, 150, 56, 154, 127]
#
# Word: built
# Text Indices: [56]
#
# Word: 'll
# Text Indices: [56, 147]
#
# Word: discover
# Text Indices: [56, 179]
#
# Word: before
# Text Indices: [57]
#
# Word: fall
# Text Indices: [57]
#
# Word: berlin
# Text Indices: [57]
#
# Word: wall
# Text Indices: [57, 117]
#
# Word: east
# Text Indices: [57]
#
# Word: germany
# Text Indices: [57]
#
# Word: secret
# Text Indices: [57, 244, 174]
#
# Word: police
# Text Indices: [57]
#
# Word: listened
# Text Indices: [57]
#
# Word: hollywood
# Text Indices: [224, 58, 94]
#
# Word: screen
# Text Indices: [224, 236, 109, 240, 241, 94, 59, 158]
#
# Word: thrust
# Text Indices: [59]
#
# Word: gut
# Text Indices: [59]
#
# Word: iconic
# Text Indices: [60]
#
# Word: terror
# Text Indices: [60]
#
# Word: 1
# Text Indices: [81, 60, 103]
#
# Word: bestselling
# Text Indices: [60]
#
# Word: writer
# Text Indices: [60]
#
# Word: comedy
# Text Indices: [128, 67, 241, 85, 61]
#
# Word: universe
# Text Indices: [65, 62]
#
# Word: once
# Text Indices: [70, 62]
#
# Word: electrifying
# Text Indices: [63]
#
# Word: entertainment
# Text Indices: [63]
#
# Word: enter
# Text Indices: [65]
#
# Word: wear
# Text Indices: [65, 166]
#
# Word: mask
# Text Indices: [65]
#
# Word: look
# Text Indices: [66]
#
# Word: closer
# Text Indices: [66]
#
# Word: classic
# Text Indices: [192, 67, 187]
#
# Word: celebrated
# Text Indices: [67]
#
# Word: director
# Text Indices: [81, 67, 84]
#
# Word: stanley
# Text Indices: [67]
#
# Word: kubrick
# Text Indices: [67]
#
# Word: end
# Text Indices: [180, 68]
#
# Word: 15
# Text Indices: [69]
#
# Word: imprisonment
# Text Indices: [69]
#
# Word: five
# Text Indices: [69]
#
# Word: day
# Text Indices: [226, 196, 197, 69, 119, 223]
#
# Word: upon
# Text Indices: [70]
#
# Word: nazi
# Text Indices: [70]
#
# Word: occupied
# Text Indices: [70]
#
# Word: france
# Text Indices: [70]
#
# Word: madness
# Text Indices: [208, 71]
#
# Word: murder
# Text Indices: [169, 103, 71]
#
# Word: motion
# Text Indices: [96, 133, 71, 239, 243]
#
# Word: oooh
# Text Indices: [73]
#
# Word: 3-d
# Text Indices: [73]
#
# Word: usa
# Text Indices: [73]
#
# Word: 2009
# Text Indices: [73]
#
# Word: put
# Text Indices: [74, 147]
#
# Word: happy
# Text Indices: [74]
#
# Word: face
# Text Indices: [74]
#
# Word: soul
# Text Indices: [75, 219]
#
# Word: courage
# Text Indices: [75, 142]
#
# Word: follow
# Text Indices: [75]
#
# Word: 42
# Text Indices: [76]
#
# Word: raw
# Text Indices: [76]
#
# Word: recruit
# Text Indices: [76]
#
# Word: caught
# Text Indices: [76]
#
# Word: understand
# Text Indices: [76]
#
# Word: captain
# Text Indices: [76]
#
# Word: struggle
# Text Indices: [76]
#
# Word: survive
# Text Indices: [76]
#
# Word: avenge
# Text Indices: [77]
#
# Word: fallen
# Text Indices: [77]
#
# Word: live
# Text Indices: [177, 78]
#
# Word: lust
# Text Indices: [79]
#
# Word: sergio
# Text Indices: [79]
#
# Word: leone
# Text Indices: [79]
#
# Word: explosive
# Text Indices: [79]
#
# Word: saga
# Text Indices: [222, 79]
#
# Word: gangland
# Text Indices: [79]
#
# Word: america
# Text Indices: [79]
#
# Word: people
# Text Indices: [80, 203, 140, 199]
#
# Word: believe
# Text Indices: [80]
#
# Word: belief
# Text Indices: [80, 136]
#
# Word: experience
# Text Indices: [81, 133, 111]
#
# Word: japan
# Text Indices: [81]
#
# Word: 2016
# Text Indices: [81]
#
# Word: visionary
# Text Indices: [81]
#
# Word: makoto
# Text Indices: [81]
#
# Word: shinkai
# Text Indices: [81]
#
# Word: do
# Text Indices: [82, 91]
#
# Word: stupid
# Text Indices: [82]
#
# Word: be
# Text Indices: [176, 82, 196, 138]
#
# Word: i.d.i.o.t
# Text Indices: [82]
#
# Word: singin
# Text Indices: [83]
#
# Word: '
# Text Indices: [83, 118]
#
# Word: swingin
# Text Indices: [83]
#
# Word: glorious
# Text Indices: [83]
#
# Word: feelin
# Text Indices: [83]
#
# Word: technicolor
# Text Indices: [83]
#
# Word: musical
# Text Indices: [107, 83]
#
# Word: from
# Text Indices: [224, 84, 239]
#
# Word: pi
# Text Indices: [84]
#
# Word: breakout
# Text Indices: [85]
#
# Word: of
# Text Indices: [96, 221, 85]
#
# Word: summer
# Text Indices: [203, 212, 85]
#
# Word: 142
# Text Indices: [86]
#
# Word: screenful
# Text Indices: [86]
#
# Word: minute
# Text Indices: [114, 86]
#
# Word: suspense
# Text Indices: [161, 86]
#
# Word: suing
# Text Indices: [87]
#
# Word: parent
# Text Indices: [206, 87]
#
# Word: giving
# Text Indices: [87]
#
# Word: coming
# Text Indices: [88, 218]
#
# Word: may
# Text Indices: [88]
#
# Word: 25
# Text Indices: [88, 114]
#
# Word: 1983
# Text Indices: [88]
#
# Word: galaxy
# Text Indices: [88, 218]
#
# Word: second
# Text Indices: [88, 220]
#
# Word: advance
# Text Indices: [88]
#
# Word: already
# Text Indices: [89]
#
# Word: forget
# Text Indices: [89, 177, 133]
#
# Word: used
# Text Indices: [89]
#
# Word: feel
# Text Indices: [89, 105, 111]
#
# Word: let
# Text Indices: [90]
#
# Word: awe
# Text Indices: [90, 246]
#
# Word: mystery
# Text Indices: [90]
#
# Word: journey
# Text Indices: [177, 90, 173]
#
# Word: unlike
# Text Indices: [90]
#
# Word: any
# Text Indices: [232, 90]
#
# Word: other
# Text Indices: [90, 91]
#
# Word: begin
# Text Indices: [90, 245, 126]
#
# Word: total
# Text Indices: [91]
#
# Word: stranger
# Text Indices: [91]
#
# Word: team
# Text Indices: [91]
#
# Word: up
# Text Indices: [112, 91]
#
# Word: perfect
# Text Indices: [91, 203]
#
# Word: each
# Text Indices: [91]
#
# Word: name
# Text Indices: [106, 91, 188, 125]
#
# Word: but
# Text Indices: [216, 91, 166]
#
# Word: got
# Text Indices: [91, 220, 237, 183]
#
# Word: color
# Text Indices: [91]
#
# Word: cruelest
# Text Indices: [92]
#
# Word: side
# Text Indices: [92]
#
# Word: spreading
# Text Indices: [93]
#
# Word: radio
# Text Indices: [94]
#
# Word: most
# Text Indices: [94]
#
# Word: dynamic
# Text Indices: [94]
#
# Word: artist
# Text Indices: [94]
#
# Word: at
# Text Indices: [190, 94, 103]
#
# Word: whose
# Text Indices: [94]
#
# Word: voice
# Text Indices: [160, 94]
#
# Word: nation
# Text Indices: [123, 94]
#
# Word: trembled
# Text Indices: [94]
#
# Word: now
# Text Indices: [114, 94]
#
# Word: exciting
# Text Indices: [158, 94]
#
# Word: orson
# Text Indices: [94]
#
# Word: welles
# Text Indices: [94]
#
# Word: said
# Text Indices: [94]
#
# Word: 'd
# Text Indices: [94]
#
# Word: stagger
# Text Indices: [95]
#
# Word: sen
# Text Indices: [95]
#
# Word: shock
# Text Indices: [95]
#
# Word: leave
# Text Indices: [95]
#
# Word: gasping
# Text Indices: [95]
#
# Word: sensation
# Text Indices: [95]
#
# Word: 3
# Text Indices: [95]
#
# Word: continent
# Text Indices: [95]
#
# Word: mighty
# Text Indices: [96, 236, 221]
#
# Word: action
# Text Indices: [96, 128, 158]
#
# Word: and
# Text Indices: [96, 103, 240, 243, 246]
#
# Word: ....
# Text Indices: [97]
#
# Word: north
# Text Indices: [97]
#
# Word: northwest
# Text Indices: [97]
#
# Word: thriller
# Text Indices: [98, 187]
#
# Word: you
# Text Indices: [98, 134, 146, 210, 183, 155, 124]
#
# Word: our
# Text Indices: [99, 196]
#
# Word: person
# Text Indices: [100]
#
# Word: forever
# Text Indices: [248, 100, 134]
#
# Word: movie-wise
# Text Indices: [101]
#
# Word: anything
# Text Indices: [101, 223]
#
# Word: apartment
# Text Indices: [101]
#
# Word: love-wise
# Text Indices: [101]
#
# Word: laugh-wise
# Text Indices: [101]
#
# Word: otherwise-wise
# Text Indices: [101]
#
# Word: being
# Text Indices: [102]
#
# Word: young
# Text Indices: [102]
#
# Word: could
# Text Indices: [102]
#
# Word: resist
# Text Indices: [102]
#
# Word: pretty
# Text Indices: [102]
#
# Word: bit
# Text Indices: [102]
#
# Word: old
# Text Indices: [102]
#
# Word: ultra-violence
# Text Indices: [102]
#
# Word: went
# Text Indices: [102]
#
# Word: jail
# Text Indices: [102]
#
# Word: re-conditioned
# Text Indices: [102]
#
# Word: came
# Text Indices: [102]
#
# Word: different
# Text Indices: [102, 199]
#
# Word: sight
# Text Indices: [103]
#
# Word: ad
# Text Indices: [186, 196, 103]
#
# Word: lubbock
# Text Indices: [196, 103]
#
# Word: morning
# Text Indices: [196, 103]
#
# Word: avalanche
# Text Indices: [196, 103]
#
# Word: lindsey
# Text Indices: [103]
#
# Word: theatre
# Text Indices: [196, 103]
#
# Word: texas
# Text Indices: [196, 103]
#
# Word: september
# Text Indices: [103]
#
# Word: 1944
# Text Indices: [103]
#
# Word: cap
# Text Indices: [196, 197, 103]
#
# Word: epic
# Text Indices: [104]
#
# Word: vietnam
# Text Indices: [104]
#
# Word: australia
# Text Indices: [104]
#
# Word: theatrical
# Text Indices: [104]
#
# Word: need
# Text Indices: [105]
#
# Word: speed
# Text Indices: [105]
#
# Word: tony
# Text Indices: [106]
#
# Word: montana
# Text Indices: [106]
#
# Word: another
# Text Indices: [106]
#
# Word: scarface
# Text Indices: [128, 106]
#
# Word: american
# Text Indices: [209, 107]
#
# Word: search
# Text Indices: [108]
#
# Word: began
# Text Indices: [108]
#
# Word: opening
# Text Indices: [108]
#
# Word: mother
# Text Indices: [108]
#
# Word: beloved
# Text Indices: [109]
#
# Word: widely
# Text Indices: [109]
#
# Word: read
# Text Indices: [232, 109]
#
# Word: pulitzer
# Text Indices: [109]
#
# Word: prize
# Text Indices: [120, 109]
#
# Word: winner
# Text Indices: [109]
#
# Word: vividly
# Text Indices: [109]
#
# Word: alive
# Text Indices: [109]
#
# Word: l.a.
# Text Indices: [110]
#
# Word: redemption
# Text Indices: [110]
#
# Word: recapture
# Text Indices: [111]
#
# Word: sting
# Text Indices: [111]
#
# Word: good
# Text Indices: [228, 111]
#
# Word: wa
# Text Indices: [111]
#
# Word: fly
# Text Indices: [112]
#
# Word: venezuela
# Text Indices: [112]
#
# Word: ugly
# Text Indices: [113]
#
# Word: truth
# Text Indices: [113, 155]
#
# Word: sweet
# Text Indices: [113]
#
# Word: fritz
# Text Indices: [114]
#
# Word: lang
# Text Indices: [114]
#
# Word: 1927
# Text Indices: [114]
#
# Word: lost
# Text Indices: [114]
#
# Word: footage
# Text Indices: [194, 114]
#
# Word: 2010
# Text Indices: [114]
#
# Word: every
# Text Indices: [194, 167, 203, 115, 121]
#
# Word: street
# Text Indices: [115, 229]
#
# Word: city
# Text Indices: [115]
#
# Word: country
# Text Indices: [168, 115, 208]
#
# Word: nobody
# Text Indices: [115]
#
# Word: dream
# Text Indices: [185, 115, 209, 173]
#
# Word: somebody
# Text Indices: [115]
#
# Word: off
# Text Indices: [116]
#
# Word: record
# Text Indices: [116]
#
# Word: qt
# Text Indices: [116]
#
# Word: hush-hush
# Text Indices: [116]
#
# Word: blow
# Text Indices: [117]
#
# Word: theater
# Text Indices: [117]
#
# Word: stealin
# Text Indices: [118]
#
# Word: stone
# Text Indices: [118]
#
# Word: breakin
# Text Indices: [118]
#
# Word: bone
# Text Indices: [118]
#
# Word: memorial
# Text Indices: [119]
#
# Word: 1989
# Text Indices: [119]
#
# Word: censor
# Text Indices: [120]
#
# Word: child
# Text Indices: [232, 121, 206]
#
# Word: special
# Text Indices: [121]
#
# Word: april
# Text Indices: [123]
#
# Word: 1945
# Text Indices: [123]
#
# Word: awaits
# Text Indices: [123]
#
# Word: think
# Text Indices: [144, 124]
#
# Word: lesser
# Text Indices: [124]
#
# Word: boy
# Text Indices: [124, 229]
#
# Word: working
# Text Indices: [127]
#
# Word: not
# Text Indices: [128, 232]
#
# Word: since
# Text Indices: [128]
#
# Word: marx
# Text Indices: [128]
#
# Word: brother
# Text Indices: [128]
#
# Word: itch
# Text Indices: [128]
#
# Word: marilyn
# Text Indices: [128]
#
# Word: seems
# Text Indices: [129]
#
# Word: woman
# Text Indices: [130, 229]
#
# Word: earn
# Text Indices: [131]
#
# Word: spend
# Text Indices: [131]
#
# Word: party
# Text Indices: [131]
#
# Word: inspired
# Text Indices: [132, 158]
#
# Word: true
# Text Indices: [132, 231, 172, 178, 154, 191]
#
# Word: more
# Text Indices: [133]
#
# Word: overwhelming
# Text Indices: [133]
#
# Word: human
# Text Indices: [133]
#
# Word: emotion
# Text Indices: [133]
#
# Word: top
# Text Indices: [134]
#
# Word: tiondramawar
# Text Indices: [135]
#
# Word: what
# Text Indices: [197, 136, 237, 220, 223]
#
# Word: happens
# Text Indices: [136]
#
# Word: make-believe
# Text Indices: [136]
#
# Word: real
# Text Indices: [136, 172, 216]
#
# Word: stage
# Text Indices: [137]
#
# Word: greed
# Text Indices: [138]
#
# Word: thing
# Text Indices: [139, 166, 142]
#
# Word: killing
# Text Indices: [139]
#
# Word: only
# Text Indices: [142]
#
# Word: greater
# Text Indices: [142]
#
# Word: than
# Text Indices: [142]
#
# Word: better
# Text Indices: [144]
#
# Word: storming
# Text Indices: [145]
#
# Word: high
# Text Indices: [145]
#
# Word: worse
# Text Indices: [146]
#
# Word: fence
# Text Indices: [147]
#
# Word: front
# Text Indices: [147]
#
# Word: climb
# Text Indices: [147]
#
# Word: are
# Text Indices: [148]
#
# Word: clean
# Text Indices: [148]
#
# Word: getaway
# Text Indices: [148]
#
# Word: multiverse
# Text Indices: [149]
#
# Word: unleashed
# Text Indices: [149]
#
# Word: 2003
# Text Indices: [150]
#
# Word: uma
# Text Indices: [150]
#
# Word: thurman
# Text Indices: [150]
#
# Word: kill
# Text Indices: [214, 150]
#
# Word: bill
# Text Indices: [150]
#
# Word: bandit
# Text Indices: [151]
#
# Word: anytime
# Text Indices: [152]
#
# Word: anywhere
# Text Indices: [152]
#
# Word: 71
# Text Indices: [153]
#
# Word: %
# Text Indices: [153]
#
# Word: surface
# Text Indices: [153]
#
# Word: covered
# Text Indices: [153]
#
# Word: water
# Text Indices: [153, 203, 230]
#
# Word: lot
# Text Indices: [153]
#
# Word: fish
# Text Indices: [153]
#
# Word: incredible
# Text Indices: [154, 191]
#
# Word: probably
# Text Indices: [154]
#
# Word: tough
# Text Indices: [155]
#
# Word: tender
# Text Indices: [155]
#
# Word: close
# Text Indices: [155]
#
# Word: maybe
# Text Indices: [155]
#
# Word: even
# Text Indices: [155, 229]
#
# Word: ographydramasport
# Text Indices: [156]
#
# Word: 5th
# Text Indices: [157]
#
# Word: november
# Text Indices: [196, 157]
#
# Word: gun
# Text Indices: [157]
#
# Word: powder
# Text Indices: [157]
#
# Word: treason
# Text Indices: [157]
#
# Word: plot
# Text Indices: [157]
#
# Word: reason
# Text Indices: [157]
#
# Word: forgot
# Text Indices: [157]
#
# Word: thousand
# Text Indices: [232, 158]
#
# Word: unparalleled
# Text Indices: [158]
#
# Word: drama
# Text Indices: [158]
#
# Word: romance
# Text Indices: [158]
#
# Word: wonder
# Text Indices: [158]
#
# Word: revealed
# Text Indices: [158]
#
# Word: breathtaking
# Text Indices: [158]
#
# Word: spectacle
# Text Indices: [158]
#
# Word: acting
# Text Indices: [158]
#
# Word: cast
# Text Indices: [158]
#
# Word: assembled
# Text Indices: [158]
#
# Word: most-talked
# Text Indices: [158]
#
# Word: made
# Text Indices: [216, 185, 204, 158]
#
# Word: disgrace
# Text Indices: [159]
#
# Word: criminal
# Text Indices: [159]
#
# Word: everywhere
# Text Indices: [159]
#
# Word: meet
# Text Indices: [160]
#
# Word: little
# Text Indices: [160, 185, 174]
#
# Word: inside
# Text Indices: [160, 249]
#
# Word: head
# Text Indices: [160]
#
# Word: kiss
# Text Indices: [161]
#
# Word: by
# Text Indices: [161]
#
# Word: supreme
# Text Indices: [161]
#
# Word: unfurls
# Text Indices: [161]
#
# Word: un
# Text Indices: [162, 205]
#
# Word: crimen
# Text Indices: [162]
#
# Word: sin
# Text Indices: [162, 205]
#
# Word: castigo
# Text Indices: [162]
#
# Word: amor
# Text Indices: [162]
#
# Word: puro
# Text Indices: [162]
#
# Word: una
# Text Indices: [162, 214]
#
# Word: historia
# Text Indices: [162]
#
# Word: que
# Text Indices: [162, 205]
#
# Word: debe
# Text Indices: [162]
#
# Word: morir
# Text Indices: [162]
#
# Word: without
# Text Indices: [225, 162]
#
# Word: punishment
# Text Indices: [162]
#
# Word: pure
# Text Indices: [162]
#
# Word: imationadventurefamilyfantasy
# Text Indices: [163]
#
# Word: medycrimedrama
# Text Indices: [164]
#
# Word: towering
# Text Indices: [165]
#
# Word: triumph
# Text Indices: [248, 165]
#
# Word: maker
# Text Indices: [165]
#
# Word: lawrence
# Text Indices: [165]
#
# Word: arabia
# Text Indices: [165]
#
# Word: choose
# Text Indices: [166]
#
# Word: starter
# Text Indices: [166]
#
# Word: home
# Text Indices: [166]
#
# Word: dental
# Text Indices: [166]
#
# Word: insurance
# Text Indices: [166]
#
# Word: leisure
# Text Indices: [166]
#
# Word: matching
# Text Indices: [166]
#
# Word: luggage
# Text Indices: [166]
#
# Word: future
# Text Indices: [166]
#
# Word: would
# Text Indices: [166, 223]
#
# Word: moment
# Text Indices: [167]
#
# Word: matter
# Text Indices: [167]
#
# Word: homespun
# Text Indices: [169]
#
# Word: imationcomedyfamilyfantasy
# Text Indices: [171]
#
# Word: fake
# Text Indices: [172]
#
# Word: beyond
# Text Indices: [173]
#
# Word: silence
# Text Indices: [213, 173]
#
# Word: feeling
# Text Indices: [173]
#
# Word: biggest
# Text Indices: [174]
#
# Word: futuristic
# Text Indices: [175]
#
# Word: vision
# Text Indices: [175]
#
# Word: perfected
# Text Indices: [175]
#
# Word: 2007
# Text Indices: [212, 175]
#
# Word: final
# Text Indices: [175]
#
# Word: remembered
# Text Indices: [176]
#
# Word: -charlie
# Text Indices: [176]
#
# Word: chaplin
# Text Indices: [176]
#
# Word: ad-
# Text Indices: [176, 236]
#
# Word: calgary
# Text Indices: [176]
#
# Word: daily
# Text Indices: [176]
#
# Word: herald
# Text Indices: [176]
#
# Word: alta
# Text Indices: [176]
#
# Word: 30
# Text Indices: [176]
#
# Word: december
# Text Indices: [176]
#
# Word: 1925
# Text Indices: [176]
#
# Word: jump
# Text Indices: [177]
#
# Word: eurorail
# Text Indices: [177]
#
# Word: extraordinary
# Text Indices: [178, 204, 239]
#
# Word: solomon
# Text Indices: [178]
#
# Word: northup
# Text Indices: [178]
#
# Word: launched
# Text Indices: [179]
#
# Word: here
# Text Indices: [180]
#
# Word: lived
# Text Indices: [181]
#
# Word: jungle
# Text Indices: [181]
#
# Word: law
# Text Indices: [181]
#
# Word: dock
# Text Indices: [181]
#
# Word: tale
# Text Indices: [182]
#
# Word: christ
# Text Indices: [182]
#
# Word: 'til
# Text Indices: [183]
#
# Word: venturecomedycrime
# Text Indices: [184]
#
# Word: we
# Text Indices: [232, 185, 202, 195]
#
# Word: stuff
# Text Indices: [185]
#
# Word: rounded
# Text Indices: [185]
#
# Word: sleep
# Text Indices: [185]
#
# Word: shakespeare
# Text Indices: [185]
#
# Word: tempest
# Text Indices: [185]
#
# Word: buster
# Text Indices: [186]
#
# Word: drive
# Text Indices: [186]
#
# Word: general
# Text Indices: [186]
#
# Word: trainload
# Text Indices: [186]
#
# Word: trade
# Text Indices: [186]
#
# Word: paper
# Text Indices: [186]
#
# Word: carol
# Text Indices: [187]
#
# Word: reed
# Text Indices: [187]
#
# Word: falsely
# Text Indices: [188]
#
# Word: accused
# Text Indices: [188]
#
# Word: wrongly
# Text Indices: [188]
#
# Word: imprisoned
# Text Indices: [188]
#
# Word: fought
# Text Indices: [188]
#
# Word: justice
# Text Indices: [188]
#
# Word: clear
# Text Indices: [203, 188]
#
# Word: important
# Text Indices: [189]
#
# Word: powerful
# Text Indices: [189, 198]
#
# Word: redmond
# Text Indices: [190]
#
# Word: barry
# Text Indices: [190]
#
# Word: gentleman
# Text Indices: [190]
#
# Word: tragedy
# Text Indices: [190]
#
# Word: based
# Text Indices: [191]
#
# Word: complete
# Text Indices: [192]
#
# Word: restored
# Text Indices: [192]
#
# Word: version
# Text Indices: [192]
#
# Word: 1953
# Text Indices: [192]
#
# Word: french
# Text Indices: [192, 229]
#
# Word: 1986
# Text Indices: [193]
#
# Word: small
# Text Indices: [193]
#
# Word: two
# Text Indices: [193, 199, 200, 241, 243]
#
# Word: detective
# Text Indices: [193]
#
# Word: everything
# Text Indices: [193, 203, 223]
#
# Word: inch
# Text Indices: [194]
#
# Word: lose
# Text Indices: [195]
#
# Word: control
# Text Indices: [195]
#
# Word: operator
# Text Indices: [196]
#
# Word: say
# Text Indices: [196]
#
# Word: ..
# Text Indices: [196]
#
# Word: going
# Text Indices: [196]
#
# Word: to
# Text Indices: [227, 196, 236]
#
# Word: pleasure
# Text Indices: [196]
#
# Word: mr.
# Text Indices: [196]
#
# Word: smith
# Text Indices: [196]
#
# Word: go
# Text Indices: [234, 196, 206]
#
# Word: washington
# Text Indices: [196]
#
# Word: 5
# Text Indices: [196]
#
# Word: starting
# Text Indices: [196]
#
# Word: sunday
# Text Indices: [196]
#
# Word: nov.7
# Text Indices: [196]
#
# Word: cactus
# Text Indices: [196]
#
# Word: 2
# Text Indices: [196]
#
# Word: 1938
# Text Indices: [196]
#
# Word: lovely
# Text Indices: [197]
#
# Word: visual
# Text Indices: [198]
#
# Word: scope
# Text Indices: [198]
#
# Word: imaginative
# Text Indices: [198]
#
# Word: concept
# Text Indices: [198]
#
# Word: content
# Text Indices: [198]
#
# Word: written
# Text Indices: [198]
#
# Word: directed
# Text Indices: [198]
#
# Word: ingmar
# Text Indices: [242, 198]
#
# Word: bergman
# Text Indices: [242, 198]
#
# Word: twice
# Text Indices: [198]
#
# Word: honored
# Text Indices: [198]
#
# Word: interational
# Text Indices: [198]
#
# Word: jury
# Text Indices: [198]
#
# Word: cannes
# Text Indices: [198]
#
# Word: festival
# Text Indices: [198]
#
# Word: 1956,1957
# Text Indices: [198]
#
# Word: unlikely
# Text Indices: [199]
#
# Word: together
# Text Indices: [199]
#
# Word: unusual
# Text Indices: [199]
#
# Word: boundary
# Text Indices: [201]
#
# Word: monster
# Text Indices: [202]
#
# Word: inc.
# Text Indices: [202, 207]
#
# Word: scare
# Text Indices: [202]
#
# Word: because
# Text Indices: [202]
#
# Word: care
# Text Indices: [202]
#
# Word: amity
# Text Indices: [203]
#
# Word: island
# Text Indices: [203]
#
# Word: sky
# Text Indices: [203]
#
# Word: gentle
# Text Indices: [203]
#
# Word: surf
# Text Indices: [203]
#
# Word: warm
# Text Indices: [203]
#
# Word: flocked
# Text Indices: [203]
#
# Word: feeding
# Text Indices: [203]
#
# Word: ground
# Text Indices: [203]
#
# Word: inspiration
# Text Indices: [204]
#
# Word: hay
# Text Indices: [205]
#
# Word: quienes
# Text Indices: [205]
#
# Word: tratan
# Text Indices: [205]
#
# Word: de
# Text Indices: [205]
#
# Word: ganarse
# Text Indices: [205]
#
# Word: la
# Text Indices: [205, 214]
#
# Word: vida
# Text Indices: [205]
#
# Word: mover
# Text Indices: [205]
#
# Word: dedo
# Text Indices: [205]
#
# Word: otros
# Text Indices: [205]
#
# Word: tienen
# Text Indices: [205]
#
# Word: cortarlos
# Text Indices: [205]
#
# Word: mexico
# Text Indices: [205]
#
# Word: relationship
# Text Indices: [206, 238]
#
# Word: bring
# Text Indices: [206]
#
# Word: boundless
# Text Indices: [206]
#
# Word: joy
# Text Indices: [206]
#
# Word: endless
# Text Indices: [206]
#
# Word: grief
# Text Indices: [206]
#
# Word: joan
# Text Indices: [207]
#
# Word: arc
# Text Indices: [207]
#
# Word: present
# Text Indices: [207]
#
# Word: when
# Text Indices: [208]
#
# Word: descended
# Text Indices: [208]
#
# Word: turned
# Text Indices: [208]
#
# Word: choice
# Text Indices: [208]
#
# Word: took
# Text Indices: [209]
#
# Word: ride
# Text Indices: [209]
#
# Word: ringside
# Text Indices: [210]
#
# Word: seat
# Text Indices: [210]
#
# Word: bloodiest
# Text Indices: [210]
#
# Word: bicentennial
# Text Indices: [210]
#
# Word: history
# Text Indices: [210]
#
# Word: casualty
# Text Indices: [211]
#
# Word: innocence
# Text Indices: [216, 211]
#
# Word: dinner
# Text Indices: [212]
#
# Word: served
# Text Indices: [212]
#
# Word: break
# Text Indices: [213]
#
# Word: sua
# Text Indices: [214]
#
# Word: missione
# Text Indices: [214]
#
# Word: e
# Text Indices: [214]
#
# Word: sola
# Text Indices: [214]
#
# Word: distruggere
# Text Indices: [214]
#
# Word: uccidere
# Text Indices: [214]
#
# Word: mission
# Text Indices: [214]
#
# Word: destroy
# Text Indices: [214]
#
# Word: italian
# Text Indices: [214]
#
# Word: dvd
# Text Indices: [214, 247]
#
# Word: taste
# Text Indices: [216]
#
# Word: everyone
# Text Indices: [216, 217, 227, 249]
#
# Word: driven
# Text Indices: [217]
#
# Word: something
# Text Indices: [217]
#
# Word: network
# Text Indices: [218]
#
# Word: humanoid
# Text Indices: [218]
#
# Word: trial
# Text Indices: [218]
#
# Word: tribulation
# Text Indices: [218]
#
# Word: savior
# Text Indices: [218]
#
# Word: television
# Text Indices: [218]
#
# Word: attempted
# Text Indices: [218]
#
# Word: suicide
# Text Indices: [218]
#
# Word: assassination
# Text Indices: [218]
#
# Word: along
# Text Indices: [218]
#
# Word: into
# Text Indices: [219]
#
# Word: chance
# Text Indices: [220]
#
# Word: away
# Text Indices: [220]
#
# Word: show
# Text Indices: [221]
#
# Word: 1000
# Text Indices: [221]
#
# Word: delight
# Text Indices: [221]
#
# Word: indian
# Text Indices: [222]
#
# Word: stuck
# Text Indices: [223]
#
# Word: desire
# Text Indices: [223]
#
# Word: waiting
# Text Indices: [225, 249]
#
# Word: wait
# Text Indices: [225]
#
# Word: colonel
# Text Indices: [229]
#
# Word: forced
# Text Indices: [229]
#
# Word: torture
# Text Indices: [229]
#
# Word: many
# Text Indices: [229]
#
# Word: stopped
# Text Indices: [229]
#
# Word: win
# Text Indices: [229]
#
# Word: algerian
# Text Indices: [229]
#
# Word: rebel
# Text Indices: [229]
#
# Word: prepare
# Text Indices: [230]
#
# Word: blown
# Text Indices: [230]
#
# Word: faith
# Text Indices: [231]
#
# Word: devotion
# Text Indices: [231]
#
# Word: undying
# Text Indices: [231]
#
# Word: book
# Text Indices: [232]
#
# Word: sell
# Text Indices: [232]
#
# Word: ticket
# Text Indices: [232]
#
# Word: imedramamystery
# Text Indices: [233]
#
# Word: give
# Text Indices: [234]
#
# Word: room
# Text Indices: [234]
#
# Word: dad
# Text Indices: [234]
#
# Word: novel
# Text Indices: [236]
#
# Word: leap
# Text Indices: [236]
#
# Word: turbulent
# Text Indices: [236]
#
# Word: syracuse
# Text Indices: [236]
#
# Word: herald-american
# Text Indices: [236]
#
# Word: ny
# Text Indices: [236]
#
# Word: 24
# Text Indices: [236]
#
# Word: march
# Text Indices: [236]
#
# Word: 1940
# Text Indices: [236]
#
# Word: failure
# Text Indices: [237]
#
# Word: communicate
# Text Indices: [237]
#
# Word: expect
# Text Indices: [238]
#
# Word: controversial
# Text Indices: [238]
#
# Word: vanguard
# Text Indices: [239]
#
# Word: film-makers
# Text Indices: [239]
#
# Word: radiance
# Text Indices: [240]
#
# Word: flood
# Text Indices: [240]
#
# Word: warms
# Text Indices: [240]
#
# Word: lover
# Text Indices: [241]
#
# Word: grandest
# Text Indices: [241]
#
# Word: romantic
# Text Indices: [241]
#
# Word: destined
# Text Indices: [243]
#
# Word: offend
# Text Indices: [243]
#
# Word: nearly
# Text Indices: [243]
#
# Word: third
# Text Indices: [243]
#
# Word: civilized
# Text Indices: [243]
#
# Word: severely
# Text Indices: [243]
#
# Word: annoy
# Text Indices: [243]
#
# Word: huge
# Text Indices: [244]
#
# Word: hide
# Text Indices: [244]
#
# Word: whisper
# Text Indices: [245]
#
# Word: nature
# Text Indices: [246]
#
# Word: mercy
# Text Indices: [246]
#
# Word: reverence
# Text Indices: [246]
#
# Word: called
# Text Indices: [246]
#
# Word: wish
# Text Indices: [247]
#
# Word: granted
# Text Indices: [247]
#
# Word: changed
# Text Indices: [248]
#
# Word: frontier
# Text Indices: [249]
#
# Word: discovered
# Text Indices: [249]

# %% [markdown]
# BOOLEAN QUERIES

# %%
def query_parsed(infix):
    
    order = {}
    order['('] = 0
    order[')'] = 0   
    order['OR'] = 1 
    order['NOT'] = 3
    order['AND'] = 2
    
    

    output = []
    stack = []

    for token in infix:
        if (token == '('):
            stack.append(token)

        elif (token == ')'):
            operator = stack.pop()
            while operator != '(':
                output.append(operator)
                operator = stack.pop()

        elif (token in order):
            if (stack):
                current_operator = stack[-1]
                while (stack and order[current_operator] > order[token]):
                    output.append(stack.pop())
                    if (stack):
                        current_operator = stack[-1]
            stack.append(token) # add token to stack
        else:
            output.append(token.lower())

    while (stack):
        output.append(stack.pop())

    return output

# %%
def boolean_query(query, inverted_index):
    query = query.strip()
    query_tokens = query.split()
    boolean_query = query_parsed(query_tokens)
        
    result_stack = list()
    for idx, token in enumerate(boolean_query):
        if token not in ["AND", "NOT", "OR"]:
            result = set(inverted_index[token])
        else:
            if token in ['AND', 'OR']:
                right_operand = result_stack.pop()
                left_operand = result_stack.pop()
                
                if token == 'AND':
                    operation = set.intersection
                else:
                    operation = set.union
                
                result = operation(left_operand, right_operand)
                
            else:
                operand = result_stack.pop()
                complement_document_ids = inverted_index[boolean_query[idx-1]]
                result = list()
                for word in inverted_index:
                    result.extend([_id for _id in inverted_index[word] if _id not in complement_document_ids])
                result = set(result)
                
        result_stack.append(result)
    
    return result_stack.pop()

# %% [markdown]
# testing with queries

# %%
doc_id = boolean_query("Why AND So AND Serious", inverted_index)
print(f"Document IDs: {doc_id}")
# Out:
# Document IDs: {2}

# %%
doc_id_or = boolean_query("Your OR mind OR scene AND crime AND Free", inverted_index)
print(f"Document IDs: {doc_id_or}")
# Out:
# Document IDs: {4, 21, 57, 13, 142, 15}

# %% [markdown]
# POSITIONAL INDEX

# %%
def positional_posting_list(tokenized_corpus):
    positional_index = dict()
    for review_id, review in enumerate(tokenized_corpus):
        for token_id, token in enumerate(review):
            if token not in positional_index:
                positional_index[token] = dict()
            if review_id not in positional_index[token]:
                positional_index[token][review_id] = list()
            positional_index[token][review_id].append(token_id)
    
    for token in positional_index:
        for review_id in positional_index[token]:
            positional_index[token][review_id] = sorted(positional_index[token][review_id])
        items = list(positional_index[token].items())
        items.sort(key=lambda x: x[0])
        for k, v in items:
            positional_index[token][k] = v
            
    return positional_index

# %%
positional_index = positional_posting_list(nostopword_casefolded_stemming_corpus)

# %%
for key in list(positional_index.keys())[:1000]:
    print(f"Word: {key}\nText & Token Indices: {positional_index[key]}\n")
# Out:
# Word: fear
# Text & Token Indices: {0: [0]}
#
# Word: hold
# Text & Token Indices: {0: [1], 194: [3]}
#
# Word: prisoner
# Text & Token Indices: {0: [2]}
#
# Word: hope
# Text & Token Indices: {0: [3], 37: [11], 173: [7]}
#
# Word: set
# Text & Token Indices: {0: [4]}
#
# Word: free
# Text & Token Indices: {0: [5], 15: [0], 75: [3]}
#
# Word: an
# Text & Token Indices: {1: [0], 25: [0], 62: [0], 104: [0], 107: [0], 110: [0], 154: [0]}
#
# Word: offer
# Text & Token Indices: {1: [1]}
#
# Word: ca
# Text & Token Indices: {1: [2], 3: [3]}
#
# Word: n't
# Text & Token Indices: {1: [3], 3: [4], 7: [2], 39: [8], 76: [7], 82: [1], 91: [11], 102: [6], 134: [1], 183: [1]}
#
# Word: refuse
# Text & Token Indices: {1: [4]}
#
# Word: why
# Text & Token Indices: {2: [0], 44: [5], 87: [1]}
#
# Word: so
# Text & Token Indices: {2: [1], 228: [0]}
#
# Word: serious
# Text & Token Indices: {2: [2]}
#
# Word: all
# Text & Token Indices: {3: [0], 19: [8], 137: [0], 180: [1], 218: [16]}
#
# Word: power
# Text & Token Indices: {3: [1], 12: [2], 79: [3], 142: [5]}
#
# Word: earth
# Text & Token Indices: {3: [2], 24: [2], 46: [10], 153: [2]}
#
# Word: change
# Text & Token Indices: {3: [5], 100: [2], 200: [2], 245: [0]}
#
# Word: destiny
# Text & Token Indices: {3: [6]}
#
# Word: life
# Text & Token Indices: {4: [0], 5: [3], 8: [3], 20: [8], 36: [9], 47: [3], 54: [0], 87: [8], 100: [3], 143: [0], 166: [1], 185: [6], 204: [4], 206: [2], 216: [9], 236: [6]}
#
# Word: is
# Text & Token Indices: {4: [1, 7], 12: [3], 224: [6]}
#
# Word: in
# Text & Token Indices: {4: [2], 21: [6], 23: [0], 50: [0], 150: [0]}
#
# Word: their
# Text & Token Indices: {4: [3, 9], 174: [4]}
#
# Word: hand
# Text & Token Indices: {4: [4]}
#
# Word: --
# Text & Token Indices: {4: [5], 16: [12], 130: [3], 190: [7], 218: [14]}
#
# Word: death
# Text & Token Indices: {4: [6], 44: [8], 235: [2]}
#
# Word: on
# Text & Token Indices: {4: [8], 115: [0], 236: [7]}
#
# Word: mind
# Text & Token Indices: {4: [10], 13: [1], 15: [1], 21: [7], 142: [6]}
#
# Word: !
# Text & Token Indices: {4: [11], 7: [7], 19: [10], 27: [3], 32: [7], 42: [5], 44: [10, 17, 18], 46: [7, 25], 59: [6], 61: [3], 63: [4], 86: [5], 94: [19], 95: [4, 17], 96: [8], 97: [6], 98: [6], 99: [5], 101: [11], 103: [8], 109: [11], 117: [5], 120: [6], 130: [6], 133: [11], 144: [4], 145: [5], 158: [7, 15, 24, 31, 37], 161: [7], 174: [7], 177: [6], 181: [6], 189: [5], 194: [5], 210: [6], 218: [23], 221: [6], 224: [14], 229: [7, 15, 24], 232: [14], 236: [10], 240: [10], 241: [7], 247: [2]}
#
# Word: whoever
# Text & Token Indices: {5: [0]}
#
# Word: save
# Text & Token Indices: {5: [1, 4], 226: [0]}
#
# Word: one
# Text & Token Indices: {5: [2], 23: [14], 25: [9], 32: [10], 46: [9], 47: [4, 7, 10], 50: [2], 65: [2], 99: [0], 100: [0], 153: [12], 189: [0], 197: [5], 200: [0], 208: [7], 214: [10], 220: [3], 229: [8]}
#
# Word: world
# Text & Token Indices: {5: [5], 39: [7], 44: [1], 45: [5], 46: [19], 51: [3], 106: [4], 137: [1], 199: [5], 200: [4], 208: [4], 243: [9], 248: [4]}
#
# Word: entire
# Text & Token Indices: {5: [6], 62: [1]}
#
# Word: the
# Text & Token Indices: {6: [0], 8: [0], 10: [0], 14: [0], 23: [7], 27: [4], 30: [0], 32: [0], 39: [0], 41: [0], 44: [0, 15], 48: [0], 52: [0, 2], 61: [0], 63: [0], 67: [0], 68: [0], 71: [0, 3, 6, 9, 12], 72: [0], 75: [0], 85: [0, 4], 91: [6], 92: [0], 93: [0], 94: [5], 95: [2], 101: [5], 105: [3], 106: [3], 108: [0], 109: [0], 111: [8, 11], 120: [0], 125: [0], 126: [0], 128: [13], 142: [0], 149: [0], 151: [0], 158: [25, 32], 165: [0], 172: [0], 176: [1], 178: [0], 181: [0], 185: [12], 186: [3], 192: [0], 211: [0], 222: [0], 224: [0, 7], 225: [0], 226: [1], 227: [0], 229: [0, 16], 232: [0], 236: [0, 8], 240: [3, 8], 248: [3]}
#
# Word: eye
# Text & Token Indices: {6: [1]}
#
# Word: enemy
# Text & Token Indices: {6: [2], 37: [9], 122: [1]}
#
# Word: moving
# Text & Token Indices: {6: [3]}
#
# Word: girl
# Text & Token Indices: {7: [0], 102: [9], 124: [2]}
#
# Word: like
# Text & Token Indices: {7: [1, 5], 101: [3], 166: [21]}
#
# Word: make
# Text & Token Indices: {7: [3], 17: [3], 46: [11], 94: [27], 208: [9]}
#
# Word: invitation
# Text & Token Indices: {7: [4]}
#
# Word: anyone
# Text & Token Indices: {7: [6], 152: [2], 166: [18]}
#
# Word: legend
# Text & Token Indices: {8: [1], 68: [1], 126: [1], 179: [3]}
#
# Word: come
# Text & Token Indices: {8: [2], 109: [7], 199: [6], 215: [2], 239: [4]}
#
# Word: they
# Text & Token Indices: {9: [0], 91: [9, 18], 120: [3], 209: [0]}
#
# Word: formed
# Text & Token Indices: {9: [1]}
#
# Word: alliance
# Text & Token Indices: {9: [2]}
#
# Word: hate
# Text & Token Indices: {9: [3], 37: [3]}
#
# Word: steal
# Text & Token Indices: {9: [4]}
#
# Word: fortune
# Text & Token Indices: {9: [5]}
#
# Word: dead
# Text & Token Indices: {9: [6], 140: [3], 144: [2]}
#
# Word: man
# Text & Token Indices: {9: [7], 71: [1], 75: [2], 94: [6], 102: [3, 22], 125: [1], 139: [5], 181: [1], 208: [8], 246: [1, 11]}
#
# Word: 's
# Text & Token Indices: {9: [8], 17: [1], 20: [2, 6], 27: [1], 28: [1], 29: [1], 32: [16], 45: [4, 7], 56: [7], 57: [6], 64: [2], 79: [7], 81: [2], 91: [15, 23], 94: [1, 15], 103: [1], 108: [5], 114: [2], 115: [6], 119: [1], 130: [1], 136: [4], 137: [2], 139: [1], 153: [3, 8], 154: [7], 158: [27], 183: [6], 187: [2], 188: [9], 196: [6], 216: [1, 12], 217: [1], 218: [15], 224: [2], 246: [4]}
#
# Word: gold
# Text & Token Indices: {9: [9]}
#
# Word: story
# Text & Token Indices: {10: [1], 58: [2], 75: [1], 76: [1], 104: [2], 154: [3], 158: [30], 162: [20], 169: [3], 172: [2], 178: [3], 191: [3], 199: [8], 213: [1], 218: [6], 224: [5], 231: [2]}
#
# Word: lifetime
# Text & Token Indices: {10: [2], 72: [2]}
#
# Word: how
# Text & Token Indices: {11: [0], 38: [3], 111: [6]}
#
# Word: much
# Text & Token Indices: {11: [1], 128: [3, 9, 17]}
#
# Word: know
# Text & Token Indices: {11: [2], 91: [12], 157: [9], 183: [2], 201: [1], 218: [21], 232: [4]}
#
# Word: 've
# Text & Token Indices: {11: [3], 16: [7], 91: [19], 183: [3], 225: [2], 237: [2]}
#
# Word: never
# Text & Token Indices: {11: [4], 24: [4], 44: [3], 59: [0], 80: [2], 94: [26], 101: [1], 133: [9], 177: [4], 238: [0]}
#
# Word: fight
# Text & Token Indices: {11: [5], 168: [0]}
#
# Word: a
# Text & Token Indices: {12: [0], 16: [1], 40: [0], 49: [0], 58: [0], 94: [10], 96: [0], 98: [0], 159: [0], 162: [12, 16, 19], 169: [0], 174: [0], 175: [0], 182: [0], 196: [10], 197: [1], 198: [0], 206: [0], 231: [0], 242: [0], 243: [0]}
#
# Word: new
# Text & Token Indices: {12: [1], 55: [3], 94: [17], 119: [3], 145: [1], 158: [9], 193: [7], 239: [2], 242: [1]}
#
# Word: rising
# Text & Token Indices: {12: [4]}
#
# Word: your
# Text & Token Indices: {13: [0], 57: [10]}
#
# Word: scene
# Text & Token Indices: {13: [2]}
#
# Word: crime
# Text & Token Indices: {13: [3], 79: [0], 91: [8], 162: [13]}
#
# Word: adventure
# Text & Token Indices: {14: [1], 96: [7], 102: [1], 119: [4], 145: [4], 165: [3], 174: [6], 200: [1]}
#
# Word: continues
# Text & Token Indices: {14: [2]}
#
# Word: ...
# Text & Token Indices: {14: [3], 20: [3], 23: [13], 32: [5, 8, 13], 46: [17], 66: [0], 70: [6], 71: [2, 5, 8, 11, 15], 73: [2], 75: [5], 95: [5], 102: [4, 10, 14, 18, 23], 105: [2], 106: [8], 116: [4], 123: [4], 133: [3], 137: [4], 147: [4, 7], 151: [3], 154: [4], 161: [3], 174: [3], 183: [7], 193: [3], 205: [11], 212: [2], 214: [8, 14], 218: [3], 223: [4], 225: [4], 229: [3, 11, 20], 234: [5], 238: [5], 240: [5], 246: [13]}
#
# Word: ``
# Text & Token Indices: {16: [0], 73: [0], 87: [0, 5], 101: [4], 111: [1], 140: [0], 165: [5], 176: [0], 185: [0], 186: [2], 196: [14], 218: [0], 237: [0]}
#
# Word: far
# Text & Token Indices: {16: [2], 38: [4], 228: [1]}
#
# Word: back
# Text & Token Indices: {16: [3], 27: [2], 117: [2], 119: [2], 125: [3], 208: [6]}
#
# Word: i
# Text & Token Indices: {16: [4, 6], 36: [6], 89: [0, 3], 140: [1], 157: [8], 176: [3]}
#
# Word: remember
# Text & Token Indices: {16: [5], 106: [5], 111: [5], 157: [0, 1], 158: [2]}
#
# Word: always
# Text & Token Indices: {16: [8]}
#
# Word: wanted
# Text & Token Indices: {16: [9], 47: [8, 11]}
#
# Word: gangster
# Text & Token Indices: {16: [10]}
#
# Word: ''
# Text & Token Indices: {16: [11], 20: [4, 9], 73: [4], 87: [4, 9], 101: [7], 111: [4], 140: [5], 165: [8], 176: [7], 185: [9], 186: [5], 196: [4, 20], 218: [2], 237: [6]}
#
# Word: henry
# Text & Token Indices: {16: [13]}
#
# Word: hill
# Text & Token Indices: {16: [14]}
#
# Word: brooklyn
# Text & Token Indices: {16: [15]}
#
# Word: n.y.
# Text & Token Indices: {16: [16]}
#
# Word: 1955
# Text & Token Indices: {16: [17]}
#
# Word: if
# Text & Token Indices: {17: [0], 22: [0, 4], 34: [0]}
#
# Word: crazy
# Text & Token Indices: {17: [2]}
#
# Word: long
# Text & Token Indices: {18: [0], 190: [1], 206: [1]}
#
# Word: way
# Text & Token Indices: {18: [1], 143: [2]}
#
# Word: hard
# Text & Token Indices: {18: [2]}
#
# Word: hell
# Text & Token Indices: {18: [3], 139: [2]}
#
# Word: lead
# Text & Token Indices: {18: [4], 76: [11]}
#
# Word: light
# Text & Token Indices: {18: [5]}
#
# Word: will
# Text & Token Indices: {19: [0], 138: [1, 5], 232: [6]}
#
# Word: take
# Text & Token Indices: {19: [1], 38: [5], 41: [3], 97: [2]}
#
# Word: it
# Text & Token Indices: {19: [2], 20: [5], 24: [3], 27: [0], 28: [0], 95: [0, 9, 13], 103: [0], 117: [0], 130: [0], 133: [4], 139: [0], 180: [0], 196: [5], 203: [13]}
#
# Word: place
# Text & Token Indices: {19: [3], 234: [3]}
#
# Word: with
# Text & Token Indices: {19: [4], 114: [6]}
#
# Word: seven
# Text & Token Indices: {19: [5], 91: [0], 128: [14]}
#
# Word: greatest
# Text & Token Indices: {19: [6], 23: [8], 32: [17], 39: [1], 46: [3], 158: [20], 224: [3]}
#
# Word: film
# Text & Token Indices: {19: [7], 81: [4], 99: [2], 127: [2], 154: [9], 189: [3], 198: [1, 17], 224: [9], 242: [2]}
#
# Word: time
# Text & Token Indices: {19: [9], 35: [2], 46: [6], 63: [3], 64: [1], 70: [2], 99: [4], 111: [13], 122: [0], 158: [14], 189: [4], 215: [1], 216: [13]}
#
# Word: frank
# Text & Token Indices: {20: [0]}
#
# Word: capra
# Text & Token Indices: {20: [1]}
#
# Word: wonderful
# Text & Token Indices: {20: [7]}
#
# Word: dr.
# Text & Token Indices: {21: [0]}
#
# Word: hannibal
# Text & Token Indices: {21: [1]}
#
# Word: lecter
# Text & Token Indices: {21: [2]}
#
# Word: brilliant
# Text & Token Indices: {21: [3, 16]}
#
# Word: cunning
# Text & Token Indices: {21: [4]}
#
# Word: psychotic
# Text & Token Indices: {21: [5]}
#
# Word: lie
# Text & Token Indices: {21: [8], 38: [0], 93: [1], 113: [3]}
#
# Word: clue
# Text & Token Indices: {21: [9]}
#
# Word: ruthless
# Text & Token Indices: {21: [10]}
#
# Word: killer
# Text & Token Indices: {21: [11, 23]}
#
# Word: -
# Text & Token Indices: {21: [12], 55: [2], 56: [4], 79: [4], 95: [8, 12], 103: [11, 15, 18, 21, 25], 185: [11], 196: [28, 32, 35, 38, 42]}
#
# Word: clarice
# Text & Token Indices: {21: [13]}
#
# Word: starling
# Text & Token Indices: {21: [14]}
#
# Word: fbi
# Text & Token Indices: {21: [15]}
#
# Word: vulnerable
# Text & Token Indices: {21: [17]}
#
# Word: alone
# Text & Token Indices: {21: [18], 46: [2]}
#
# Word: she
# Text & Token Indices: {21: [19]}
#
# Word: must
# Text & Token Indices: {21: [20], 32: [2], 76: [10], 162: [21]}
#
# Word: trust
# Text & Token Indices: {21: [21]}
#
# Word: stop
# Text & Token Indices: {21: [22]}
#
# Word: run
# Text & Token Indices: {22: [1], 196: [13]}
#
# Word: beast
# Text & Token Indices: {22: [2, 6], 246: [2]}
#
# Word: get
# Text & Token Indices: {22: [3], 29: [4], 155: [1, 4, 7, 11], 238: [2]}
#
# Word: stay
# Text & Token Indices: {22: [5], 134: [2]}
#
# Word: eat
# Text & Token Indices: {22: [7]}
#
# Word: last
# Text & Token Indices: {23: [1, 4], 190: [2], 216: [2]}
#
# Word: great
# Text & Token Indices: {23: [2, 5], 99: [1], 127: [1], 241: [1]}
#
# Word: invasion
# Text & Token Indices: {23: [3]}
#
# Word: war
# Text & Token Indices: {23: [6], 55: [8], 59: [5], 76: [6], 92: [3], 104: [4], 211: [3]}
#
# Word: danger
# Text & Token Indices: {23: [9]}
#
# Word: eight
# Text & Token Indices: {23: [10]}
#
# Word: men
# Text & Token Indices: {23: [11], 47: [2], 130: [5], 144: [1], 147: [3]}
#
# Word: saving
# Text & Token Indices: {23: [12]}
#
# Word: mankind
# Text & Token Indices: {24: [0]}
#
# Word: born
# Text & Token Indices: {24: [1], 29: [6]}
#
# Word: meant
# Text & Token Indices: {24: [5], 56: [8]}
#
# Word: die
# Text & Token Indices: {24: [6], 162: [22]}
#
# Word: unforgettable
# Text & Token Indices: {25: [1]}
#
# Word: fable
# Text & Token Indices: {25: [2]}
#
# Word: prof
# Text & Token Indices: {25: [3]}
#
# Word: love
# Text & Token Indices: {25: [4], 42: [1], 103: [2], 158: [29], 162: [18], 173: [11], 201: [0], 218: [5, 22], 224: [4], 231: [6], 235: [0], 246: [8]}
#
# Word: family
# Text & Token Indices: {25: [5], 222: [3]}
#
# Word: imagination
# Text & Token Indices: {25: [6], 95: [7]}
#
# Word: conquer
# Text & Token Indices: {25: [7]}
#
# Word: canadian
# Text & Token Indices: {25: [8]}
#
# Word: sheet
# Text & Token Indices: {25: [10], 197: [6]}
#
# Word: miracle
# Text & Token Indices: {26: [0], 221: [1]}
#
# Word: happen
# Text & Token Indices: {26: [1]}
#
# Word: force
# Text & Token Indices: {27: [5]}
#
# Word: three
# Text & Token Indices: {27: [6], 47: [1]}
#
# Word: week
# Text & Token Indices: {27: [7]}
#
# Word: 1979
# Text & Token Indices: {27: [8]}
#
# Word: reissue
# Text & Token Indices: {27: [9], 158: [38], 192: [7]}
#
# Word: poster
# Text & Token Indices: {27: [10], 88: [7]}
#
# Word: nothing
# Text & Token Indices: {28: [2], 129: [0], 229: [13]}
#
# Word: personal
# Text & Token Indices: {28: [3]}
#
# Word: he
# Text & Token Indices: {29: [0], 46: [0], 51: [0], 106: [0], 119: [0], 188: [4], 204: [0, 2]}
#
# Word: kid
# Text & Token Indices: {29: [2]}
#
# Word: ever
# Text & Token Indices: {29: [3], 35: [3], 39: [4], 157: [14], 158: [22, 35]}
#
# Word: trouble
# Text & Token Indices: {29: [5]}
#
# Word: uk
# Text & Token Indices: {29: [7]}
#
# Word: tunnel
# Text & Token Indices: {30: [1]}
#
# Word: led
# Text & Token Indices: {30: [2]}
#
# Word: chihiro
# Text & Token Indices: {30: [3]}
#
# Word: mysterious
# Text & Token Indices: {30: [4]}
#
# Word: town
# Text & Token Indices: {30: [5], 193: [2]}
#
# Word: music
# Text & Token Indices: {31: [0], 71: [4]}
#
# Word: passion
# Text & Token Indices: {31: [1], 79: [1]}
#
# Word: survival
# Text & Token Indices: {31: [2]}
#
# Word: masterpiece
# Text & Token Indices: {31: [3], 61: [2], 114: [4]}
#
# Word: picture
# Text & Token Indices: {32: [1], 44: [13], 71: [14], 94: [22], 96: [3], 120: [2], 133: [2], 158: [34], 176: [2], 207: [2], 227: [1], 232: [13], 239: [7], 243: [2]}
#
# Word: see
# Text & Token Indices: {32: [3], 35: [0], 98: [4], 140: [2], 146: [2], 227: [5], 232: [12]}
#
# Word: beginning
# Text & Token Indices: {32: [4], 98: [5]}
#
# Word: or
# Text & Token Indices: {32: [6]}
#
# Word: for
# Text & Token Indices: {32: [9], 87: [6], 91: [5], 158: [0, 8], 216: [0]}
#
# Word: seated
# Text & Token Indices: {32: [11]}
#
# Word: start
# Text & Token Indices: {32: [12]}
#
# Word: alfred
# Text & Token Indices: {32: [14], 97: [0]}
#
# Word: hitchcock
# Text & Token Indices: {32: [15], 48: [2], 97: [1], 98: [1]}
#
# Word: shocker
# Text & Token Indices: {32: [18]}
#
# Word: psycho
# Text & Token Indices: {32: [19]}
#
# Word: misplaced
# Text & Token Indices: {33: [0]}
#
# Word: familyhood
# Text & Token Indices: {33: [1]}
#
# Word: australia/new
# Text & Token Indices: {33: [2]}
#
# Word: zealand/singapore
# Text & Token Indices: {33: [3]}
#
# Word: want
# Text & Token Indices: {34: [1], 120: [4], 166: [19], 176: [4], 223: [6], 227: [3]}
#
# Word: job
# Text & Token Indices: {34: [2], 166: [3]}
#
# Word: done
# Text & Token Indices: {34: [3]}
#
# Word: right
# Text & Token Indices: {34: [4]}
#
# Word: hire
# Text & Token Indices: {34: [5]}
#
# Word: professional
# Text & Token Indices: {34: [6]}
#
# Word: first
# Text & Token Indices: {35: [1], 103: [6], 111: [12], 158: [13], 211: [1], 216: [6]}
#
# Word: 3d
# Text & Token Indices: {35: [4, 6]}
#
# Word: 2011
# Text & Token Indices: {35: [5]}
#
# Word: re-release
# Text & Token Indices: {35: [7], 73: [7], 111: [14], 114: [12], 247: [4]}
#
# Word: father
# Text & Token Indices: {36: [0], 37: [1], 188: [8]}
#
# Word: murdered
# Text & Token Indices: {36: [1, 4]}
#
# Word: son
# Text & Token Indices: {36: [2]}
#
# Word: husband
# Text & Token Indices: {36: [3], 151: [1]}
#
# Word: wife
# Text & Token Indices: {36: [5], 151: [2]}
#
# Word: shall
# Text & Token Indices: {36: [7]}
#
# Word: vengeance
# Text & Token Indices: {36: [8], 54: [3], 69: [5], 138: [7]}
#
# Word: next
# Text & Token Indices: {36: [10]}
#
# Word: his
# Text & Token Indices: {37: [0, 4, 8], 214: [9], 215: [0], 248: [0]}
#
# Word: taught
# Text & Token Indices: {37: [2, 6]}
#
# Word: friend
# Text & Token Indices: {37: [5]}
#
# Word: rage
# Text & Token Indices: {37: [7]}
#
# Word: gave
# Text & Token Indices: {37: [10]}
#
# Word: betrayal
# Text & Token Indices: {38: [1], 235: [1]}
#
# Word: sacrifice
# Text & Token Indices: {38: [2]}
#
# Word: trick
# Text & Token Indices: {39: [2]}
#
# Word: devil
# Text & Token Indices: {39: [3]}
#
# Word: pulled
# Text & Token Indices: {39: [5]}
#
# Word: convince
# Text & Token Indices: {39: [6]}
#
# Word: exist
# Text & Token Indices: {39: [9]}
#
# Word: friendship
# Text & Token Indices: {40: [1], 49: [3], 132: [2], 179: [1], 199: [10]}
#
# Word: that
# Text & Token Indices: {40: [2], 153: [7], 240: [1]}
#
# Word: became
# Text & Token Indices: {40: [3], 190: [5], 229: [21]}
#
# Word: rivalry
# Text & Token Indices: {40: [4]}
#
# Word: road
# Text & Token Indices: {41: [1]}
#
# Word: greatness
# Text & Token Indices: {41: [2]}
#
# Word: edge
# Text & Token Indices: {41: [4]}
#
# Word: where
# Text & Token Indices: {42: [0]}
#
# Word: cut
# Text & Token Indices: {42: [2], 175: [6]}
#
# Word: deep
# Text & Token Indices: {42: [3]}
#
# Word: dagger
# Text & Token Indices: {42: [4]}
#
# Word: imationdramawar
# Text & Token Indices: {43: [0]}
#
# Word: ha
# Text & Token Indices: {44: [2]}
#
# Word: understood
# Text & Token Indices: {44: [4]}
#
# Word: japanese
# Text & Token Indices: {44: [6]}
#
# Word: prefer
# Text & Token Indices: {44: [7]}
#
# Word: dishonor
# Text & Token Indices: {44: [9]}
#
# Word: this
# Text & Token Indices: {44: [11], 64: [0], 76: [0], 127: [0], 224: [10]}
#
# Word: samurai
# Text & Token Indices: {44: [12]}
#
# Word: provides
# Text & Token Indices: {44: [14]}
#
# Word: answer
# Text & Token Indices: {44: [16]}
#
# Word: sometimes
# Text & Token Indices: {45: [0]}
#
# Word: reach
# Text & Token Indices: {45: [1]}
#
# Word: someone
# Text & Token Indices: {45: [2], 80: [4], 141: [0]}
#
# Word: else
# Text & Token Indices: {45: [3]}
#
# Word: find
# Text & Token Indices: {45: [6], 143: [1], 153: [11]}
#
# Word: missing
# Text & Token Indices: {45: [8], 141: [1]}
#
# Word: stand
# Text & Token Indices: {46: [1]}
#
# Word: entertainer
# Text & Token Indices: {46: [4]}
#
# Word: modern
# Text & Token Indices: {46: [5]}
#
# Word: no
# Text & Token Indices: {46: [8], 60: [2], 148: [2]}
#
# Word: laugh
# Text & Token Indices: {46: [12, 20], 194: [4]}
#
# Word: heartily
# Text & Token Indices: {46: [13]}
#
# Word: touch
# Text & Token Indices: {46: [14]}
#
# Word: heart
# Text & Token Indices: {46: [15], 142: [8], 219: [1], 223: [8], 240: [9]}
#
# Word: deeply
# Text & Token Indices: {46: [16], 59: [3]}
#
# Word: whole
# Text & Token Indices: {46: [18], 127: [4]}
#
# Word: cry
# Text & Token Indices: {46: [21]}
#
# Word: thrill
# Text & Token Indices: {46: [22], 86: [3]}
#
# Word: priceless
# Text & Token Indices: {46: [23]}
#
# Word: genius
# Text & Token Indices: {46: [24]}
#
# Word: there
# Text & Token Indices: {47: [0], 138: [0, 4], 148: [0], 246: [0, 6]}
#
# Word: knew
# Text & Token Indices: {47: [5]}
#
# Word: past
# Text & Token Indices: {47: [6], 173: [2]}
#
# Word: land
# Text & Token Indices: {47: [9]}
#
# Word: revenge
# Text & Token Indices: {47: [12]}
#
# Word: essential
# Text & Token Indices: {48: [1]}
#
# Word: celebration
# Text & Token Indices: {49: [1], 72: [1]}
#
# Word: youth
# Text & Token Indices: {49: [2]}
#
# Word: everlasting
# Text & Token Indices: {49: [4]}
#
# Word: magic
# Text & Token Indices: {49: [5]}
#
# Word: movie
# Text & Token Indices: {49: [6], 225: [1]}
#
# Word: space
# Text & Token Indices: {50: [1], 153: [10]}
#
# Word: hear
# Text & Token Indices: {50: [3]}
#
# Word: scream
# Text & Token Indices: {50: [4]}
#
# Word: return
# Text & Token Indices: {51: [1]}
#
# Word: -and
# Text & Token Indices: {51: [2], 130: [4]}
#
# Word: rock
# Text & Token Indices: {51: [4]}
#
# Word: laughter
# Text & Token Indices: {51: [5], 186: [7]}
#
# Word: print
# Text & Token Indices: {51: [6], 103: [9], 176: [10], 196: [26], 236: [11]}
#
# Word: ad-daily
# Text & Token Indices: {51: [7]}
#
# Word: examiner
# Text & Token Indices: {51: [8]}
#
# Word: grafton
# Text & Token Indices: {51: [9]}
#
# Word: nsw
# Text & Token Indices: {51: [10]}
#
# Word: 6
# Text & Token Indices: {51: [11]}
#
# Word: july
# Text & Token Indices: {51: [12]}
#
# Word: 1931
# Text & Token Indices: {51: [13]}
#
# Word: horror
# Text & Token Indices: {52: [1, 3]}
#
# Word: some
# Text & Token Indices: {53: [0], 80: [0], 244: [0]}
#
# Word: memory
# Text & Token Indices: {53: [1], 173: [8], 216: [14]}
#
# Word: best
# Text & Token Indices: {53: [2], 154: [8], 224: [8]}
#
# Word: forgotten
# Text & Token Indices: {53: [3]}
#
# Word: liberty
# Text & Token Indices: {54: [1]}
#
# Word: pursuit
# Text & Token Indices: {54: [2]}
#
# Word: indiana
# Text & Token Indices: {55: [0]}
#
# Word: jones
# Text & Token Indices: {55: [1]}
#
# Word: hero
# Text & Token Indices: {55: [4], 229: [23]}
#
# Word: creator
# Text & Token Indices: {55: [5]}
#
# Word: jaw
# Text & Token Indices: {55: [6]}
#
# Word: star
# Text & Token Indices: {55: [7], 94: [18], 218: [20]}
#
# Word: after
# Text & Token Indices: {56: [0]}
#
# Word: 700
# Text & Token Indices: {56: [1]}
#
# Word: year
# Text & Token Indices: {56: [2], 69: [1], 127: [5], 128: [15], 150: [1], 154: [6], 224: [11]}
#
# Word: built
# Text & Token Indices: {56: [3]}
#
# Word: 'll
# Text & Token Indices: {56: [5], 147: [5]}
#
# Word: discover
# Text & Token Indices: {56: [6], 179: [0]}
#
# Word: before
# Text & Token Indices: {57: [0]}
#
# Word: fall
# Text & Token Indices: {57: [1]}
#
# Word: berlin
# Text & Token Indices: {57: [2]}
#
# Word: wall
# Text & Token Indices: {57: [3], 117: [3]}
#
# Word: east
# Text & Token Indices: {57: [4]}
#
# Word: germany
# Text & Token Indices: {57: [5]}
#
# Word: secret
# Text & Token Indices: {57: [7, 11], 174: [2], 244: [1]}
#
# Word: police
# Text & Token Indices: {57: [8]}
#
# Word: listened
# Text & Token Indices: {57: [9]}
#
# Word: hollywood
# Text & Token Indices: {58: [1], 94: [23], 224: [13]}
#
# Word: screen
# Text & Token Indices: {59: [1], 94: [14], 109: [10], 158: [26], 224: [1], 236: [9], 240: [4], 241: [3]}
#
# Word: thrust
# Text & Token Indices: {59: [2]}
#
# Word: gut
# Text & Token Indices: {59: [4]}
#
# Word: iconic
# Text & Token Indices: {60: [0]}
#
# Word: terror
# Text & Token Indices: {60: [1]}
#
# Word: 1
# Text & Token Indices: {60: [3], 81: [3], 103: [23]}
#
# Word: bestselling
# Text & Token Indices: {60: [4]}
#
# Word: writer
# Text & Token Indices: {60: [5]}
#
# Word: comedy
# Text & Token Indices: {61: [1], 67: [1], 85: [2], 128: [10], 241: [6]}
#
# Word: universe
# Text & Token Indices: {62: [2], 65: [1]}
#
# Word: once
# Text & Token Indices: {62: [3], 70: [0]}
#
# Word: electrifying
# Text & Token Indices: {63: [1]}
#
# Word: entertainment
# Text & Token Indices: {63: [2]}
#
# Word: enter
# Text & Token Indices: {65: [0]}
#
# Word: wear
# Text & Token Indices: {65: [3], 166: [11]}
#
# Word: mask
# Text & Token Indices: {65: [4]}
#
# Word: look
# Text & Token Indices: {66: [1]}
#
# Word: closer
# Text & Token Indices: {66: [2]}
#
# Word: classic
# Text & Token Indices: {67: [2], 187: [3], 192: [6]}
#
# Word: celebrated
# Text & Token Indices: {67: [3]}
#
# Word: director
# Text & Token Indices: {67: [4], 81: [7], 84: [1]}
#
# Word: stanley
# Text & Token Indices: {67: [5]}
#
# Word: kubrick
# Text & Token Indices: {67: [6]}
#
# Word: end
# Text & Token Indices: {68: [2], 180: [2]}
#
# Word: 15
# Text & Token Indices: {69: [0]}
#
# Word: imprisonment
# Text & Token Indices: {69: [2]}
#
# Word: five
# Text & Token Indices: {69: [3]}
#
# Word: day
# Text & Token Indices: {69: [4], 119: [6], 196: [22], 197: [3], 223: [3], 226: [2]}
#
# Word: upon
# Text & Token Indices: {70: [1]}
#
# Word: nazi
# Text & Token Indices: {70: [3]}
#
# Word: occupied
# Text & Token Indices: {70: [4]}
#
# Word: france
# Text & Token Indices: {70: [5]}
#
# Word: madness
# Text & Token Indices: {71: [7], 208: [3]}
#
# Word: murder
# Text & Token Indices: {71: [10], 103: [4], 169: [2]}
#
# Word: motion
# Text & Token Indices: {71: [13], 96: [2], 133: [1], 239: [6], 243: [1]}
#
# Word: oooh
# Text & Token Indices: {73: [1]}
#
# Word: 3-d
# Text & Token Indices: {73: [3]}
#
# Word: usa
# Text & Token Indices: {73: [5]}
#
# Word: 2009
# Text & Token Indices: {73: [6]}
#
# Word: put
# Text & Token Indices: {74: [0], 147: [0]}
#
# Word: happy
# Text & Token Indices: {74: [1]}
#
# Word: face
# Text & Token Indices: {74: [2]}
#
# Word: soul
# Text & Token Indices: {75: [4], 219: [3]}
#
# Word: courage
# Text & Token Indices: {75: [6], 142: [7]}
#
# Word: follow
# Text & Token Indices: {75: [7]}
#
# Word: 42
# Text & Token Indices: {76: [2]}
#
# Word: raw
# Text & Token Indices: {76: [3]}
#
# Word: recruit
# Text & Token Indices: {76: [4]}
#
# Word: caught
# Text & Token Indices: {76: [5]}
#
# Word: understand
# Text & Token Indices: {76: [8]}
#
# Word: captain
# Text & Token Indices: {76: [9]}
#
# Word: struggle
# Text & Token Indices: {76: [12]}
#
# Word: survive
# Text & Token Indices: {76: [13]}
#
# Word: avenge
# Text & Token Indices: {77: [0]}
#
# Word: fallen
# Text & Token Indices: {77: [1]}
#
# Word: live
# Text & Token Indices: {78: [0], 177: [1]}
#
# Word: lust
# Text & Token Indices: {79: [2]}
#
# Word: sergio
# Text & Token Indices: {79: [5]}
#
# Word: leone
# Text & Token Indices: {79: [6]}
#
# Word: explosive
# Text & Token Indices: {79: [8]}
#
# Word: saga
# Text & Token Indices: {79: [9], 222: [1]}
#
# Word: gangland
# Text & Token Indices: {79: [10]}
#
# Word: america
# Text & Token Indices: {79: [11]}
#
# Word: people
# Text & Token Indices: {80: [1], 140: [4], 199: [2], 203: [9]}
#
# Word: believe
# Text & Token Indices: {80: [3]}
#
# Word: belief
# Text & Token Indices: {80: [5], 136: [3]}
#
# Word: experience
# Text & Token Indices: {81: [0], 111: [3], 133: [6]}
#
# Word: japan
# Text & Token Indices: {81: [1]}
#
# Word: 2016
# Text & Token Indices: {81: [5]}
#
# Word: visionary
# Text & Token Indices: {81: [6]}
#
# Word: makoto
# Text & Token Indices: {81: [8]}
#
# Word: shinkai
# Text & Token Indices: {81: [9]}
#
# Word: do
# Text & Token Indices: {82: [0], 91: [10]}
#
# Word: stupid
# Text & Token Indices: {82: [2]}
#
# Word: be
# Text & Token Indices: {82: [3], 138: [2, 6], 176: [5], 196: [9]}
#
# Word: i.d.i.o.t
# Text & Token Indices: {82: [4]}
#
# Word: singin
# Text & Token Indices: {83: [0]}
#
# Word: '
# Text & Token Indices: {83: [1, 3, 6], 118: [1, 4]}
#
# Word: swingin
# Text & Token Indices: {83: [2]}
#
# Word: glorious
# Text & Token Indices: {83: [4]}
#
# Word: feelin
# Text & Token Indices: {83: [5]}
#
# Word: technicolor
# Text & Token Indices: {83: [7]}
#
# Word: musical
# Text & Token Indices: {83: [8], 107: [2]}
#
# Word: from
# Text & Token Indices: {84: [0], 224: [12], 239: [0]}
#
# Word: pi
# Text & Token Indices: {84: [2]}
#
# Word: breakout
# Text & Token Indices: {85: [1]}
#
# Word: of
# Text & Token Indices: {85: [3], 96: [4], 221: [3]}
#
# Word: summer
# Text & Token Indices: {85: [5], 203: [12], 212: [3]}
#
# Word: 142
# Text & Token Indices: {86: [0]}
#
# Word: screenful
# Text & Token Indices: {86: [1]}
#
# Word: minute
# Text & Token Indices: {86: [2], 114: [8]}
#
# Word: suspense
# Text & Token Indices: {86: [4], 161: [5]}
#
# Word: suing
# Text & Token Indices: {87: [2]}
#
# Word: parent
# Text & Token Indices: {87: [3], 206: [5]}
#
# Word: giving
# Text & Token Indices: {87: [7]}
#
# Word: coming
# Text & Token Indices: {88: [0], 218: [17]}
#
# Word: may
# Text & Token Indices: {88: [1]}
#
# Word: 25
# Text & Token Indices: {88: [2], 114: [7]}
#
# Word: 1983
# Text & Token Indices: {88: [3]}
#
# Word: galaxy
# Text & Token Indices: {88: [4], 218: [19]}
#
# Word: second
# Text & Token Indices: {88: [5], 220: [1]}
#
# Word: advance
# Text & Token Indices: {88: [6]}
#
# Word: already
# Text & Token Indices: {89: [1]}
#
# Word: forget
# Text & Token Indices: {89: [2], 133: [10], 177: [5]}
#
# Word: used
# Text & Token Indices: {89: [4]}
#
# Word: feel
# Text & Token Indices: {89: [5], 105: [0], 111: [9]}
#
# Word: let
# Text & Token Indices: {90: [0]}
#
# Word: awe
# Text & Token Indices: {90: [1], 246: [7]}
#
# Word: mystery
# Text & Token Indices: {90: [2]}
#
# Word: journey
# Text & Token Indices: {90: [3], 173: [10], 177: [3]}
#
# Word: unlike
# Text & Token Indices: {90: [4]}
#
# Word: any
# Text & Token Indices: {90: [5], 232: [9]}
#
# Word: other
# Text & Token Indices: {90: [6], 91: [14, 22]}
#
# Word: begin
# Text & Token Indices: {90: [7], 126: [2], 245: [1]}
#
# Word: total
# Text & Token Indices: {91: [1]}
#
# Word: stranger
# Text & Token Indices: {91: [2]}
#
# Word: team
# Text & Token Indices: {91: [3]}
#
# Word: up
# Text & Token Indices: {91: [4], 112: [1]}
#
# Word: perfect
# Text & Token Indices: {91: [7], 203: [14]}
#
# Word: each
# Text & Token Indices: {91: [13, 21]}
#
# Word: name
# Text & Token Indices: {91: [16], 106: [7], 125: [2], 188: [10]}
#
# Word: but
# Text & Token Indices: {91: [17], 166: [16], 216: [10]}
#
# Word: got
# Text & Token Indices: {91: [20], 183: [4], 220: [4], 237: [3]}
#
# Word: color
# Text & Token Indices: {91: [24]}
#
# Word: cruelest
# Text & Token Indices: {92: [1]}
#
# Word: side
# Text & Token Indices: {92: [2]}
#
# Word: spreading
# Text & Token Indices: {93: [2]}
#
# Word: radio
# Text & Token Indices: {94: [0]}
#
# Word: most
# Text & Token Indices: {94: [2]}
#
# Word: dynamic
# Text & Token Indices: {94: [3]}
#
# Word: artist
# Text & Token Indices: {94: [4]}
#
# Word: at
# Text & Token Indices: {94: [7], 103: [5], 190: [0]}
#
# Word: whose
# Text & Token Indices: {94: [8]}
#
# Word: voice
# Text & Token Indices: {94: [9], 160: [2]}
#
# Word: nation
# Text & Token Indices: {94: [11], 123: [2]}
#
# Word: trembled
# Text & Token Indices: {94: [12]}
#
# Word: now
# Text & Token Indices: {94: [13], 114: [5]}
#
# Word: exciting
# Text & Token Indices: {94: [16], 158: [28]}
#
# Word: orson
# Text & Token Indices: {94: [20]}
#
# Word: welles
# Text & Token Indices: {94: [21]}
#
# Word: said
# Text & Token Indices: {94: [24]}
#
# Word: 'd
# Text & Token Indices: {94: [25]}
#
# Word: stagger
# Text & Token Indices: {95: [1]}
#
# Word: sen
# Text & Token Indices: {95: [3]}
#
# Word: shock
# Text & Token Indices: {95: [6]}
#
# Word: leave
# Text & Token Indices: {95: [10]}
#
# Word: gasping
# Text & Token Indices: {95: [11]}
#
# Word: sensation
# Text & Token Indices: {95: [14]}
#
# Word: 3
# Text & Token Indices: {95: [15]}
#
# Word: continent
# Text & Token Indices: {95: [16]}
#
# Word: mighty
# Text & Token Indices: {96: [1], 221: [0], 236: [1]}
#
# Word: action
# Text & Token Indices: {96: [5], 128: [4], 158: [5]}
#
# Word: and
# Text & Token Indices: {96: [6], 103: [3], 240: [6], 243: [10], 246: [10]}
#
# Word: ....
# Text & Token Indices: {97: [3]}
#
# Word: north
# Text & Token Indices: {97: [4]}
#
# Word: northwest
# Text & Token Indices: {97: [5]}
#
# Word: thriller
# Text & Token Indices: {98: [2], 187: [4]}
#
# Word: you
# Text & Token Indices: {98: [3], 124: [0], 134: [0], 146: [0], 155: [0, 3, 6], 183: [0], 210: [0]}
#
# Word: our
# Text & Token Indices: {99: [3], 196: [0]}
#
# Word: person
# Text & Token Indices: {100: [1]}
#
# Word: forever
# Text & Token Indices: {100: [4], 134: [4], 248: [5]}
#
# Word: movie-wise
# Text & Token Indices: {101: [0]}
#
# Word: anything
# Text & Token Indices: {101: [2], 223: [5]}
#
# Word: apartment
# Text & Token Indices: {101: [6]}
#
# Word: love-wise
# Text & Token Indices: {101: [8]}
#
# Word: laugh-wise
# Text & Token Indices: {101: [9]}
#
# Word: otherwise-wise
# Text & Token Indices: {101: [10]}
#
# Word: being
# Text & Token Indices: {102: [0]}
#
# Word: young
# Text & Token Indices: {102: [2, 21]}
#
# Word: could
# Text & Token Indices: {102: [5]}
#
# Word: resist
# Text & Token Indices: {102: [7]}
#
# Word: pretty
# Text & Token Indices: {102: [8]}
#
# Word: bit
# Text & Token Indices: {102: [11]}
#
# Word: old
# Text & Token Indices: {102: [12]}
#
# Word: ultra-violence
# Text & Token Indices: {102: [13]}
#
# Word: went
# Text & Token Indices: {102: [15]}
#
# Word: jail
# Text & Token Indices: {102: [16]}
#
# Word: re-conditioned
# Text & Token Indices: {102: [17]}
#
# Word: came
# Text & Token Indices: {102: [19]}
#
# Word: different
# Text & Token Indices: {102: [20], 199: [4]}
#
# Word: sight
# Text & Token Indices: {103: [7]}
#
# Word: ad
# Text & Token Indices: {103: [10], 186: [10], 196: [27]}
#
# Word: lubbock
# Text & Token Indices: {103: [12, 19], 196: [29, 36]}
#
# Word: morning
# Text & Token Indices: {103: [13], 196: [30]}
#
# Word: avalanche
# Text & Token Indices: {103: [14], 196: [31]}
#
# Word: lindsey
# Text & Token Indices: {103: [16]}
#
# Word: theatre
# Text & Token Indices: {103: [17], 196: [34]}
#
# Word: texas
# Text & Token Indices: {103: [20], 196: [37]}
#
# Word: september
# Text & Token Indices: {103: [22]}
#
# Word: 1944
# Text & Token Indices: {103: [24]}
#
# Word: cap
# Text & Token Indices: {103: [26], 196: [43], 197: [4]}
#
# Word: epic
# Text & Token Indices: {104: [1]}
#
# Word: vietnam
# Text & Token Indices: {104: [3]}
#
# Word: australia
# Text & Token Indices: {104: [5]}
#
# Word: theatrical
# Text & Token Indices: {104: [6]}
#
# Word: need
# Text & Token Indices: {105: [1, 4]}
#
# Word: speed
# Text & Token Indices: {105: [5]}
#
# Word: tony
# Text & Token Indices: {106: [1]}
#
# Word: montana
# Text & Token Indices: {106: [2]}
#
# Word: another
# Text & Token Indices: {106: [6]}
#
# Word: scarface
# Text & Token Indices: {106: [9], 128: [2]}
#
# Word: american
# Text & Token Indices: {107: [1], 209: [2]}
#
# Word: search
# Text & Token Indices: {108: [1]}
#
# Word: began
# Text & Token Indices: {108: [2]}
#
# Word: opening
# Text & Token Indices: {108: [3]}
#
# Word: mother
# Text & Token Indices: {108: [4]}
#
# Word: beloved
# Text & Token Indices: {109: [1]}
#
# Word: widely
# Text & Token Indices: {109: [2]}
#
# Word: read
# Text & Token Indices: {109: [3], 232: [2]}
#
# Word: pulitzer
# Text & Token Indices: {109: [4]}
#
# Word: prize
# Text & Token Indices: {109: [5], 120: [1]}
#
# Word: winner
# Text & Token Indices: {109: [6]}
#
# Word: vividly
# Text & Token Indices: {109: [8]}
#
# Word: alive
# Text & Token Indices: {109: [9]}
#
# Word: l.a.
# Text & Token Indices: {110: [1]}
#
# Word: redemption
# Text & Token Indices: {110: [2]}
#
# Word: recapture
# Text & Token Indices: {111: [0]}
#
# Word: sting
# Text & Token Indices: {111: [2]}
#
# Word: good
# Text & Token Indices: {111: [7], 228: [2]}
#
# Word: wa
# Text & Token Indices: {111: [10]}
#
# Word: fly
# Text & Token Indices: {112: [0]}
#
# Word: venezuela
# Text & Token Indices: {112: [2]}
#
# Word: ugly
# Text & Token Indices: {113: [0]}
#
# Word: truth
# Text & Token Indices: {113: [1], 155: [13]}
#
# Word: sweet
# Text & Token Indices: {113: [2]}
#
# Word: fritz
# Text & Token Indices: {114: [0]}
#
# Word: lang
# Text & Token Indices: {114: [1]}
#
# Word: 1927
# Text & Token Indices: {114: [3]}
#
# Word: lost
# Text & Token Indices: {114: [9]}
#
# Word: footage
# Text & Token Indices: {114: [10], 194: [2]}
#
# Word: 2010
# Text & Token Indices: {114: [11]}
#
# Word: every
# Text & Token Indices: {115: [1, 3], 121: [0], 167: [0], 194: [0], 203: [11]}
#
# Word: street
# Text & Token Indices: {115: [2], 229: [18]}
#
# Word: city
# Text & Token Indices: {115: [4]}
#
# Word: country
# Text & Token Indices: {115: [5], 168: [1], 208: [1]}
#
# Word: nobody
# Text & Token Indices: {115: [7]}
#
# Word: dream
# Text & Token Indices: {115: [8], 173: [4], 185: [3], 209: [3]}
#
# Word: somebody
# Text & Token Indices: {115: [9]}
#
# Word: off
# Text & Token Indices: {116: [0]}
#
# Word: record
# Text & Token Indices: {116: [1]}
#
# Word: qt
# Text & Token Indices: {116: [2]}
#
# Word: hush-hush
# Text & Token Indices: {116: [3]}
#
# Word: blow
# Text & Token Indices: {117: [1]}
#
# Word: theater
# Text & Token Indices: {117: [4]}
#
# Word: stealin
# Text & Token Indices: {118: [0]}
#
# Word: stone
# Text & Token Indices: {118: [2]}
#
# Word: breakin
# Text & Token Indices: {118: [3]}
#
# Word: bone
# Text & Token Indices: {118: [5]}
#
# Word: memorial
# Text & Token Indices: {119: [5]}
#
# Word: 1989
# Text & Token Indices: {119: [7]}
#
# Word: censor
# Text & Token Indices: {120: [5]}
#
# Word: child
# Text & Token Indices: {121: [1], 206: [6], 232: [10]}
#
# Word: special
# Text & Token Indices: {121: [2]}
#
# Word: april
# Text & Token Indices: {123: [0]}
#
# Word: 1945
# Text & Token Indices: {123: [1]}
#
# Word: awaits
# Text & Token Indices: {123: [3]}
#
# Word: think
# Text & Token Indices: {124: [1], 144: [3]}
#
# Word: lesser
# Text & Token Indices: {124: [3]}
#
# Word: boy
# Text & Token Indices: {124: [4], 229: [19]}
#
# Word: working
# Text & Token Indices: {127: [3]}
#
# Word: not
# Text & Token Indices: {128: [0, 5, 11], 232: [7]}
#
# Word: since
# Text & Token Indices: {128: [1, 6, 12]}
#
# Word: marx
# Text & Token Indices: {128: [7]}
#
# Word: brother
# Text & Token Indices: {128: [8]}
#
# Word: itch
# Text & Token Indices: {128: [16]}
#
# Word: marilyn
# Text & Token Indices: {128: [18]}
#
# Word: seems
# Text & Token Indices: {129: [1]}
#
# Word: woman
# Text & Token Indices: {130: [2], 229: [10]}
#
# Word: earn
# Text & Token Indices: {131: [0]}
#
# Word: spend
# Text & Token Indices: {131: [1]}
#
# Word: party
# Text & Token Indices: {131: [2]}
#
# Word: inspired
# Text & Token Indices: {132: [0], 158: [18]}
#
# Word: true
# Text & Token Indices: {132: [1], 154: [2], 172: [1], 178: [2], 191: [2], 231: [1]}
#
# Word: more
# Text & Token Indices: {133: [0]}
#
# Word: overwhelming
# Text & Token Indices: {133: [5]}
#
# Word: human
# Text & Token Indices: {133: [7]}
#
# Word: emotion
# Text & Token Indices: {133: [8]}
#
# Word: top
# Text & Token Indices: {134: [3]}
#
# Word: tiondramawar
# Text & Token Indices: {135: [0]}
#
# Word: what
# Text & Token Indices: {136: [0], 197: [0], 220: [0], 223: [0], 237: [1]}
#
# Word: happens
# Text & Token Indices: {136: [1]}
#
# Word: make-believe
# Text & Token Indices: {136: [2]}
#
# Word: real
# Text & Token Indices: {136: [5], 172: [3], 216: [3, 7]}
#
# Word: stage
# Text & Token Indices: {137: [3]}
#
# Word: greed
# Text & Token Indices: {138: [3]}
#
# Word: thing
# Text & Token Indices: {139: [3], 142: [2], 166: [20]}
#
# Word: killing
# Text & Token Indices: {139: [4]}
#
# Word: only
# Text & Token Indices: {142: [1]}
#
# Word: greater
# Text & Token Indices: {142: [3]}
#
# Word: than
# Text & Token Indices: {142: [4]}
#
# Word: better
# Text & Token Indices: {144: [0]}
#
# Word: storming
# Text & Token Indices: {145: [0]}
#
# Word: high
# Text & Token Indices: {145: [2, 3]}
#
# Word: worse
# Text & Token Indices: {146: [1]}
#
# Word: fence
# Text & Token Indices: {147: [1]}
#
# Word: front
# Text & Token Indices: {147: [2]}
#
# Word: climb
# Text & Token Indices: {147: [6]}
#
# Word: are
# Text & Token Indices: {148: [1]}
#
# Word: clean
# Text & Token Indices: {148: [3]}
#
# Word: getaway
# Text & Token Indices: {148: [4]}
#
# Word: multiverse
# Text & Token Indices: {149: [1]}
#
# Word: unleashed
# Text & Token Indices: {149: [2]}
#
# Word: 2003
# Text & Token Indices: {150: [2]}
#
# Word: uma
# Text & Token Indices: {150: [3]}
#
# Word: thurman
# Text & Token Indices: {150: [4]}
#
# Word: kill
# Text & Token Indices: {150: [5], 214: [13]}
#
# Word: bill
# Text & Token Indices: {150: [6]}
#
# Word: bandit
# Text & Token Indices: {151: [4]}
#
# Word: anytime
# Text & Token Indices: {152: [0]}
#
# Word: anywhere
# Text & Token Indices: {152: [1]}
#
# Word: 71
# Text & Token Indices: {153: [0]}
#
# Word: %
# Text & Token Indices: {153: [1]}
#
# Word: surface
# Text & Token Indices: {153: [4]}
#
# Word: covered
# Text & Token Indices: {153: [5]}
#
# Word: water
# Text & Token Indices: {153: [6], 203: [8], 230: [2]}
#
# Word: lot
# Text & Token Indices: {153: [9]}
#
# Word: fish
# Text & Token Indices: {153: [13]}
#
# Word: incredible
# Text & Token Indices: {154: [1], 191: [1]}
#
# Word: probably
# Text & Token Indices: {154: [5]}
#
# Word: tough
# Text & Token Indices: {155: [2]}
#
# Word: tender
# Text & Token Indices: {155: [5]}
#
# Word: close
# Text & Token Indices: {155: [8, 12]}
#
# Word: maybe
# Text & Token Indices: {155: [9]}
#
# Word: even
# Text & Token Indices: {155: [10], 229: [5]}
#
# Word: ographydramasport
# Text & Token Indices: {156: [0]}
#
# Word: 5th
# Text & Token Indices: {157: [2]}
#
# Word: november
# Text & Token Indices: {157: [3], 196: [39]}
#
# Word: gun
# Text & Token Indices: {157: [4, 11]}
#
# Word: powder
# Text & Token Indices: {157: [5, 12]}
#
# Word: treason
# Text & Token Indices: {157: [6, 13]}
#
# Word: plot
# Text & Token Indices: {157: [7]}
#
# Word: reason
# Text & Token Indices: {157: [10]}
#
# Word: forgot
# Text & Token Indices: {157: [15]}
#
# Word: thousand
# Text & Token Indices: {158: [1, 10], 232: [1]}
#
# Word: unparalleled
# Text & Token Indices: {158: [3]}
#
# Word: drama
# Text & Token Indices: {158: [4]}
#
# Word: romance
# Text & Token Indices: {158: [6]}
#
# Word: wonder
# Text & Token Indices: {158: [11]}
#
# Word: revealed
# Text & Token Indices: {158: [12]}
#
# Word: breathtaking
# Text & Token Indices: {158: [16]}
#
# Word: spectacle
# Text & Token Indices: {158: [17]}
#
# Word: acting
# Text & Token Indices: {158: [19]}
#
# Word: cast
# Text & Token Indices: {158: [21]}
#
# Word: assembled
# Text & Token Indices: {158: [23]}
#
# Word: most-talked
# Text & Token Indices: {158: [33]}
#
# Word: made
# Text & Token Indices: {158: [36], 185: [4], 204: [3], 216: [15]}
#
# Word: disgrace
# Text & Token Indices: {159: [1]}
#
# Word: criminal
# Text & Token Indices: {159: [2]}
#
# Word: everywhere
# Text & Token Indices: {159: [3]}
#
# Word: meet
# Text & Token Indices: {160: [0]}
#
# Word: little
# Text & Token Indices: {160: [1], 174: [1], 185: [5]}
#
# Word: inside
# Text & Token Indices: {160: [3], 249: [0]}
#
# Word: head
# Text & Token Indices: {160: [4]}
#
# Word: kiss
# Text & Token Indices: {161: [0, 2]}
#
# Word: by
# Text & Token Indices: {161: [1]}
#
# Word: supreme
# Text & Token Indices: {161: [4]}
#
# Word: unfurls
# Text & Token Indices: {161: [6]}
#
# Word: un
# Text & Token Indices: {162: [0, 4], 205: [9]}
#
# Word: crimen
# Text & Token Indices: {162: [1]}
#
# Word: sin
# Text & Token Indices: {162: [2], 205: [7]}
#
# Word: castigo
# Text & Token Indices: {162: [3]}
#
# Word: amor
# Text & Token Indices: {162: [5]}
#
# Word: puro
# Text & Token Indices: {162: [6]}
#
# Word: una
# Text & Token Indices: {162: [7], 214: [4]}
#
# Word: historia
# Text & Token Indices: {162: [8]}
#
# Word: que
# Text & Token Indices: {162: [9], 205: [14]}
#
# Word: debe
# Text & Token Indices: {162: [10]}
#
# Word: morir
# Text & Token Indices: {162: [11]}
#
# Word: without
# Text & Token Indices: {162: [14], 225: [5]}
#
# Word: punishment
# Text & Token Indices: {162: [15]}
#
# Word: pure
# Text & Token Indices: {162: [17]}
#
# Word: imationadventurefamilyfantasy
# Text & Token Indices: {163: [0]}
#
# Word: medycrimedrama
# Text & Token Indices: {164: [0]}
#
# Word: towering
# Text & Token Indices: {165: [1]}
#
# Word: triumph
# Text & Token Indices: {165: [2], 248: [1]}
#
# Word: maker
# Text & Token Indices: {165: [4]}
#
# Word: lawrence
# Text & Token Indices: {165: [6]}
#
# Word: arabia
# Text & Token Indices: {165: [7]}
#
# Word: choose
# Text & Token Indices: {166: [0, 2, 4, 7, 14]}
#
# Word: starter
# Text & Token Indices: {166: [5]}
#
# Word: home
# Text & Token Indices: {166: [6]}
#
# Word: dental
# Text & Token Indices: {166: [8]}
#
# Word: insurance
# Text & Token Indices: {166: [9]}
#
# Word: leisure
# Text & Token Indices: {166: [10]}
#
# Word: matching
# Text & Token Indices: {166: [12]}
#
# Word: luggage
# Text & Token Indices: {166: [13]}
#
# Word: future
# Text & Token Indices: {166: [15]}
#
# Word: would
# Text & Token Indices: {166: [17], 223: [1]}
#
# Word: moment
# Text & Token Indices: {167: [1]}
#
# Word: matter
# Text & Token Indices: {167: [2]}
#
# Word: homespun
# Text & Token Indices: {169: [1]}
#
# Word: imationcomedyfamilyfantasy
# Text & Token Indices: {171: [0]}
#
# Word: fake
# Text & Token Indices: {172: [4]}
#
# Word: beyond
# Text & Token Indices: {173: [0, 3, 6, 9]}
#
# Word: silence
# Text & Token Indices: {173: [1], 213: [3]}
#
# Word: feeling
# Text & Token Indices: {173: [5]}
#
# Word: biggest
# Text & Token Indices: {174: [5]}
#
# Word: futuristic
# Text & Token Indices: {175: [1]}
#
# Word: vision
# Text & Token Indices: {175: [2]}
#
# Word: perfected
# Text & Token Indices: {175: [3]}
#
# Word: 2007
# Text & Token Indices: {175: [4], 212: [4]}
#
# Word: final
# Text & Token Indices: {175: [5]}
#
# Word: remembered
# Text & Token Indices: {176: [6]}
#
# Word: -charlie
# Text & Token Indices: {176: [8]}
#
# Word: chaplin
# Text & Token Indices: {176: [9]}
#
# Word: ad-
# Text & Token Indices: {176: [11], 236: [12]}
#
# Word: calgary
# Text & Token Indices: {176: [12, 15]}
#
# Word: daily
# Text & Token Indices: {176: [13]}
#
# Word: herald
# Text & Token Indices: {176: [14]}
#
# Word: alta
# Text & Token Indices: {176: [16]}
#
# Word: 30
# Text & Token Indices: {176: [17]}
#
# Word: december
# Text & Token Indices: {176: [18]}
#
# Word: 1925
# Text & Token Indices: {176: [19]}
#
# Word: jump
# Text & Token Indices: {177: [0]}
#
# Word: eurorail
# Text & Token Indices: {177: [2]}
#
# Word: extraordinary
# Text & Token Indices: {178: [1], 204: [5], 239: [5]}
#
# Word: solomon
# Text & Token Indices: {178: [4]}
#
# Word: northup
# Text & Token Indices: {178: [5]}
#
# Word: launched
# Text & Token Indices: {179: [2]}
#
# Word: here
# Text & Token Indices: {180: [3]}
#
# Word: lived
# Text & Token Indices: {181: [2]}
#
# Word: jungle
# Text & Token Indices: {181: [3]}
#
# Word: law
# Text & Token Indices: {181: [4]}
#
# Word: dock
# Text & Token Indices: {181: [5]}
#
# Word: tale
# Text & Token Indices: {182: [1]}
#
# Word: christ
# Text & Token Indices: {182: [2]}
#
# Word: 'til
# Text & Token Indices: {183: [5]}
#
# Word: venturecomedycrime
# Text & Token Indices: {184: [0]}
#
# Word: we
# Text & Token Indices: {185: [1], 195: [0], 202: [2, 5], 232: [5]}
#
# Word: stuff
# Text & Token Indices: {185: [2]}
#
# Word: rounded
# Text & Token Indices: {185: [7]}
#
# Word: sleep
# Text & Token Indices: {185: [8]}
#
# Word: shakespeare
# Text & Token Indices: {185: [10]}
#
# Word: tempest
# Text & Token Indices: {185: [13]}
#
# Word: buster
# Text & Token Indices: {186: [0]}
#
# Word: drive
# Text & Token Indices: {186: [1]}
#
# Word: general
# Text & Token Indices: {186: [4]}
#
# Word: trainload
# Text & Token Indices: {186: [6]}
#
# Word: trade
# Text & Token Indices: {186: [8]}
#
# Word: paper
# Text & Token Indices: {186: [9]}
#
# Word: carol
# Text & Token Indices: {187: [0]}
#
# Word: reed
# Text & Token Indices: {187: [1]}
#
# Word: falsely
# Text & Token Indices: {188: [0]}
#
# Word: accused
# Text & Token Indices: {188: [1]}
#
# Word: wrongly
# Text & Token Indices: {188: [2]}
#
# Word: imprisoned
# Text & Token Indices: {188: [3]}
#
# Word: fought
# Text & Token Indices: {188: [5]}
#
# Word: justice
# Text & Token Indices: {188: [6]}
#
# Word: clear
# Text & Token Indices: {188: [7], 203: [3]}
#
# Word: important
# Text & Token Indices: {189: [1]}
#
# Word: powerful
# Text & Token Indices: {189: [2], 198: [6]}
#
# Word: redmond
# Text & Token Indices: {190: [3]}
#
# Word: barry
# Text & Token Indices: {190: [4]}
#
# Word: gentleman
# Text & Token Indices: {190: [6]}
#
# Word: tragedy
# Text & Token Indices: {190: [8]}
#
# Word: based
# Text & Token Indices: {191: [0]}
#
# Word: complete
# Text & Token Indices: {192: [1]}
#
# Word: restored
# Text & Token Indices: {192: [2]}
#
# Word: version
# Text & Token Indices: {192: [3]}
#
# Word: 1953
# Text & Token Indices: {192: [4]}
#
# Word: french
# Text & Token Indices: {192: [5], 229: [1]}
#
# Word: 1986
# Text & Token Indices: {193: [0]}
#
# Word: small
# Text & Token Indices: {193: [1]}
#
# Word: two
# Text & Token Indices: {193: [4], 199: [0, 3], 200: [3], 241: [0], 243: [6]}
#
# Word: detective
# Text & Token Indices: {193: [5]}
#
# Word: everything
# Text & Token Indices: {193: [6], 203: [2], 223: [7]}
#
# Word: inch
# Text & Token Indices: {194: [1]}
#
# Word: lose
# Text & Token Indices: {195: [1]}
#
# Word: control
# Text & Token Indices: {195: [2]}
#
# Word: operator
# Text & Token Indices: {196: [1]}
#
# Word: say
# Text & Token Indices: {196: [2]}
#
# Word: ..
# Text & Token Indices: {196: [3]}
#
# Word: going
# Text & Token Indices: {196: [7]}
#
# Word: to
# Text & Token Indices: {196: [8, 12, 18], 227: [4], 236: [4]}
#
# Word: pleasure
# Text & Token Indices: {196: [11]}
#
# Word: mr.
# Text & Token Indices: {196: [15]}
#
# Word: smith
# Text & Token Indices: {196: [16]}
#
# Word: go
# Text & Token Indices: {196: [17], 206: [3], 234: [4]}
#
# Word: washington
# Text & Token Indices: {196: [19]}
#
# Word: 5
# Text & Token Indices: {196: [21]}
#
# Word: starting
# Text & Token Indices: {196: [23]}
#
# Word: sunday
# Text & Token Indices: {196: [24]}
#
# Word: nov.7
# Text & Token Indices: {196: [25]}
#
# Word: cactus
# Text & Token Indices: {196: [33]}
#
# Word: 2
# Text & Token Indices: {196: [40]}
#
# Word: 1938
# Text & Token Indices: {196: [41]}
#
# Word: lovely
# Text & Token Indices: {197: [2]}
#
# Word: visual
# Text & Token Indices: {198: [2]}
#
# Word: scope
# Text & Token Indices: {198: [3]}
#
# Word: imaginative
# Text & Token Indices: {198: [4]}
#
# Word: concept
# Text & Token Indices: {198: [5]}
#
# Word: content
# Text & Token Indices: {198: [7]}
#
# Word: written
# Text & Token Indices: {198: [8]}
#
# Word: directed
# Text & Token Indices: {198: [9]}
#
# Word: ingmar
# Text & Token Indices: {198: [10], 242: [3]}
#
# Word: bergman
# Text & Token Indices: {198: [11], 242: [4]}
#
# Word: twice
# Text & Token Indices: {198: [12]}
#
# Word: honored
# Text & Token Indices: {198: [13]}
#
# Word: interational
# Text & Token Indices: {198: [14]}
#
# Word: jury
# Text & Token Indices: {198: [15]}
#
# Word: cannes
# Text & Token Indices: {198: [16]}
#
# Word: festival
# Text & Token Indices: {198: [18]}
#
# Word: 1956,1957
# Text & Token Indices: {198: [19]}
#
# Word: unlikely
# Text & Token Indices: {199: [1]}
#
# Word: together
# Text & Token Indices: {199: [7]}
#
# Word: unusual
# Text & Token Indices: {199: [9]}
#
# Word: boundary
# Text & Token Indices: {201: [2]}
#
# Word: monster
# Text & Token Indices: {202: [0]}
#
# Word: inc.
# Text & Token Indices: {202: [1], 207: [3]}
#
# Word: scare
# Text & Token Indices: {202: [3]}
#
# Word: because
# Text & Token Indices: {202: [4]}
#
# Word: care
# Text & Token Indices: {202: [6]}
#
# Word: amity
# Text & Token Indices: {203: [0]}
#
# Word: island
# Text & Token Indices: {203: [1]}
#
# Word: sky
# Text & Token Indices: {203: [4]}
#
# Word: gentle
# Text & Token Indices: {203: [5]}
#
# Word: surf
# Text & Token Indices: {203: [6]}
#
# Word: warm
# Text & Token Indices: {203: [7]}
#
# Word: flocked
# Text & Token Indices: {203: [10]}
#
# Word: feeding
# Text & Token Indices: {203: [15]}
#
# Word: ground
# Text & Token Indices: {203: [16]}
#
# Word: inspiration
# Text & Token Indices: {204: [1]}
#
# Word: hay
# Text & Token Indices: {205: [0]}
#
# Word: quienes
# Text & Token Indices: {205: [1]}
#
# Word: tratan
# Text & Token Indices: {205: [2]}
#
# Word: de
# Text & Token Indices: {205: [3]}
#
# Word: ganarse
# Text & Token Indices: {205: [4]}
#
# Word: la
# Text & Token Indices: {205: [5], 214: [0]}
#
# Word: vida
# Text & Token Indices: {205: [6]}
#
# Word: mover
# Text & Token Indices: {205: [8]}
#
# Word: dedo
# Text & Token Indices: {205: [10]}
#
# Word: otros
# Text & Token Indices: {205: [12]}
#
# Word: tienen
# Text & Token Indices: {205: [13]}
#
# Word: cortarlos
# Text & Token Indices: {205: [15]}
#
# Word: mexico
# Text & Token Indices: {205: [16]}
#
# Word: relationship
# Text & Token Indices: {206: [4], 238: [4]}
#
# Word: bring
# Text & Token Indices: {206: [7]}
#
# Word: boundless
# Text & Token Indices: {206: [8]}
#
# Word: joy
# Text & Token Indices: {206: [9]}
#
# Word: endless
# Text & Token Indices: {206: [10]}
#
# Word: grief
# Text & Token Indices: {206: [11]}
#
# Word: joan
# Text & Token Indices: {207: [0]}
#
# Word: arc
# Text & Token Indices: {207: [1]}
#
# Word: present
# Text & Token Indices: {207: [4]}
#
# Word: when
# Text & Token Indices: {208: [0]}
#
# Word: descended
# Text & Token Indices: {208: [2]}
#
# Word: turned
# Text & Token Indices: {208: [5]}
#
# Word: choice
# Text & Token Indices: {208: [10]}
#
# Word: took
# Text & Token Indices: {209: [1]}
#
# Word: ride
# Text & Token Indices: {209: [4]}
#
# Word: ringside
# Text & Token Indices: {210: [1]}
#
# Word: seat
# Text & Token Indices: {210: [2]}
#
# Word: bloodiest
# Text & Token Indices: {210: [3]}
#
# Word: bicentennial
# Text & Token Indices: {210: [4]}
#
# Word: history
# Text & Token Indices: {210: [5]}
#
# Word: casualty
# Text & Token Indices: {211: [2]}
#
# Word: innocence
# Text & Token Indices: {211: [4], 216: [5]}
#
# Word: dinner
# Text & Token Indices: {212: [0]}
#
# Word: served
# Text & Token Indices: {212: [1]}
#
# Word: break
# Text & Token Indices: {213: [0, 2]}
#
# Word: sua
# Text & Token Indices: {214: [1]}
#
# Word: missione
# Text & Token Indices: {214: [2]}
#
# Word: e
# Text & Token Indices: {214: [3]}
#
# Word: sola
# Text & Token Indices: {214: [5]}
#
# Word: distruggere
# Text & Token Indices: {214: [6]}
#
# Word: uccidere
# Text & Token Indices: {214: [7]}
#
# Word: mission
# Text & Token Indices: {214: [11]}
#
# Word: destroy
# Text & Token Indices: {214: [12]}
#
# Word: italian
# Text & Token Indices: {214: [15]}
#
# Word: dvd
# Text & Token Indices: {214: [16], 247: [3]}
#
# Word: taste
# Text & Token Indices: {216: [4, 8]}
#
# Word: everyone
# Text & Token Indices: {216: [11], 217: [0], 227: [2], 249: [1]}
#
# Word: driven
# Text & Token Indices: {217: [2]}
#
# Word: something
# Text & Token Indices: {217: [3]}
#
# Word: network
# Text & Token Indices: {218: [1]}
#
# Word: humanoid
# Text & Token Indices: {218: [4]}
#
# Word: trial
# Text & Token Indices: {218: [7]}
#
# Word: tribulation
# Text & Token Indices: {218: [8]}
#
# Word: savior
# Text & Token Indices: {218: [9]}
#
# Word: television
# Text & Token Indices: {218: [10]}
#
# Word: attempted
# Text & Token Indices: {218: [11]}
#
# Word: suicide
# Text & Token Indices: {218: [12]}
#
# Word: assassination
# Text & Token Indices: {218: [13]}
#
# Word: along
# Text & Token Indices: {218: [18]}
#
# Word: into
# Text & Token Indices: {219: [0, 2]}
#
# Word: chance
# Text & Token Indices: {220: [2]}
#
# Word: away
# Text & Token Indices: {220: [5]}
#
# Word: show
# Text & Token Indices: {221: [2]}
#
# Word: 1000
# Text & Token Indices: {221: [4]}
#
# Word: delight
# Text & Token Indices: {221: [5]}
#
# Word: indian
# Text & Token Indices: {222: [2]}
#
# Word: stuck
# Text & Token Indices: {223: [2]}
#
# Word: desire
# Text & Token Indices: {223: [9]}
#
# Word: waiting
# Text & Token Indices: {225: [3], 249: [3]}
#
# Word: wait
# Text & Token Indices: {225: [6]}
#
# Word: colonel
# Text & Token Indices: {229: [2]}
#
# Word: forced
# Text & Token Indices: {229: [4]}
#
# Word: torture
# Text & Token Indices: {229: [6]}
#
# Word: many
# Text & Token Indices: {229: [9]}
#
# Word: stopped
# Text & Token Indices: {229: [12]}
#
# Word: win
# Text & Token Indices: {229: [14]}
#
# Word: algerian
# Text & Token Indices: {229: [17]}
#
# Word: rebel
# Text & Token Indices: {229: [22]}
#
# Word: prepare
# Text & Token Indices: {230: [0]}
#
# Word: blown
# Text & Token Indices: {230: [1]}
#
# Word: faith
# Text & Token Indices: {231: [3]}
#
# Word: devotion
# Text & Token Indices: {231: [4]}
#
# Word: undying
# Text & Token Indices: {231: [5]}
#
# Word: book
# Text & Token Indices: {232: [3]}
#
# Word: sell
# Text & Token Indices: {232: [8]}
#
# Word: ticket
# Text & Token Indices: {232: [11]}
#
# Word: imedramamystery
# Text & Token Indices: {233: [0]}
#
# Word: give
# Text & Token Indices: {234: [0]}
#
# Word: room
# Text & Token Indices: {234: [1]}
#
# Word: dad
# Text & Token Indices: {234: [2]}
#
# Word: novel
# Text & Token Indices: {236: [2]}
#
# Word: leap
# Text & Token Indices: {236: [3]}
#
# Word: turbulent
# Text & Token Indices: {236: [5]}
#
# Word: syracuse
# Text & Token Indices: {236: [13, 15]}
#
# Word: herald-american
# Text & Token Indices: {236: [14]}
#
# Word: ny
# Text & Token Indices: {236: [16]}
#
# Word: 24
# Text & Token Indices: {236: [17]}
#
# Word: march
# Text & Token Indices: {236: [18]}
#
# Word: 1940
# Text & Token Indices: {236: [19]}
#
# Word: failure
# Text & Token Indices: {237: [4]}
#
# Word: communicate
# Text & Token Indices: {237: [5]}
#
# Word: expect
# Text & Token Indices: {238: [1]}
#
# Word: controversial
# Text & Token Indices: {238: [3]}
#
# Word: vanguard
# Text & Token Indices: {239: [1]}
#
# Word: film-makers
# Text & Token Indices: {239: [3]}
#
# Word: radiance
# Text & Token Indices: {240: [0]}
#
# Word: flood
# Text & Token Indices: {240: [2]}
#
# Word: warms
# Text & Token Indices: {240: [7]}
#
# Word: lover
# Text & Token Indices: {241: [2]}
#
# Word: grandest
# Text & Token Indices: {241: [4]}
#
# Word: romantic
# Text & Token Indices: {241: [5]}
#
# Word: destined
# Text & Token Indices: {243: [3]}
#
# Word: offend
# Text & Token Indices: {243: [4]}
#
# Word: nearly
# Text & Token Indices: {243: [5]}
#
# Word: third
# Text & Token Indices: {243: [7, 13]}
#
# Word: civilized
# Text & Token Indices: {243: [8]}
#
# Word: severely
# Text & Token Indices: {243: [11]}
#
# Word: annoy
# Text & Token Indices: {243: [12]}
#
# Word: huge
# Text & Token Indices: {244: [2]}
#
# Word: hide
# Text & Token Indices: {244: [3]}
#
# Word: whisper
# Text & Token Indices: {245: [2]}
#
# Word: nature
# Text & Token Indices: {246: [3]}
#
# Word: mercy
# Text & Token Indices: {246: [5]}
#
# Word: reverence
# Text & Token Indices: {246: [9]}
#
# Word: called
# Text & Token Indices: {246: [12]}
#
# Word: wish
# Text & Token Indices: {247: [0]}
#
# Word: granted
# Text & Token Indices: {247: [1]}
#
# Word: changed
# Text & Token Indices: {248: [2]}
#
# Word: frontier
# Text & Token Indices: {249: [2]}
#
# Word: discovered
# Text & Token Indices: {249: [4]}

# %% [markdown]
# Positional Index and Phrase Query

# %%
def positional_intersect(p1, p2, K):
    answer = list()
    i = 0
    j = 0
    while i < len(p1) and j < len(p2):
        document_id_p1 = list(p1.keys())[i]
        document_id_p2 = list(p2.keys())[j]
        
        if document_id_p1 == document_id_p2:
            l = list()
            pp1 = p1[document_id_p1]
            pp2 = p2[document_id_p2]
            
            k = 0
            while k < len(pp1):
                m = 0
                while m < len(pp2):
                    distance = pp2[m] - pp1[k]
                    if distance == K:
                        l.append(m)
                    m += 1
                
                for ps in l:
                    distance = (pp2[ps] - pp1[k])
                    if distance != K:
                        l.remove(ps)
                        
                for ps in l:
                    answer.append((document_id_p1, pp1[k], pp2[ps]))
                
                k += 1
            
            i += 1
            j += 1
        
        elif document_id_p1 < document_id_p2:
            i += 1
        else:
            j += 1
    
    return answer

# %% [markdown]
# checking if positional index works

# %%
def search_positional_index(query):
    query = query.split()
    words = [query[i] for i in range(0, len(query), 2)]
    k = [int(query[i][1:]) for i in range(1, len(query), 2)]
    
    document_list = list()
    for i in range(0, len(words)-1):
        word1, word2 = words[i:i+2]
        p1 = positional_index[word1]
        p2 = positional_index[word2]
        result = positional_intersect(p1, p2, k[i])
        document_list.extend(result)
        
    return document_list

# %%
search_positional_index("life /7 ")
# Out:
# []

# %% [markdown]
# HANDLING WILDCARD AND PHRASE QUERIES

# %%
def search(query):
    if '*' in query:
        query = query.replace('*', '')
        result = []
        for word in inverted_index:
            if query in word:
                result.extend(inverted_index[word])
        return result
    elif '"' in query:
        query = query.replace('"', '')
        result = []
        for word in inverted_index:
            if query == word:
                result.extend(inverted_index[word])
        return result
    else:
        return inverted_index[query]

# %%
search('picture*')
# Out:
# [32, 96, 227, 133, 71, 232, 44, 207, 176, 239, 243, 120, 158, 94]

# %%
search("day")
# Out:
# [226, 196, 197, 69, 119, 223]

# %% [markdown]
# RETRIEVE RELEVANT TEXT USING SIMILARITY INDEX

# %%
def retrieve_relevant_text(query):
    # handle wildcard and phase queries
    docs = search(query)
    # get the relevant text
    relevant_text = []
    for doc in docs:
        relevant_text.append(df.loc[df['id'] == doc]['tagline'].values[0])
    return relevant_text

# %%
df['id'] = range(0, len(df))

# %%
retrieve_relevant_text('life')
# Out:
# ['Life Is In Their Hands -- Death Is On Their Minds!',
#  'Whoever saves one life, saves the world entire.',
#  'Father of a murdered son, husband to a murdered wife and I shall have my vengeance in this life or the next',
#  'One person can change your life forever.',
#  'The Legend Comes to Life',
#  'Choose life. Choose a job. Choose a starter home. Choose dental insurance, leisure wear and matching luggage. Choose your future. But why would anyone want to do a thing like that?',
#  'He was their inspiration. He made their lives extraordinary.',
#  'THE MIGHTY NOVEL LEAPS TO TURBULENT LIFE ON THE SCREEN! (Print Ad- Syracuse Herald-American, ((Syracuse, NY)) 24 March 1940)',
#  'As long as life goes on, relationships between parents and children will bring boundless joy and endless grief.',
#  'There were three men in her life. One knew her past. One wanted her land. One wanted revenge.',
#  'Life finds a way.',
#  'Frank Capra\'s..."It\'s a Wonderful Life".',
#  'Life, liberty and the pursuit of vengeance.',
#  '"Why are you suing your parents?" "For giving me life."',
#  "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.",
#  '"We are such stuff as dreams are made on, and our little life is rounded with a sleep." Shakespeare - The Tempest']

# %% [markdown]
# retrieve relevant text using likelhood language model

# %%
def retrieve_relevant_text_using_likelihood_language_model(query):
    # handle wildcard and phase queries
    docs = search(query)
    # get the relevant text
    relevant_text = []
    for doc in docs:
        relevant_text.append(df.loc[df['id'] == doc]['tagline'].values[0])
    return relevant_text

# %%
retrieve_relevant_text_using_likelihood_language_model('picture')
# Out:
# ["The picture you MUST see from the beginning... Or not at all!... For no one will be seated after the start of... Alfred Hitchcock's greatest shocker Psycho.",
#  'A Mighty Motion Picture Of Action And Adventure!',
#  'The Picture Everyone Wants To See.',
#  'More than a motion picture...It is an overwhelming experience in human emotion you will never forget!',
#  'The man... The music... The madness... The murder... The motion picture...',
#  'The thousands who have read the book will know why WE WILL NOT SELL ANY CHILDREN TICKETS to see this picture!',
#  'The World Has Never Understood Why the Japanese Prefer Death to Dishonor! This Samurai Picture Provides The Answer!!',
#  'JOAN of ARC PICTURES Inc. presents',
#  '"The Picture I Want to Be Remembered by." -Charlie Chaplin. (Print Ad- Calgary Daily Herald, ((Calgary, Alta.)) 30 December 1925)',
#  'From the Vanguard of New Film-Makers Comes an Extraordinary Motion Picture',
#  'A motion picture destined to offend nearly two thirds of the civilized world. And severely annoy the other third.',
#  'The Prize Picture They Want to Censor!',
#  "For the thousands who remember its unparalleled drama, action and romance! For the new thousands to whom the wonders will be revealed for the first time! Breathtaking spectacle, inspired acting by the greatest cast ever assembled! The screen's most exciting love story! The most-talked about picture ever made! [reissue]",
#  "Radio's Most Dynamic Artist . . The Man At Whose Voice A Nation Trembled . . . Now the screen's most exciting NEW star ! ORSON WELLES in the picture Hollywood said he'd never make"]

# %% [markdown]
# RANKING OF RETRIEVED DOCUMENTS

# %%
def rank_retrieved_documents(query):
    # handle wildcard and phase queries
    docs = search(query)
    # get the relevant text
    relevant_text = []
    for doc in docs:
        relevant_text.append(df.loc[df['id'] == doc]['tagline'].values[0])
    # calculate the score for each document
    scores = {}
    for doc in relevant_text:
        scores[doc] = 0
        for word in query.split():
            scores[doc] += doc.count(word)
    # sort the documents based on the score
    sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    return sorted_scores

# %%
rank_retrieved_documents('world')
# Out:
# [('Whoever saves one life, saves the world entire.', 1),
#  ("The greatest trick the devil ever pulled was to convince the world he didn't exist",
#   1),
#  ('Two unlikely people. Two different worlds come together in a story about a most unusual friendship.',
#   1),
#  ("All the world's a stage...", 1),
#  ('He was Tony Montana. The world will remember him by another name...SCARFACE.',
#   1),
#  ('One adventure will change two worlds', 1),
#  ("Sometimes you have to reach into someone else's world to find out what's missing in your own.",
#   1),
#  ('He stands alone as the greatest entertainer of modern times! No one on earth can make you laugh as heartily or touch your heart as deeply...the whole world laughs, cries and thrills to his priceless genius!',
#   1),
#  ('When a country descended into madness and the world turned its back, one man had to make a choice',
#   1),
#  ('HE RETURNS -And the world rocks again with laughter. (Print Ad-Daily Examiner, ((Grafton, NSW)) 6 July 1931)',
#   1),
#  ('A motion picture destined to offend nearly two thirds of the civilized world. And severely annoy the other third.',
#   1),
#  ('The World Has Never Understood Why the Japanese Prefer Death to Dishonor! This Samurai Picture Provides The Answer!!',
#   0),
#  ('His Triumph Changed The World Forever.', 0)]

# %% [markdown]
# Advanced search: relevance feedback, semantic matching, reranking of results, finding out query intention

# %%
def advanced_search(query):
    # get the relevant text
    relevant_text = retrieve_relevant_text(query)
    # calculate the score for each document
    scores = {}
    for doc in relevant_text:
        scores[doc] = 0
        for word in query.split():
            scores[doc] += doc.count(word)
    # sort the documents based on the score
    sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    return sorted_scores

# %%
advanced_search('world')
# Out:
# [('Whoever saves one life, saves the world entire.', 1),
#  ("The greatest trick the devil ever pulled was to convince the world he didn't exist",
#   1),
#  ('Two unlikely people. Two different worlds come together in a story about a most unusual friendship.',
#   1),
#  ("All the world's a stage...", 1),
#  ('He was Tony Montana. The world will remember him by another name...SCARFACE.',
#   1),
#  ('One adventure will change two worlds', 1),
#  ("Sometimes you have to reach into someone else's world to find out what's missing in your own.",
#   1),
#  ('He stands alone as the greatest entertainer of modern times! No one on earth can make you laugh as heartily or touch your heart as deeply...the whole world laughs, cries and thrills to his priceless genius!',
#   1),
#  ('When a country descended into madness and the world turned its back, one man had to make a choice',
#   1),
#  ('HE RETURNS -And the world rocks again with laughter. (Print Ad-Daily Examiner, ((Grafton, NSW)) 6 July 1931)',
#   1),
#  ('A motion picture destined to offend nearly two thirds of the civilized world. And severely annoy the other third.',
#   1),
#  ('The World Has Never Understood Why the Japanese Prefer Death to Dishonor! This Samurai Picture Provides The Answer!!',
#   0),
#  ('His Triumph Changed The World Forever.', 0)]

# %% [markdown]
# RERANKING RESULTS

# %%
def rerank_results(query):
    index = inverted_index
    documents = search(query)
    # Create a list to store document scores
    scores = []
    # Split the query into individual terms
    query_terms = query.split()
    # Iterate over each document
    for doc_id in documents:
        # Initialize the score for this document
        score = 0
        # Iterate over each query term
        for term in query_terms:
            # If the term appears in the document
            if term in index and doc_id in index[term]:
                # Increment the score by the frequency of the term in the document
                try:
                    score += index[term][doc_id]
                except:
                    pass
        # Add the document score to the list of scores
        scores.append((doc_id, score))
    # Sort the list of scores in descending order
    scores.sort(key=lambda x: x[1], reverse=True)
    # Return the sorted list of document IDs
    return [doc_id for doc_id, score in scores]

# %%
rerank_results('world')
# Out:
# [5, 39, 199, 137, 106, 200, 44, 45, 46, 208, 51, 243, 248]

# %% [markdown]
# SEMANTIC MATCHING

# %%
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize

# define a function to calculate semantic similarity between two words using WordNet
def calculate_similarity(word1, word2):
    synsets1 = wn.synsets(word1)
    synsets2 = wn.synsets(word2)
    if not synsets1 or not synsets2:
        return 0.0
    max_sim = -1
    for synset1 in synsets1:
        for synset2 in synsets2:
            sim = wn.path_similarity(synset1, synset2)
            if sim is not None and sim > max_sim:
                max_sim = sim
    return max_sim

# define a function to perform semantic matching of a query against a document
def semantic_matching(query):
    documents = inverted_index

    scores = []

    query_tokens = word_tokenize(query)

    for document in documents:
        doc_tokens = word_tokenize(document)
        similarity_score = 0.0
        for query_token in query_tokens:
            max_sim = -1
            for doc_token in doc_tokens:
                sim = calculate_similarity(query_token, doc_token)
                if sim > max_sim:
                    max_sim = sim
            similarity_score += max_sim
        scores.append((document, similarity_score / len(query_tokens)))
    return scores

# %%
semantic_matching('why so serious')
# Out:
